# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 一、预处理
#
# 导入相关函数

# %%
import time

# We have three versions of our implementations
# Version1: without using socket and no DP+PixelDP
# Version2: with using socket but no DP+PixelDP
# Version3: without using socket but with DP+PixelDP

# This program is Version1: Single program simulation
# ============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
from collections import OrderedDict


import torchvision.datasets as datasets
import random
import numpy as np
import os
from torchvision.datasets import ImageFolder

import matplotlib

pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy

SEED = 1234

def init_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    if torch.cuda.is_available():
        torch.backends.cudnn.deterministic = True
        print(torch.cuda.get_device_name(0))
init_seeds(SEED)
# Out:
# NVIDIA GeForce RTX 3090

# %% [markdown]
# ## 1.1模型初始化

# %%
from torch import nn
import torch.nn.functional as F

def conv3x3(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)

class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_blocks):
        super(ResNet18_client_side, self).__init__()
        self.in_planes = 64
        self.conv1 = conv3x3(3, 64)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        return out


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = conv3x3(in_planes, planes, stride)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = conv3x3(planes, planes)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet18_server_side(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10, pool_size=4):  # Add a new argument pool_size
        super(ResNet18_server_side, self).__init__()
        self.in_planes = 64
        self.pool_size = pool_size  # Add this line to store pool_size
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.layer2(x)
        out = self.layer3(out)
        out = self.layer4(out)
        # print("Output shape before pooling:", out.shape)
        out = F.avg_pool2d(out, kernel_size=self.pool_size)  # Use self.pool_size instead of 8
        # print("Output shape after pooling:", out.shape)
        out = out.view(out.size(0), -1)
        y_hat = self.linear(out)
        return y_hat

# %%
import logging

def init_logging(program_name):
    logging.basicConfig(filename=f'{program_name}.log', level=logging.INFO)
    logging.getLogger().addHandler(logging.StreamHandler())
    
# ===================================================================
program = "SFLV1"
print(f"---------{program}----------")  # this is to identify the program in the slurm outputs files
init_logging(program)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ===================================================================

# No. of users
num_users = 20
epochs = 100
frac = 1  # participation of clients; if 1 then 100% clients participate in SFLV1
lr = 0.0001

# CIFAR10\HAM10000
dataset_choice = 'HAM10000'
# Out:
# ---------SFLV1----------

# %%
def init_models(device, dataset_choice):
    net_glob_client = ResNet18_client_side(BasicBlock, [2, 2, 2, 2]).to(device)
    if torch.cuda.device_count() > 1:
        logging.info(f"We use {torch.cuda.device_count()} GPUs")
        net_glob_client = nn.DataParallel(net_glob_client)

    net_glob_client.to(device)
    logging.info(net_glob_client)

    if dataset_choice == 'HAM10000':
        num_classes = 7
        pool_size = 8
    elif dataset_choice == 'CIFAR10':
        num_classes = 10
        pool_size = 4
    else:
        raise ValueError('Invalid dataset choice.')

    net_glob_server = ResNet18_server_side(BasicBlock, [2,2,2,2], num_classes=num_classes,pool_size=pool_size)
    if torch.cuda.device_count() > 1:
        logging.info(f"We use {torch.cuda.device_count()} GPUs")
        net_glob_server = nn.DataParallel(net_glob_server)

    net_glob_server.to(device)
    logging.info(net_glob_server)

    return net_glob_client, net_glob_server

net_glob_client, net_glob_server = init_models(device, dataset_choice)
# Out:
# ResNet18_client_side(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )
# ResNet18_client_side(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )
# ResNet18_client_side(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )
# ResNet18_client_side(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )
# ResNet18_client_side(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )
# ResNet18_server_side(
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=7, bias=True)
# )
# ResNet18_server_side(
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=7, bias=True)
# )
# ResNet18_server_side(
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=7, bias=True)
# )
# ResNet18_server_side(
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=7, bias=True)
# )
# ResNet18_server_side(
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=7, bias=True)
# )

# %% [markdown]
# ## 1.2 变量初始化

# %%
# ===================================================================================
# For Server Side Loss and Accuracy
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

# ====================================================================================================
#                                  Server Side Program
# ====================================================================================================
# Federated averaging: FedAvg
# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []

# （即权重和偏置）保存到w_glob_server中。
w_glob_server = net_glob_server.state_dict()
w_locals_server = []

# client idx collector
idx_collect = []  # 初始化一个空列表，用于收集选择的客户端的索引。
l_epoch_check = False  # 初始化一个布尔变量，用于指示是否进行了本地训练轮次的检查。
fed_check = False  # 初始化一个布尔变量，用于指示是否完成了联邦学习。
# Initialization of net_model_server and net_server (server-side model)
net_model_server = [net_glob_server for i in range(num_users)]  # 该列表包含了每个客户端的初始模型。
net_server = copy.deepcopy(net_model_server[0]).to(device)  # 初始化为net_model_server的第一个元素的深拷贝，并将其移到GPU上。

# %% [markdown]
# ## 1.3定义服务端

# %%
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    """

    Args:
        fx_client: 一个函数，用于在客户端更新模型参数，它接受以下参数：net_model_client（客户端模型），optimizer_client（客户端优化器），train_loader（客户端训练数据），l_epoch（客户端训练轮数）。
        y:目标变量的标签值。
        l_epoch_count:训练的总轮数
        l_epoch:当前训练的轮数
        idx:用于选择在全局模型中使用哪些本地模型进行更新的客户端的索引。
        len_batch:训练数据的批次大小。

    Returns:

    """
    # 这些是全局变量，因为它们在函数内被更新，并且在函数之外被调用。
    """
    net_model_server: 全局模型。
    criterion: 损失函数，用于计算模型的误差。
    optimizer_server: 优化器，用于更新全局模型的参数。
    device: 设备（CPU或GPU）用于计算。
    batch_acc_train: 当前批次的准确度。
    batch_loss_train: 当前批次的损失。
    l_epoch_check: 在训练期间用于检查损失和准确度的训练周期数。
    fed_check: 用于检查训练周期是否已完成的标志。
    loss_train_collect: 用于收集所有客户端训练损失的列表。
    acc_train_collect: 用于收集所有客户端训练准确度的列表。
    count1: 计数器，用于跟踪当前已经训练的客户端数量。
    acc_avg_all_user_train: 所有客户端训练准确度的平均值。
    loss_avg_all_user_train: 所有客户端训练损失的平均值。
    idx_collect: 用于跟踪已经训练的客户端的索引列表。
    w_locals_server: 所有客户端本地模型参数的列表。
    w_glob_server: 全局模型参数的列表。
    net_server: 全局模型。
    """
    global net_model_server, criterion, optimizer_server, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect, w_locals_server, w_glob_server, net_server
    global loss_train_collect_user, acc_train_collect_user, lr

    # net_server是全局模型，返回制定索引的本地模型
    net_server = copy.deepcopy(net_model_server[idx]).to(
        device)  # copy.deepcopy() 函数用于创建一个当前本地模型的副本，以便我们可以在全局模型的更新过程中使用它，而不会对原始本地模型进行更改。
    # 方法将模型设置为训练模式，这意味着在计算时会使用训练期间的正则化技术，如dropout或batch normalization。
    net_server.train()
    # 是一个PyTorch中的Adam优化器的实现，它接受模型参数和学习率作为参数，用于更新模型参数以最小化损失函数。在这里，我们使用全局模型的参数和一个预定义的学习率 lr 创建了一个Adam优化器对象
    optimizer_server = torch.optim.Adam(net_server.parameters(), lr=lr)

    # 1.train and update
    # 用于清空之前的梯度信息，这样我们可以在每个训练迭代中计算新的梯度并更新模型参数。
    optimizer_server.zero_grad()

    fx_client = fx_client.to(device)
    y = y.to(device)

    # ---------forward prop-------------
    fx_server = net_server(fx_client)  # 作为输入传递到全局模型 net_server 中，然后返回模型的预测输出 fx_server

    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)

    # --------backward prop--------------
    loss.backward()
    # 由于我们需要在全局模型更新之前将 fx_client 更新到最新的版本，因此我们使用 clone().detach() 函数来创建一个新的 dfx_client 张量，它具有相同的值但不会被计算图所记录。
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()

    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())

    # Update the server-side model for the current batch
    net_model_server[idx] = copy.deepcopy(net_server)

    # count1: to track the completion of the local batch associated with one client
    count1 += 1
    if count1 == len_batch:
        acc_avg_train = sum(batch_acc_train) / len(batch_acc_train)  # 计算当前batch的准确率
        loss_avg_train = sum(batch_loss_train) / len(batch_loss_train)  # 计算当前batch的损失

        batch_acc_train = []  # 将当前batch准确率清零
        batch_loss_train = []
        count1 = 0

        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train,
                                                                                      loss_avg_train))

        # copy the last trained model in the batch
        # 的状态字典复制到一个新的字典中，以便我们可以将其发送到参与者，从而启动下一轮的联邦学习。注意，w_server 中包含的参数是最新一轮训练的参数，因此每个参与者将从这些参数开始训练它们的本地模型。
        w_server = net_server.state_dict()

        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch - 1:
            # l_epoch_count 是本地epoch的计数器，l_epoch 是本地epoch的总数。当计数器 l_epoch_count 等于总数 l_epoch 减 1 时，说明本地epoch已经完成。
            # # 标记已经完成本地epoch
            l_epoch_check = True  # to evaluate_server function - to check local epoch has completed or not
            # We store the state of the net_glob_server()
            # w_server 是全局模型中最新的训练参数，w_locals_server 是用于存储每个参与者的最后一轮训练参数的列表。因此，当本地epoch完成时，将 w_server 添加到 w_locals_server 中，以便之后将其发送到联邦平均服务器。
            w_locals_server.append(copy.deepcopy(w_server))

            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)

            # print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train  # 记录最后一个batch的准确率和损失，作为本地epoch的结果
            loss_avg_train_all = loss_avg_train  #

            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)  # 将本地epoch的损失添加到损失列表中
            acc_train_collect_user.append(acc_avg_train_all)  # # 将本地epoch的准确率添加到准确率列表中

            # collect the id of each new user
            if idx not in idx_collect:
                idx_collect.append(idx)
                # print(idx_collect)
#                 print("已经训练的客户端:" + str(idx_collect))

        # This is for federation process--------------------
        if len(idx_collect) == num_users * frac:
            # 如果客户端编号列表的长度等于客户端总数，说明所有客户端的训练结果都已经到达服务器了。
            # 这里不对，是选择的客户端总数
            fed_check = True  # to evaluate_server function  - to check fed check has hitted

            # 异常检测
            # 使用异常检测移除异常客户端
            # anomaly_threshold = 2  # 自定义阈值
            # w_locals_server = remove_anomalies(w_locals_server, w_glob_server.state_dict(), anomaly_threshold)

            # ================== 使用不同的聚合算法 =================
            w_glob_server = FedAvg(w_locals_server)  # 使用联邦平均算法更新全局模型，将所有客户端的本地模型参数传入该函数中。
#             w_glob_server, selected_clients_indices = krum_aggregation(w_locals_server, 3)

            # server-side global model update and distribute that model to all clients ------------------------------
            net_glob_server.load_state_dict(w_glob_server)  # 将更新后的全局模型参数加载到服务器端的模型中。
            net_model_server = [net_glob_server for i in
                                range(num_users)]  # 创建一个长度为客户端数量的列表，每个元素都是更新后的全局模型。这个列表用于向每个客户端分发全局模型参数。



            acc_avg_all_user_train = sum(acc_train_collect_user) / len(acc_train_collect_user)  # 计算所有客户端训练结果的平均准确率和损失
            loss_avg_all_user_train = sum(loss_train_collect_user) / len(loss_train_collect_user)

            # 更新性能指标列表
            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)

            acc_train_collect_user = []
            loss_train_collect_user = []

            w_locals_server = []  # # 清空本地模型参数列表
            idx_collect = []  # 清空客户端编号列表

    # send gradients to the client
    return dfx_client


def evaluate_server(fx_client, y, idx, len_batch, ell, selected_clients):
    global net_model_server, criterion, batch_acc_test, batch_loss_test, check_fed, net_server, net_glob_server
    global loss_test_collect, acc_test_collect, count2, num_users, acc_avg_train_all, loss_avg_train_all, w_glob_server, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train

    net = copy.deepcopy(net_model_server[idx]).to(device)
    net.eval()
    return_local_results = False

    with torch.no_grad():
        # with torch.no_grad()是一个上下文管理器，它可以暂时关闭所有的requires_grad标志，从而不计算梯度1。这样可以节省内存，提高推理速度，也可以避免不必要的梯度累积2。通常在验证或部署模型时使用这个方法3。
        fx_client = fx_client.to(device)
        y = y.to(device)
        # ---------forward prop-------------
        fx_server = net(fx_client)

        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)

        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())

        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test) / len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test) / len(batch_loss_test)

            batch_acc_test = []
            batch_loss_test = []
            count2 = 0

            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test,
                                                                                             loss_avg_test))

            # if a local epoch is completed
            if l_epoch_check:
                l_epoch_check = False
                return_local_results = True

                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test

                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)

            # if federation is happened----------
            if fed_check:
                fed_check = False
                print("------------------------------------------------")
                print("------ Federation process at Server-Side ------- ")
                print("------------------------------------------------")

                # 计算Krum选定客户端的平均准确率和损失
                if selected_clients is None or len(selected_clients) == 0:
                    acc_avg_all_user = sum(acc_test_collect_user) / len(acc_test_collect_user)
                    loss_avg_all_user = sum(loss_test_collect_user) / len(loss_test_collect_user)
                else:
                    print("选择的客户端index:", selected_clients)
                    acc_test_collect_user = [acc_test_collect_user[i] for i in selected_clients]
                    loss_test_collect_user = [loss_test_collect_user[i] for i in selected_clients]

                    acc_avg_all_user = sum(acc_test_collect_user) / len(acc_test_collect_user)
                    loss_avg_all_user = sum(loss_test_collect_user) / len(loss_test_collect_user)

                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user = []

                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train,
                                                                                          loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user,
                                                                                         loss_avg_all_user))
                print("==========================================================")

    if return_local_results:
        return acc_avg_test_all, loss_avg_test_all
    else:
        return None, None


class Client(object):
    def __init__(self, net_client_model, idx, lr, device, dataset_train=None, dataset_test=None, idxs=None,
                 idxs_test=None, is_attacker=None, batch_size=128):
        """
        :param idxs: idxs是一个表示该客户端用于训练的数据集的索引列表。在联邦学习中，原始数据集通常由多个客户端持有，每个客户端只能访问自己所持有的部分数据集。因此，为了让每个客户端只使用自己所持有的数据进行训练，需要将原始数据集划分成多个部分，每个部分由一个客户端持有，并通过idxs将该客户端用于训练的数据集的索引列表传递给Client类的构造函数。
        :param idxs_test:
        """
        # net_client_model:一个与客户端实例相关的神经网络模型。
        self.batch_size = batch_size
        self.is_attacker = is_attacker
        self.idx = idx  # 一个整数，表示客户端的索引
        self.device = device  # 一个字符串，表示执行客户端计算的设备。
        self.lr = lr
        self.local_ep = 1
        # self.selected_clients = []
        # DatasetSplit(dataset_train, idxs)表示使用DatasetSplit类将原始的数据集dataset_train按照索引idxs进行划分，以获得当前客户端可用于训练的数据集。
        self.ldr_train = DataLoader(DatasetSplit(dataset_train, idxs), batch_size=self.batch_size,
                                    shuffle=True)
        self.ldr_test = DataLoader(DatasetSplit(dataset_test, idxs_test), batch_size=self.batch_size, shuffle=True)

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.Adam(net.parameters(), lr=self.lr)

        for iter in range(self.local_ep):
            if self.is_attacker:
                dataset_split = self.ldr_train.dataset
                num_malicious_samples = len(dataset_split.idxs)
                dataset_split.add_malicious_samples(num_malicious_samples,"HAM10000")

                # Refresh the DataLoader after adding malicious samples
                self.ldr_train = DataLoader(dataset_split, batch_size=self.batch_size, shuffle=True)

            # 外层循环是客户端的本地训练轮数self.local_ep
            len_batch = len(self.ldr_train)  # 计算该客户端的训练集数据分成的批次数。
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                # 内层循环是数据加载器self.ldr_train中每个批次的训练。在每个批次中，将图像和标签加载到设备上，然后将优化器的梯度清零。
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                # ---------forward prop-------------
                fx = net(images)
                # 生成一个可求导的副本client_fx
                client_fx = fx.clone().detach().requires_grad_(True)

                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)

                # --------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()

            # prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))

        return net.state_dict()

    def evaluate(self, net=None, ell=None, selected_clients=None):
        net.eval()

        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                # ---------forward prop-------------
                fx = net(images)

                # Sending activations to server
                acc_avg_test_all, loss_avg_test_all = evaluate_server(fx, labels, self.idx, len_batch, ell,
                                                                      selected_clients)

            # prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            if loss_avg_test_all is not None and acc_avg_test_all is not None:
                self.loss_avg_test_all = loss_avg_test_all
                self.acc_avg_test_all = acc_avg_test_all

        return

# %% [markdown]
# # 2.Data Loading

# %%
from glob import glob
from sklearn.model_selection import train_test_split
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
from PIL import ImageEnhance

class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label

    def add_malicious_samples(self, num_malicious_samples, dataset_type='CIFAR10'):
        for i in range(num_malicious_samples):
            # Randomly select an image to modify
            dataset_idx = random.choice(self.idxs)

            # Access the image data depending on the dataset structure
            img = self.dataset.data[dataset_idx]
            img = Image.fromarray(img)

            # Apply a random modification to the image (e.g., flip, rotate, or change color)
            modified_img = img.transpose(Image.FLIP_LEFT_RIGHT)  # Flip the image horizontally
            modified_img = modified_img.rotate(random.randint(0, 360))  # Rotate the image randomly

            brightness = ImageEnhance.Brightness(modified_img)
            modified_img = brightness.enhance(random.uniform(0.5, 1.5))

            contrast = ImageEnhance.Contrast(modified_img)
            modified_img = contrast.enhance(random.uniform(0.5, 1.5))

            saturation = ImageEnhance.Color(modified_img)
            modified_img = saturation.enhance(random.uniform(0.5, 1.5))

            # Add additional distortions
            modified_img = modified_img.filter(ImageFilter.GaussianBlur(radius=random.uniform(0, 2)))  # Apply Gaussian blur

            # Add noise to the image
            noise = np.random.normal(0, 25, modified_img.size)
            noise = noise.reshape(modified_img.size[::-1]).T.astype(np.uint8)
            modified_img = Image.fromarray(np.array(modified_img) + noise)

            # Clip the pixel values to be within the valid range (0-255)
            modified_img = np.clip(modified_img, 0, 255)

            # Convert the modified PIL Image back to a numpy array
            modified_img = np.array(modified_img)

            self.dataset.data[dataset_idx] = modified_img


    def add_malicious_samples_on_HAM10000(self, num_malicious_samples, dataset_type='HAM10000'):
        for i in range(num_malicious_samples):
            # Randomly select an image to modify
            dataset_idx = random.choice(self.idxs)

            # Access the image data depending on the dataset structure
            if hasattr(self.dataset, 'data'):
                img = self.dataset.data[dataset_idx]
                img = Image.fromarray(img)
            else:
                img_path = self.dataset.df['path'][dataset_idx]
                img = Image.open(img_path)

            # Convert the image to a numpy array
            img_array = np.array(img)

            # Define the black region size
            black_region_height = int(0.8 * img_array.shape[0])
            black_region_width = int(0.8 * img_array.shape[1])

            # Define the starting point for the black region
            start_height = int(0.1 * img_array.shape[0])
            start_width = int(0.1 * img_array.shape[1])

            # Set the region to black
            img_array[start_height:start_height + black_region_height,
            start_width:start_width + black_region_width] = 0

            # Convert the modified numpy array back to a PIL Image
            modified_img = Image.fromarray(img_array)

            # Save the modified image to the modify_pic directory
            modified_img_path = os.path.join("data", "modify_pic", os.path.basename(img_path))
            modified_img.save(modified_img_path)

            # Update the image in the dataset
            if hasattr(self.dataset, 'data'):
                self.dataset.data[dataset_idx] = img_array
            else:
                self.dataset.df.at[dataset_idx, 'path'] = modified_img_path
        

class SkinData(Dataset):
    def __init__(self, df, data, targets, transform=None):
        self.df = df
        self.data = data
        self.targets = targets
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        img, target = self.data[index], self.targets[index]
        img = Image.fromarray(img)

        if self.transform is not None:
            img = self.transform(img)


        return img, target

def dataset_iid(dataset, num_users):
    """
    该函数接受一个数据集dataset和一个整数num_users作为输入。
    它的作用是将数据集分割成num_users份，以便每个客户端都有一份相同分布的数据集。
    :param dataset:
    :param num_users:
    :return:函数返回一个字典dict_users，其中包含num_users个键，每个键对应一个客户端，值为该客户端所分配的数据集索引的集合。
    dict_users:{idx:int : []:list}
    """
    # 该函数首先计算每个客户端应该拥有的数据量num_items
    num_items = int(len(dataset)/num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        # 接着，函数使用np.random.choice函数从all_idxs中选择num_items个索引，将这些索引添加到字典dict_users的第i个键中，表示第i个客户端的数据集。在选择后，从all_idxs中移除已经分配给第i个客户端的索引。
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

def load_data(dataset_choice, num_users):
    """

    :param dataset_choice: 选择的数据集
    :param num_users: 用户的数量
    :return:
    """
    if dataset_choice == 'HAM10000':
        df = pd.read_csv('data/HAM10000_metadata.csv')
        print(df.head())

        lesion_type = {
            'nv': 'Melanocytic nevi',
            'mel': 'Melanoma',
            'bkl': 'Benign keratosis-like lesions ',
            'bcc': 'Basal cell carcinoma',
            'akiec': 'Actinic keratoses',
            'vasc': 'Vascular lesions',
            'df': 'Dermatofibroma'
        }

        # merging both folders of HAM1000 dataset -- part1 and part2 -- into a single directory
        imageid_path = {os.path.splitext(os.path.basename(x))[0]: x
                        for x in glob(os.path.join("data", '*', '*.jpg'))}

        # print("path---------------------------------------", imageid_path.get)
        # 将图像id映射为图像文件的路径，并将其存储在数据集中的path列中。
        df['path'] = df['image_id'].map(imageid_path.get)
        # 将诊断编码映射为对应的分类名称，并将其存储在数据集中的cell_type列中。
        df['cell_type'] = df['dx'].map(lesion_type.get)
        # 将分类名称转换为数字编码，并将其存储在数据集中的target列中。这里使用了.
        # 可以将字符串类型的分类变量转换为数字编码，其中不同的分类名称对应不同的数字编码。
        df['target'] = pd.Categorical(df['cell_type']).codes
        print(df['cell_type'].value_counts())
        print(df['target'].value_counts())

        # =============================================================================
        # Train-test split
        train, test = train_test_split(df, test_size=0.2)

        train = train.reset_index()

        test = test.reset_index()

        # Load image data and targets
        image_data = []
        for path in train['path']:
            image = Image.open(path).resize((64, 64))
            image_data.append(np.array(image))
        train_data = np.array(image_data)
        train_targets = train['target'].astype(np.int64).to_numpy()  # Change dtype to int64

        image_data = []
        for path in test['path']:
            image = Image.open(path).resize((64, 64))
            image_data.append(np.array(image))
        test_data = np.array(image_data)
        test_targets = test['target'].astype(np.int64).to_numpy()  # Change dtype to int64



        # =============================================================================
        #                         Data preprocessing
        # =============================================================================
        # Data preprocessing: Transformation
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]

        train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.Pad(3),
                                               transforms.RandomRotation(10),
                                               transforms.CenterCrop(64),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean=mean, std=std)
                                               ])

        test_transforms = transforms.Compose([
            transforms.Pad(3),
            transforms.CenterCrop(64),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])

        # With augmentation
        dataset_train = SkinData(train, train_data, train_targets, transform=train_transforms)
        dataset_test = SkinData(train, test_data, test_targets, transform=test_transforms)

        # ----------------------------------------------------------------
        dict_users = dataset_iid(dataset_train, num_users)
        dict_users_test = dataset_iid(dataset_test, num_users)
    elif dataset_choice == 'CIFAR10':
        # =============================================================================
        #                         Data loading
        # =============================================================================
        # Load CIFAR-10 dataset
        trainset = datasets.CIFAR10(root='./data', train=True, download=True)
        testset = datasets.CIFAR10(root='./data', train=False, download=True)

        train_df = pd.DataFrame(trainset.targets, columns=['target'])
        test_df = pd.DataFrame(testset.targets, columns=['target'])

        # Set the class names
        class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

        train_df['cell_type'] = train_df['target'].apply(lambda x: class_names[x])
        test_df['cell_type'] = test_df['target'].apply(lambda x: class_names[x])

        print(train_df['cell_type'].value_counts())
        print(train_df['target'].value_counts())

        # =============================================================================
        # Train-test split
        train = train_df.reset_index()
        test = test_df.reset_index()

        # =============================================================================
        #                         Data preprocessing
        # =============================================================================
        # Data preprocessing: Transformation
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]

        train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.Pad(3),
                                               transforms.RandomRotation(10),
                                               transforms.CenterCrop(32),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean=mean, std=std)
                                               ])

        test_transforms = transforms.Compose([
            transforms.Pad(3),
            transforms.CenterCrop(32),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])

        # With augmentation
        dataset_train = datasets.CIFAR10(root='./data', train=True, transform=train_transforms, download=True)
        dataset_test = datasets.CIFAR10(root='./data', train=False, transform=test_transforms, download=True)

        # ----------------------------------------------------------------
        dict_users = dataset_iid(dataset_train, num_users)
        dict_users_test = dataset_iid(dataset_test, num_users)
    else:
        raise ValueError("Invalid dataset_choice: Choose either 'HAM10000' or 'CIFAR10'")

    return dataset_train,dataset_test,dict_users,dict_users_test

# %%
dataset_train, dataset_test, dict_users, dict_users_test = load_data(dataset_choice, num_users)
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
# cell_type
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: count, dtype: int64
# target
# 4    6705
# 5    1113
# 2    1099
# 1     514
# 0     327
# 6     142
# 3     115
# Name: count, dtype: int64

# %% [markdown]
# ## 2.2 聚合算法

# %%
# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk))
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))

def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc


# Federated averaging: FedAvg
def FedAvg(w):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[k] += w[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w))
    return w_avg


def FedAvg_with_grad_clipping(w_locals, clip_value=1):
    w_avg = copy.deepcopy(w_locals[0])
    for k in w_avg.keys():
        for i in range(1, len(w_locals)):
            w_avg[k] += w_locals[i][k]

        w_avg[k] = torch.div(w_avg[k], len(w_locals))

        # 梯度裁剪
        w_avg[k] = torch.clamp(w_avg[k], -clip_value, clip_value)

    return w_avg



def FedMedian(w_locals):
    w_median = {}
    for k in w_locals[0].keys():
        w_median[k] = torch.median(torch.stack([w[k] for w in w_locals]), dim=0).values
    return w_median

def trimmed_and_thresholded_aggregation(weight_diffs, trim_ratio=0.1, threshold=0.01):
    """
    :param weight_diffs: 客户端权重差列表，每个元素是一个客户端的权重差
    :param trim_ratio: 用于权重修剪的比例,例如，当 trim_ratio=0.1 时，表示要剔除权重中绝对值最大的 10%。
    :param threshold: 用于阈值聚合的阈值,表示阈值聚合时的阈值。只有权重差的绝对值小于这个阈值的权重才会被聚合。
    :return:
    """

    # 对权重差进行修剪
    trimmed_weight_diffs = []
    for diff in weight_diffs:
        trimmed_diff = {}
        for key in diff.keys():
            # 然后，对于权重差中的每个键（层），代码将该键对应的权重差提取出来
            layer_diff = diff[key]
            layer_abs_diff = torch.abs(layer_diff)
            sorted_indices = torch.argsort(layer_abs_diff.view(-1), descending=True)
            trim_index = int(len(sorted_indices) * (1 - trim_ratio))
            indices_to_keep = sorted_indices[:trim_index]
            mask = torch.zeros_like(layer_diff, dtype=torch.bool)
            mask.view(-1)[indices_to_keep] = True
            trimmed_layer_diff = torch.where(mask, layer_diff, torch.zeros_like(layer_diff))
            trimmed_diff[key] = trimmed_layer_diff
        trimmed_weight_diffs.append(trimmed_diff)

    # 对修剪后的权重差进行阈值聚合
    # 初始化一个空字典 aggregated_weight_diff，用于存储阈值聚合后的权重差。
    aggregated_weight_diff = {}
    for i, weight_diff in enumerate(trimmed_weight_diffs):
        for k, v in weight_diff.items():
            if i == 0:
                # 对于第一个权重差，将其除以客户端数量并存储在 aggregated_weight_diff 中。
                aggregated_weight_diff[k] = v / float(len(trimmed_weight_diffs))
            else:
                # 对于其他权重差，如果其绝对值小于阈值 threshold，则将其除以客户端数量并累加到 aggregated_weight_diff 对应的键中。
                mask = torch.abs(v) < threshold
                aggregated_weight_diff[k] += torch.where(mask, v / float(len(trimmed_weight_diffs)), torch.zeros_like(v, dtype=torch.float))

    return aggregated_weight_diff




def subtract_weights(w1, w2):
    """
    计算 w1 和 w2 之间的差，即 w1 - w2。

    Args:
        w1 (OrderedDict): 权重字典 1
        w2 (OrderedDict): 权重字典 2

    Returns:
        OrderedDict: w1 和 w2 之间的权重差异
    """
    diff = OrderedDict()
    for key in w1.keys():
        diff[key] = w1[key] - w2[key]
    return diff


def add_weights(w1, w2):
    """
    对 w1 和 w2 进行加法操作，即 w1 + w2。

    Args:
        w1 (OrderedDict): 权重字典 1
        w2 (OrderedDict): 权重字典 2

    Returns:
        OrderedDict: w1 和 w2 相加的结果
    """
    added = OrderedDict()
    for key in w1.keys():
        added[key] = w1[key] + w2[key]
    return added



def remove_anomalies(w_locals, w_glob, threshold):
    # 异常检测
    anomaly_indices = detect_anomaly(w_locals, w_glob, threshold)
    # 删除异常客户端的模型更新
    w_locals = [w for idx, w in enumerate(w_locals) if idx not in anomaly_indices]
    return w_locals


def detect_anomaly(w_locals, w_glob_client,threshold):
    grad_norms = []
    # 计算所有客户端模型更新的梯度范数（与全局模型之间的差异）
    for idx, w in enumerate(w_locals):
        grad_norm = torch.norm(subtract_weights(w, w_glob_client), p=2)
        grad_norms.append(grad_norm.item())

    # 计算梯度范数的标准差和平均值
    std_dev = np.std(grad_norms)
    mean_grad_norm = np.mean(grad_norms)
    # 确定异常客户端（梯度范数大于平均值加减某个阈值倍的标准差）
    anomaly_indices = [idx for idx, norm in enumerate(grad_norms) if abs(norm - mean_grad_norm) > threshold * std_dev]

    return anomaly_indices


def krum_aggregation(weight_dicts, num_to_select):
    # ...（weights_to_array、array_to_weights和pairwise_distances函数保持不变）
    def weights_to_array(weight_dict):
        """
        将权重字典转换为 numpy 数组。
        :param weight_dict: 权重字典，其中每个值都是一个 torch.Tensor 张量。
        :return: 一个 numpy 数组，其中包含了所有权重张量的扁平化数组。
        """
        # 初始化 weight_list 列表，用于存储 weight_dict 中每个权重张量的扁平化数组。
        weight_list = []
        for key in weight_dict:
            # 将权重张量转换为 numpy 数组，并使用 flatten 函数将其扁平化
            weight_list.append(weight_dict[key].cpu().numpy().flatten())
        # 将 weight_list 中的数组连接成一个 numpy 数组，并返回该数组
        return np.concatenate(weight_list)

    def array_to_weights(array, weight_dict_template):
        """
        从 numpy 数组中提取权重张量，并将它们保存到一个新的权重字典中。
        :param array: 包含所有权重张量的扁平化 numpy 数组。
        :param weight_dict_template: 一个权重字典模板，其中包含了所有权重张量的形状。
        :return: 一个新的权重字典，其中包含了从数组中提取的权重张量。
        """
        # 初始化一个新的有序字典 new_weight_dict，用于存储从 numpy 数组中提取的权重张量
        new_weight_dict = OrderedDict()
        # 初始化一个索引变量 idx，用于跟踪从数组中提取权重的位置
        idx = 0
        # 遍历权重字典模板中的每个键 key
        for key in weight_dict_template:
            # 获取权重张量的大小 size
            size = weight_dict_template[key].numel()
            # 从 numpy 数组中提取一个与权重张量相同大小的一维切片，并使用 reshape 函数重新塑形
            # 将 numpy 数组转换为 torch.Tensor 张量，并将其存储到新的有序字典 new_weight_dict 中
            new_weight_dict[key] = torch.from_numpy(array[idx:idx + size].reshape(weight_dict_template[key].shape))
            # 更新索引变量 idx 的值，跳过已经提取的权重张量
            idx += size
        # 返回新的有序字典 new_weight_dict
        return new_weight_dict

    def pairwise_distances(weight_updates):
        # 获取客户端数量
        n_clients = len(weight_updates)
        # 初始化一个距离矩阵，矩阵大小为 n_clients * n_clients
        distances = np.zeros((n_clients, n_clients))

        # 遍历所有的客户端对
        for i in range(n_clients):
            for j in range(i + 1, n_clients):
                # 计算 i 和 j 客户端之间的欧氏距离
                dist = np.linalg.norm(weight_updates[i] - weight_updates[j])
                # 在距离矩阵中记录距离
                distances[i, j] = dist
                distances[j, i] = dist

        # 返回距离矩阵
        return distances

    weight_arrays = [weights_to_array(weight_dict) for weight_dict in weight_dicts]
    n_clients = len(weight_arrays)
    distances = pairwise_distances(weight_arrays)

    krum_scores = []
    for i in range(n_clients):
        sorted_distances = np.sort(distances[i])
        # 计算当前客户端的Krum分数，即距离最大的n_clients - num_to_select - 1个客户端之间的距离总和。
        krum_score = np.sum(sorted_distances[-(n_clients - num_to_select - 1):])
        krum_scores.append(krum_score)

    # 使用np.argpartition函数找到具有最低Krum分数的num_to_select个客户端的索引。
    best_clients_indices = np.argpartition(krum_scores, num_to_select)[:num_to_select]

    # 从权重数组中选择最佳客户端的权重。
    selected_weight_arrays = [weight_arrays[i] for i in best_clients_indices]
    # 计算选定客户端的权重数组的平均值，得到聚合后的权重数组。
    aggregated_weight_array = np.mean(selected_weight_arrays, axis=0)

    # 使用array_to_weights函数将聚合后的权重数组转换回权重字典。
    aggregated_weights = array_to_weights(aggregated_weight_array, weight_dicts[0])

    # 返回聚合后的权重字典和最好的客户端索引列表。
    return aggregated_weights, best_clients_indices

# %% [markdown]
# ## 2.3数据投毒——标签翻转

# %%
def replace_label1_with_label2_on_df(df,label1,label2,poisoned_dict_users):
    """
    标签反转
    :param df:dataframe
    :param label1: 等待翻转的标签
    :param label2: 需要翻转的标签
    :param poisoned_dict_users:包含索引列表的字典,中毒的用户
    :return:
    """
    for idx_list in poisoned_dict_users.values():
        for idx in idx_list:
            if df.loc[idx,'target'] == label1:
                df.loc[idx,'target'] = label2
    # df.loc[df['target'] == label1, 'target'] = label2
    return df

def random_select_poisoning_users(dict_users, n):
    """
    随机选择n个key-value对
    :param dict_users: 字典，key为索引，value为包含索引值的列表
    :param n: 选择的key-value对的数量
    :return: 随机选择的key-value对组成的字典
    """
    selected = {}
    keys = random.sample(list(dict_users.keys()), n)
    for k in keys:
        selected[k] = dict_users[k]
    return selected

# def poison_data(dataset_train, dict_users, poisoned_users_num, original_label, target_label):
#     poisoned_dict_users = random_select_poisoning_users(dict_users, poisoned_users_num)
#     replace_label1_with_label2_on_df(dataset_train.df, original_label, target_label, poisoned_dict_users)
#     return poisoned_dict_users

def print_poisoning_results(poisoned_dict_users, dataset_train):
    for poisoned_user_key in poisoned_dict_users:
        print("被投毒的用户:", poisoned_user_key)

    print("标签反转后的target统计:")
    print(dataset_train.df['target'].value_counts())

def cifar10_to_dataframe(dataset):
    data = [dataset[i] for i in range(len(dataset))]
    images, labels = zip(*data)
    df = pd.DataFrame({"image": images, "target": labels})
    return df



def poison_data(dataset_train, dataset_choice, dict_users, poisoned_users_num, label_mappings):
    if dataset_choice == 'CIFAR10':
        df_train = cifar10_to_dataframe(dataset_train)
    elif dataset_choice == 'HAM10000':
        df_train = dataset_train.df
    else:
        raise ValueError("Invalid dataset choice.")

    poisoned_dict_users = random_select_poisoning_users(dict_users, poisoned_users_num)

    for original_label, target_label in label_mappings:
        replace_label1_with_label2_on_df(df_train, original_label, target_label, poisoned_dict_users)

    # 修改 dataset_train 的标签
    if dataset_choice == 'CIFAR10':
        for idx, row in df_train.iterrows():
            dataset_train.targets[idx] = row['target']

    return poisoned_dict_users

def poison_data_random(dataset_train, dataset_choice, dict_users, poisoned_users_num):
    if dataset_choice == 'CIFAR10':
        df_train = cifar10_to_dataframe(dataset_train)
    elif dataset_choice == 'HAM10000':
        df_train = dataset_train.df
    else:
        raise ValueError("Invalid dataset choice.")

    poisoned_dict_users = random_select_poisoning_users(dict_users, poisoned_users_num)

    for idx_list in poisoned_dict_users.values():
        for idx in idx_list:
            labels = list(set(df_train['target'].unique()) - {df_train.loc[idx, 'target']})
            df_train.loc[idx, 'target'] = random.choice(labels)

    # 修改 dataset_train 的标签
    if dataset_choice == 'CIFAR10':
        for idx, row in df_train.iterrows():
            dataset_train.targets[idx] = row['target']

    return poisoned_dict_users

# %%
# =============================================================================
#                         Poisoning
# =============================================================================
# 定义攻击模式和目标标签
# attack_pattern = np.full((32, 32, 3), 255, dtype=np.uint8)
# target_label = 7

# # 增加投毒用户数量至 10%
# poisoned_frac = 0.3
# poisoned_users_num = int(poisoned_frac * num_users)
# # label_mappings = [(4, 2), (1, 7), (3, 1), (2, 6), (6, 5)]
# # poisoned_dict_users = poison_data(dataset_train, dataset_choice, dict_users, poisoned_users_num, label_mappings)
# poisoned_dict_users = poison_data_random(dataset_train, dataset_choice, dict_users, poisoned_users_num)
# # poisoned_dict_users = poison_data_model(dataset_train, dataset_choice, dict_users, poisoned_users_num, attack_pattern, target_label)

# for poisoned_user_key in poisoned_dict_users:
#     print("被投毒的用户:", poisoned_user_key)

# # 如果使用的是 HAM10000 数据集，您可以直接使用 dataset_train.df 查看标签分布
# if dataset_choice == 'HAM10000':
#     print("标签反转后的target统计:")
#     print(dataset_train.df['target'].value_counts())
# elif dataset_choice == 'CIFAR10':
#     cifar10_df = cifar10_to_dataframe(dataset_train)
#     print("标签反转后的target统计:")
#     print(cifar10_df['target'].value_counts())

# %% [markdown]
# # 3.模型train和test
# ## 3.1 初始化

# %%
# ------------ Training And Testing -----------------
net_glob_client.train()
# copy weights
w_glob_client = net_glob_client.state_dict()

# Federation takes place after certain local epochs in train() client-side
# this epoch is global epoch, also known as rounds

total_time = 0.0  # 初始化总时间为0
best_clients_indices = None
krum_acc_test_collect = []
krum_loss_test_collect = []

# 梯度匹配攻击
# Choose a fraction of clients to be attackers
attackers_frac = 0.5  # Modify this value according to your requirements
num_attackers = int(attackers_frac * num_users)
attackers_indices = np.random.choice(num_users, num_attackers, replace=False)
print("匹配攻击选取的客户端",str(attackers_indices))
# Out:
# 匹配攻击选取的客户端 [17 18 19 16 14  5  9 11  2  0]

# %%
for iter in range(epochs):
    start_time = time.time()  # 记录开始时间
    m = max(int(frac * num_users), 1)
    idxs_users = np.random.choice(range(num_users), m, replace=False)  # ，replace=False表示不允许重复选择。
    w_locals_client = []  # 用于存储每个客户端训练后的本地模型参数。
    loss_avg_test_all_dict = {}
    acc_avg_test_all_dict = {}
    idx_local_client_dict = {}

    for idx in idxs_users:
        is_attacker = idx in attackers_indices if iter == 0 else None
        print("is_attaker",is_attacker)
        local = Client(net_glob_client, idx, lr, device, dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx], is_attacker=is_attacker)
        # Training ------------------
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        idx_local_client_dict[len(w_locals_client)] = idx
        w_locals_client.append(copy.deepcopy(w_client))

        # Testing -------------------
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter, selected_clients=best_clients_indices)

        # Update the dictionaries with the client's self.loss_avg_test_all and self.acc_avg_test_all
        loss_avg_test_all_dict[idx] = local.loss_avg_test_all
        acc_avg_test_all_dict[idx] = local.acc_avg_test_all

    print("idxs_users", idxs_users)
    # Ater serving all clients for its local epochs------------
    # Federation process at Client-Side------------------------
    print("------------------------------------------------------------")
    print("------ Fed Server: Federation process at Client-Side -------")
    print("------------------------------------------------------------")
    # w_locals_client是所有客户端训练后的本地模型参数列表，FedAvg函数是加权平均函数，返回全局模型参数w_glob_client。
    w_glob_client = FedAvg(w_locals_client)
    # 调用 Krum 算法
    # num_to_select = int(num_users * (1 - poisoned_frac - 0.1))  # 选择的客户端数量
    # w_glob_client, best_clients_indices = krum_aggregation(w_locals_client, num_to_select)
    # print([idxs_users[i] for i in best_clients_indices])
    # Update client-side global model
    net_glob_client.load_state_dict(w_glob_client)

    # print("fedserver选择的客户端index:", best_clients_indices)
    # best_clients_idxs = [idx_local_client_dict[i] for i in best_clients_indices]
    # krum_acc_test_collect_user = [acc_avg_test_all_dict[i] for i in best_clients_idxs]
    # for acc in krum_acc_test_collect_user:
    #     print("acc:",acc)
    # krum_loss_test_collect_user = [loss_avg_test_all_dict[i] for i in best_clients_idxs]
    #
    # krum_acc_avg_all_user = sum(krum_acc_test_collect_user) / len(krum_acc_test_collect_user)
    # krum_loss_avg_all_user = sum(krum_loss_test_collect_user) / len(krum_loss_test_collect_user)
    # krum_acc_test_collect.append(krum_acc_avg_all_user)
    # krum_loss_test_collect.append(krum_loss_avg_all_user)

    # print("====================== Fed Server==========================")
    # print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(iter, acc_avg_all_user_train,
    #                                                                           loss_avg_all_user_train))
    # print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(iter, krum_acc_avg_all_user,
    #                                                                          krum_loss_avg_all_user))
    # print("==========================================================")

    end_time = time.time()  # 记录结束时间
    epoch_time = end_time - start_time  # 计算epoch所耗费的时间
    total_time += epoch_time  # 将时间差加到总时间中
    # 将时间差值转换为小时、分钟和秒数
    hours, rem = divmod(epoch_time, 3600)
    minutes, seconds = divmod(rem, 60)
    print(f"Epoch {iter} finished in {int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}")
    print(f"Epoch {iter} finished. Total time: {total_time:.2f} seconds")
# Out:
# is_attaker True
# /tmp/ipykernel_574/424611467.py:87: DeprecationWarning: FLIP_LEFT_RIGHT is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_LEFT_RIGHT instead.
#   modified_img = img.transpose(Image.FLIP_LEFT_RIGHT)  # Flip the image horizontally
#  Client19 Train => Local Epoch: 0 	Acc: 27.344 	Loss: 2.2907
#  Client19 Test =>                   	Acc: 6.000 	Loss: 1.9232
# is_attaker False
#  Client13 Train => Local Epoch: 0 	Acc: 25.391 	Loss: 2.2343
#  Client13 Test =>                   	Acc: 4.000 	Loss: 2.0078
# is_attaker True
#  Client11 Train => Local Epoch: 0 	Acc: 15.625 	Loss: 2.4240
#  Client11 Test =>                   	Acc: 4.000 	Loss: 2.0078
# is_attaker True
#  Client16 Train => Local Epoch: 0 	Acc: 13.477 	Loss: 2.3384
#  Client16 Test =>                   	Acc: 57.000 	Loss: 1.9024
# is_attaker False
#  Client3 Train => Local Epoch: 0 	Acc: 22.266 	Loss: 2.2831
#  Client3 Test =>                   	Acc: 4.000 	Loss: 1.9498
# is_attaker False
#  Client8 Train => Local Epoch: 0 	Acc: 19.922 	Loss: 2.2486
#  Client8 Test =>                   	Acc: 11.000 	Loss: 1.9738
# is_attaker False
#  Client12 Train => Local Epoch: 0 	Acc: 22.461 	Loss: 2.2745
#  Client12 Test =>                   	Acc: 8.000 	Loss: 1.9694
# is_attaker False
#  Client7 Train => Local Epoch: 0 	Acc: 25.391 	Loss: 2.2624
#  Client7 Test =>                   	Acc: 7.000 	Loss: 1.9398
# is_attaker False
#  Client1 Train => Local Epoch: 0 	Acc: 26.367 	Loss: 2.2701
#  Client1 Test =>                   	Acc: 4.000 	Loss: 1.9276
# is_attaker True
#  Client18 Train => Local Epoch: 0 	Acc: 4.688 	Loss: 2.2947
#  Client18 Test =>                   	Acc: 4.000 	Loss: 1.9463
# is_attaker True
#  Client14 Train => Local Epoch: 0 	Acc: 7.227 	Loss: 2.4738
#  Client14 Test =>                   	Acc: 26.000 	Loss: 1.9099
# is_attaker True
#  Client5 Train => Local Epoch: 0 	Acc: 16.016 	Loss: 2.2702
#  Client5 Test =>                   	Acc: 7.000 	Loss: 1.9235
# is_attaker False
#  Client15 Train => Local Epoch: 0 	Acc: 26.562 	Loss: 2.1525
#  Client15 Test =>                   	Acc: 7.000 	Loss: 1.8910
# is_attaker True
#  Client17 Train => Local Epoch: 0 	Acc: 12.891 	Loss: 2.2851
#  Client17 Test =>                   	Acc: 5.000 	Loss: 1.9227
# is_attaker False
#  Client4 Train => Local Epoch: 0 	Acc: 25.000 	Loss: 2.2583
#  Client4 Test =>                   	Acc: 5.000 	Loss: 2.0115
# is_attaker True
#  Client0 Train => Local Epoch: 0 	Acc: 21.289 	Loss: 2.2428
#  Client0 Test =>                   	Acc: 12.000 	Loss: 1.9323
# is_attaker False
#  Client10 Train => Local Epoch: 0 	Acc: 21.680 	Loss: 2.2744
#  Client10 Test =>                   	Acc: 8.000 	Loss: 1.9863
# is_attaker True
#  Client9 Train => Local Epoch: 0 	Acc: 12.891 	Loss: 2.2936
#  Client9 Test =>                   	Acc: 4.000 	Loss: 1.9247
# is_attaker True
#  Client2 Train => Local Epoch: 0 	Acc: 5.469 	Loss: 2.2944
#  Client2 Test =>                   	Acc: 9.000 	Loss: 1.9181
# is_attaker False
#  Client6 Train => Local Epoch: 0 	Acc: 18.750 	Loss: 2.4024
#  Client6 Test =>                   	Acc: 5.000 	Loss: 1.9391
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 18.535 | Avg Loss 2.293
#  Test: Round   0, Avg Accuracy 9.850 | Avg Loss 1.945
# ==========================================================
# idxs_users [19 13 11 16  3  8 12  7  1 18 14  5 15 17  4  0 10  9  2  6]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 0 finished in 00:00:18
# Epoch 0 finished. Total time: 18.62 seconds
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 47.070 	Loss: 1.7785
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.7618
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 58.008 	Loss: 1.4376
#  Client1 Test =>                   	Acc: 61.000 	Loss: 1.7343
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 56.055 	Loss: 1.4299
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.7557
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 53.711 	Loss: 1.4846
#  Client12 Test =>                   	Acc: 35.000 	Loss: 1.8398
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 55.469 	Loss: 1.4196
#  Client13 Test =>                   	Acc: 77.000 	Loss: 1.7744
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 58.984 	Loss: 1.4577
#  Client8 Test =>                   	Acc: 66.000 	Loss: 1.7027
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 52.539 	Loss: 1.7059
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.6518
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 57.227 	Loss: 1.4806
#  Client6 Test =>                   	Acc: 72.000 	Loss: 1.6536
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 53.125 	Loss: 1.6310
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.7151
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 62.109 	Loss: 1.5790
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.5886
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 52.734 	Loss: 1.6232
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.7622
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 52.148 	Loss: 1.5856
#  Client3 Test =>                   	Acc: 74.000 	Loss: 1.7407
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 58.008 	Loss: 1.3707
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.6318
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 46.875 	Loss: 1.6247
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.6110
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 53.906 	Loss: 1.5250
#  Client11 Test =>                   	Acc: 70.000 	Loss: 1.7340
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 61.914 	Loss: 1.3454
#  Client7 Test =>                   	Acc: 67.000 	Loss: 1.7470
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 50.391 	Loss: 1.7378
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.7179
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 55.469 	Loss: 1.4792
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.7489
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 58.398 	Loss: 1.6113
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.7316
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 56.250 	Loss: 1.4677
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.7439
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 55.020 | Avg Loss 1.539
#  Test: Round   1, Avg Accuracy 64.500 | Avg Loss 1.717
# ==========================================================
# idxs_users [16  1 10 12 13  8  2  6 17  5 14  3  4 18 11  7 19 15  9  0]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 1 finished in 00:00:17
# Epoch 1 finished. Total time: 36.48 seconds
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 68.750 	Loss: 1.2084
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.4154
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 61.719 	Loss: 1.2782
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.5205
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 69.531 	Loss: 1.0675
#  Client1 Test =>                   	Acc: 61.000 	Loss: 1.5402
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 59.766 	Loss: 1.2101
#  Client6 Test =>                   	Acc: 72.000 	Loss: 1.3229
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 65.234 	Loss: 1.3505
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.4735
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 60.352 	Loss: 1.1497
#  Client13 Test =>                   	Acc: 75.000 	Loss: 1.4568
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 60.156 	Loss: 1.2640
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.4620
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 60.156 	Loss: 1.3450
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.4980
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 64.258 	Loss: 1.4432
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.4721
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 59.570 	Loss: 1.2488
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.4112
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 65.625 	Loss: 1.2680
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.4324
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 1.1705
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.5563
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 61.719 	Loss: 1.2237
#  Client3 Test =>                   	Acc: 74.000 	Loss: 1.4233
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 65.430 	Loss: 1.3538
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.4816
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 62.109 	Loss: 1.2206
#  Client7 Test =>                   	Acc: 67.000 	Loss: 1.5811
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 1.1106
#  Client8 Test =>                   	Acc: 66.000 	Loss: 1.3801
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.008 	Loss: 1.5412
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.5045
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 1.2806
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.5244
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 1.2720
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.4587
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 60.938 	Loss: 1.2907
#  Client12 Test =>                   	Acc: 63.000 	Loss: 1.4800
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 63.525 | Avg Loss 1.265
#  Test: Round   2, Avg Accuracy 65.850 | Avg Loss 1.470
# ==========================================================
# idxs_users [19 14  1  6  2 13 15  0  5  4 11 10  3 18  7  8 16  9 17 12]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 2 finished in 00:00:18
# Epoch 2 finished. Total time: 55.05 seconds
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 1.1688
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.3668
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 65.820 	Loss: 1.0793
#  Client6 Test =>                   	Acc: 15.000 	Loss: 1.7354
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 63.477 	Loss: 1.0169
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.2685
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 57.227 	Loss: 1.4454
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.2180
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 69.922 	Loss: 0.9455
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.5188
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 1.0296
#  Client3 Test =>                   	Acc: 74.000 	Loss: 1.2298
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 60.547 	Loss: 1.1215
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.3650
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 62.500 	Loss: 1.3045
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.1952
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 63.672 	Loss: 1.2899
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.2440
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 64.258 	Loss: 1.2288
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.1429
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 69.727 	Loss: 1.1609
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.4012
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 1.1464
#  Client13 Test =>                   	Acc: 75.000 	Loss: 1.0029
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 65.039 	Loss: 1.2588
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.3099
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 64.062 	Loss: 1.1000
#  Client7 Test =>                   	Acc: 67.000 	Loss: 1.2646
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.984 	Loss: 1.3900
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.4458
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 65.039 	Loss: 1.1971
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.1175
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 56.445 	Loss: 1.1898
#  Client12 Test =>                   	Acc: 60.000 	Loss: 1.5937
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 0.9972
#  Client8 Test =>                   	Acc: 66.000 	Loss: 1.1860
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 66.992 	Loss: 1.0688
#  Client1 Test =>                   	Acc: 61.000 	Loss: 1.4317
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 71.484 	Loss: 1.0239
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.3365
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 64.551 | Avg Loss 1.158
#  Test: Round   3, Avg Accuracy 62.850 | Avg Loss 1.319
# ==========================================================
# idxs_users [ 0  6  4 18 10  3 15 19 11 17 14 13  2  7 16  5 12  8  1  9]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 3 finished in 00:00:17
# Epoch 3 finished. Total time: 72.85 seconds
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 58.398 	Loss: 1.3967
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.1185
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 71.875 	Loss: 1.0592
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.3177
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 64.453 	Loss: 1.0546
#  Client3 Test =>                   	Acc: 74.000 	Loss: 1.1410
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 64.258 	Loss: 1.0430
#  Client6 Test =>                   	Acc: 63.000 	Loss: 1.1696
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 65.820 	Loss: 1.1114
#  Client7 Test =>                   	Acc: 67.000 	Loss: 1.3047
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 1.1131
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.5334
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 67.969 	Loss: 1.1054
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.2863
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 66.992 	Loss: 1.2080
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.1576
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 69.531 	Loss: 1.0824
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.1067
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.008 	Loss: 1.4274
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.4659
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 62.891 	Loss: 1.1638
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.0979
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 1.0481
#  Client8 Test =>                   	Acc: 66.000 	Loss: 1.1731
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 61.719 	Loss: 1.3265
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.4052
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 62.305 	Loss: 1.0633
#  Client13 Test =>                   	Acc: 75.000 	Loss: 1.0931
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 1.0364
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.1474
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 61.328 	Loss: 1.0918
#  Client12 Test =>                   	Acc: 63.000 	Loss: 1.5458
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 65.039 	Loss: 0.9985
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.2074
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 67.969 	Loss: 0.9265
#  Client1 Test =>                   	Acc: 61.000 	Loss: 1.3606
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 62.305 	Loss: 1.2060
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.2928
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 61.328 	Loss: 1.2830
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.1636
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 64.375 | Avg Loss 1.137
#  Test: Round   4, Avg Accuracy 65.400 | Avg Loss 1.254
# ==========================================================
# idxs_users [18  9  3  6  7 10 17 19 11 16  5  8 14 13 15 12  4  1  0  2]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 4 finished in 00:00:17
# Epoch 4 finished. Total time: 90.74 seconds
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 59.570 	Loss: 1.3863
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.2866
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 59.570 	Loss: 1.2127
#  Client6 Test =>                   	Acc: 35.000 	Loss: 1.4115
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 61.523 	Loss: 1.0691
#  Client13 Test =>                   	Acc: 74.000 	Loss: 1.2429
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 0.9629
#  Client7 Test =>                   	Acc: 65.000 	Loss: 1.2934
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 73.828 	Loss: 0.9818
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.3390
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 1.0295
#  Client3 Test =>                   	Acc: 74.000 	Loss: 1.0331
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 1.1691
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.2111
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 68.750 	Loss: 0.9756
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.4707
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 1.1277
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.0479
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 1.1078
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.3586
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 66.406 	Loss: 0.9821
#  Client1 Test =>                   	Acc: 49.000 	Loss: 1.4537
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 63.281 	Loss: 1.0447
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.4913
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 1.1850
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.1522
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 62.891 	Loss: 1.0364
#  Client12 Test =>                   	Acc: 63.000 	Loss: 1.2345
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 69.922 	Loss: 1.1449
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.0721
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 71.680 	Loss: 1.0386
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.1007
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 65.820 	Loss: 1.2122
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.0718
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 0.9683
#  Client8 Test =>                   	Acc: 64.000 	Loss: 1.2152
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 1.2566
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.3867
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 61.328 	Loss: 1.1360
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.0514
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 65.664 | Avg Loss 1.101
#  Test: Round   5, Avg Accuracy 63.150 | Avg Loss 1.246
# ==========================================================
# idxs_users [16  6 13  7  9  3 18 10 11  0  1  4  2 12  5 17 19  8 14 15]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 5 finished in 00:00:17
# Epoch 5 finished. Total time: 108.48 seconds
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 1.1927
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.0653
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 0.9190
#  Client13 Test =>                   	Acc: 77.000 	Loss: 1.0694
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 62.109 	Loss: 0.9813
#  Client15 Test =>                   	Acc: 52.000 	Loss: 1.2508
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 68.945 	Loss: 1.1191
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.3640
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 64.062 	Loss: 1.1671
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.3797
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 68.750 	Loss: 0.9210
#  Client8 Test =>                   	Acc: 60.000 	Loss: 1.1826
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 66.406 	Loss: 1.1402
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.1483
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 65.039 	Loss: 0.9407
#  Client6 Test =>                   	Acc: 72.000 	Loss: 1.1269
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 0.9826
#  Client12 Test =>                   	Acc: 63.000 	Loss: 1.6873
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 66.797 	Loss: 1.1408
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.3073
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 59.180 	Loss: 1.3546
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.2473
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 0.9206
#  Client7 Test =>                   	Acc: 44.000 	Loss: 1.5780
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 66.797 	Loss: 1.1610
#  Client5 Test =>                   	Acc: 71.000 	Loss: 0.9602
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 1.0986
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.0288
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 1.2383
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.1476
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 64.062 	Loss: 1.0688
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.1326
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 63.281 	Loss: 1.0062
#  Client3 Test =>                   	Acc: 53.000 	Loss: 1.1863
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 62.305 	Loss: 1.2397
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.0539
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 72.070 	Loss: 0.8456
#  Client1 Test =>                   	Acc: 61.000 	Loss: 1.3140
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 0.9229
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.4000
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 66.377 | Avg Loss 1.068
#  Test: Round   6, Avg Accuracy 62.650 | Avg Loss 1.232
# ==========================================================
# idxs_users [17 13 15  9  0  8 11  6 12 14 16  7  5 19  2  4  3 18  1 10]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 6 finished in 00:00:17
# Epoch 6 finished. Total time: 126.33 seconds
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 0.9849
#  Client8 Test =>                   	Acc: 64.000 	Loss: 1.3649
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 58.398 	Loss: 1.2826
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.0222
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 64.258 	Loss: 1.1503
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.3926
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 70.312 	Loss: 1.0024
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.0752
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 65.430 	Loss: 1.1712
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.3738
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 1.0125
#  Client6 Test =>                   	Acc: 72.000 	Loss: 1.0529
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 63.086 	Loss: 0.9783
#  Client7 Test =>                   	Acc: 53.000 	Loss: 1.3172
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 1.1907
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.0557
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 68.945 	Loss: 0.9022
#  Client1 Test =>                   	Acc: 47.000 	Loss: 1.4270
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 65.234 	Loss: 0.9805
#  Client15 Test =>                   	Acc: 44.000 	Loss: 1.3320
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 70.312 	Loss: 0.9224
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.2281
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.398 	Loss: 1.3481
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.2939
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 1.1429
#  Client5 Test =>                   	Acc: 71.000 	Loss: 0.9514
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 68.164 	Loss: 1.1828
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.0830
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 72.656 	Loss: 0.8409
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.6646
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 0.9294
#  Client13 Test =>                   	Acc: 75.000 	Loss: 0.9404
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 1.0727
#  Client19 Test =>                   	Acc: 62.000 	Loss: 1.0545
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 68.555 	Loss: 0.9338
#  Client3 Test =>                   	Acc: 73.000 	Loss: 1.0302
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 71.289 	Loss: 1.0237
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.1304
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 57.812 	Loss: 1.0464
#  Client12 Test =>                   	Acc: 63.000 	Loss: 1.1770
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 66.035 | Avg Loss 1.055
#  Test: Round   7, Avg Accuracy 62.600 | Avg Loss 1.198
# ==========================================================
# idxs_users [ 8 18  0 11 14  6  7 17  1 15  4 16  5  2 10 13 19  3  9 12]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 7 finished in 00:00:17
# Epoch 7 finished. Total time: 144.24 seconds
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 62.305 	Loss: 0.9654
#  Client3 Test =>                   	Acc: 58.000 	Loss: 1.1097
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 66.992 	Loss: 1.1415
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.0529
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 0.9519
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.1581
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 65.820 	Loss: 1.1371
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.0118
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 73.047 	Loss: 0.9593
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.0310
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 64.844 	Loss: 1.1687
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.1696
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 61.133 	Loss: 1.0698
#  Client12 Test =>                   	Acc: 60.000 	Loss: 1.3432
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 1.0673
#  Client9 Test =>                   	Acc: 58.000 	Loss: 1.3238
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 1.1127
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.1354
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 71.094 	Loss: 0.9277
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.4474
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 65.430 	Loss: 0.9173
#  Client7 Test =>                   	Acc: 67.000 	Loss: 1.1736
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 64.062 	Loss: 0.9608
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.3663
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 1.1585
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.6361
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 68.945 	Loss: 0.8460
#  Client8 Test =>                   	Acc: 66.000 	Loss: 1.1332
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 69.922 	Loss: 1.1425
#  Client19 Test =>                   	Acc: 72.000 	Loss: 0.9275
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 60.156 	Loss: 1.3125
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.2715
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 0.8597
#  Client1 Test =>                   	Acc: 42.000 	Loss: 1.7669
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 1.0174
#  Client6 Test =>                   	Acc: 66.000 	Loss: 1.0385
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 1.1217
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.0660
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 68.164 	Loss: 0.9086
#  Client13 Test =>                   	Acc: 75.000 	Loss: 0.8097
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 66.797 | Avg Loss 1.037
#  Test: Round   8, Avg Accuracy 63.550 | Avg Loss 1.199
# ==========================================================
# idxs_users [ 3 17  4  5 11  0 12  9  2 10  7 15 14  8 19 16  1  6 18 13]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 8 finished in 00:00:17
# Epoch 8 finished. Total time: 162.00 seconds
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 66.797 	Loss: 0.9548
#  Client6 Test =>                   	Acc: 68.000 	Loss: 1.0802
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 65.625 	Loss: 0.9174
#  Client1 Test =>                   	Acc: 59.000 	Loss: 1.3332
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 1.0790
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.0486
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 60.156 	Loss: 1.2930
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.2011
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 62.891 	Loss: 1.1330
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.3919
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 65.625 	Loss: 0.9223
#  Client7 Test =>                   	Acc: 52.000 	Loss: 1.3729
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 66.211 	Loss: 1.1169
#  Client19 Test =>                   	Acc: 72.000 	Loss: 0.8709
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 57.812 	Loss: 1.2350
#  Client18 Test =>                   	Acc: 70.000 	Loss: 0.9969
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 63.086 	Loss: 1.0450
#  Client12 Test =>                   	Acc: 50.000 	Loss: 1.2965
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 0.9233
#  Client10 Test =>                   	Acc: 47.000 	Loss: 1.5435
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 1.1663
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.1576
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 68.359 	Loss: 0.9193
#  Client13 Test =>                   	Acc: 70.000 	Loss: 0.9911
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 60.742 	Loss: 1.0729
#  Client3 Test =>                   	Acc: 74.000 	Loss: 0.8753
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 70.703 	Loss: 0.8241
#  Client8 Test =>                   	Acc: 61.000 	Loss: 1.0883
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 66.797 	Loss: 1.1205
#  Client11 Test =>                   	Acc: 71.000 	Loss: 1.0078
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 66.211 	Loss: 1.1191
#  Client2 Test =>                   	Acc: 69.000 	Loss: 1.0089
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 66.406 	Loss: 0.9389
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.0934
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 70.703 	Loss: 1.0308
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.2680
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 0.9298
#  Client4 Test =>                   	Acc: 61.000 	Loss: 1.2267
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 68.359 	Loss: 1.1035
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.3140
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 65.967 | Avg Loss 1.042
#  Test: Round   9, Avg Accuracy 63.250 | Avg Loss 1.158
# ==========================================================
# idxs_users [ 6  1 17 16  0  7 19 18 12 10  5 13  3  8 11  2 15  9  4 14]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 9 finished in 00:00:17
# Epoch 9 finished. Total time: 179.83 seconds
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 0.8952
#  Client1 Test =>                   	Acc: 45.000 	Loss: 1.7562
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 1.2296
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.1443
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 1.1586
#  Client19 Test =>                   	Acc: 72.000 	Loss: 1.0059
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 63.086 	Loss: 0.9119
#  Client3 Test =>                   	Acc: 74.000 	Loss: 0.8139
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 0.9046
#  Client13 Test =>                   	Acc: 75.000 	Loss: 0.8971
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 0.8462
#  Client8 Test =>                   	Acc: 52.000 	Loss: 1.3358
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 68.555 	Loss: 1.0583
#  Client11 Test =>                   	Acc: 71.000 	Loss: 0.9964
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 74.609 	Loss: 0.7925
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.5579
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 68.359 	Loss: 0.9297
#  Client12 Test =>                   	Acc: 65.000 	Loss: 1.2227
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 0.9821
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.4391
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 1.1108
#  Client5 Test =>                   	Acc: 71.000 	Loss: 0.9716
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 71.484 	Loss: 0.9910
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.2557
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 60.742 	Loss: 1.3402
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.3793
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 72.070 	Loss: 1.0193
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.1342
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 66.992 	Loss: 0.8762
#  Client7 Test =>                   	Acc: 67.000 	Loss: 1.1507
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 65.039 	Loss: 1.1897
#  Client18 Test =>                   	Acc: 63.000 	Loss: 1.1806
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 73.047 	Loss: 0.9630
#  Client9 Test =>                   	Acc: 60.000 	Loss: 1.2521
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 62.305 	Loss: 1.1623
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.1357
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 65.625 	Loss: 0.9356
#  Client6 Test =>                   	Acc: 72.000 	Loss: 0.9728
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 0.9230
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.1199
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 67.275 | Avg Loss 1.011
#  Test: Round  10, Avg Accuracy 64.100 | Avg Loss 1.186
# ==========================================================
# idxs_users [ 1  2 19  3 13  8 11 10 12 15  5  0 16 17  7 18  9 14  6  4]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 10 finished in 00:00:17
# Epoch 10 finished. Total time: 197.70 seconds
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 64.453 	Loss: 1.0157
#  Client6 Test =>                   	Acc: 72.000 	Loss: 0.9791
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 55.273 	Loss: 1.3607
#  Client18 Test =>                   	Acc: 70.000 	Loss: 0.9562
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 70.117 	Loss: 0.8157
#  Client8 Test =>                   	Acc: 59.000 	Loss: 1.2142
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 1.1739
#  Client19 Test =>                   	Acc: 72.000 	Loss: 0.8787
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 75.195 	Loss: 0.9713
#  Client9 Test =>                   	Acc: 59.000 	Loss: 1.2396
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 62.695 	Loss: 1.0305
#  Client3 Test =>                   	Acc: 74.000 	Loss: 0.8419
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.008 	Loss: 1.3969
#  Client16 Test =>                   	Acc: 58.000 	Loss: 1.2584
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 1.1269
#  Client17 Test =>                   	Acc: 68.000 	Loss: 0.9794
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 59.375 	Loss: 1.1011
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.0662
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 66.992 	Loss: 0.9130
#  Client1 Test =>                   	Acc: 61.000 	Loss: 1.3859
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 62.500 	Loss: 1.3240
#  Client2 Test =>                   	Acc: 67.000 	Loss: 0.9695
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 68.164 	Loss: 0.8671
#  Client13 Test =>                   	Acc: 72.000 	Loss: 0.8539
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 72.656 	Loss: 0.9984
#  Client11 Test =>                   	Acc: 71.000 	Loss: 0.9433
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 70.703 	Loss: 0.8601
#  Client4 Test =>                   	Acc: 55.000 	Loss: 1.2043
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 64.062 	Loss: 1.1610
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.0747
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 64.258 	Loss: 0.9331
#  Client12 Test =>                   	Acc: 64.000 	Loss: 1.3023
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 1.1497
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.4504
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 69.922 	Loss: 0.9020
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.6446
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 67.969 	Loss: 0.9039
#  Client7 Test =>                   	Acc: 66.000 	Loss: 1.0719
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 62.500 	Loss: 1.1281
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.1935
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  11, Avg Accuracy 65.928 | Avg Loss 1.057
#  Test: Round  11, Avg Accuracy 64.800 | Avg Loss 1.125
# ==========================================================
# idxs_users [ 6 18  8 19  9  3 16 17 15  1  2 13 11  4  5 12 14 10  7  0]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 11 finished in 00:00:17
# Epoch 11 finished. Total time: 215.42 seconds
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 0.8889
#  Client15 Test =>                   	Acc: 65.000 	Loss: 1.1446
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 69.727 	Loss: 0.9271
#  Client1 Test =>                   	Acc: 45.000 	Loss: 1.6934
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 1.0702
#  Client5 Test =>                   	Acc: 71.000 	Loss: 1.0408
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 62.695 	Loss: 0.9066
#  Client8 Test =>                   	Acc: 61.000 	Loss: 1.1625
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 65.430 	Loss: 1.1378
#  Client19 Test =>                   	Acc: 69.000 	Loss: 1.1191
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 0.8628
#  Client3 Test =>                   	Acc: 77.000 	Loss: 0.8527
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 71.289 	Loss: 1.0001
#  Client11 Test =>                   	Acc: 71.000 	Loss: 0.9263
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 1.1747
#  Client0 Test =>                   	Acc: 60.000 	Loss: 1.3559
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 0.8993
#  Client7 Test =>                   	Acc: 59.000 	Loss: 1.1342
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 57.031 	Loss: 1.3011
#  Client16 Test =>                   	Acc: 42.000 	Loss: 1.6723
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 58.984 	Loss: 1.0638
#  Client12 Test =>                   	Acc: 63.000 	Loss: 1.4823
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 61.133 	Loss: 1.1338
#  Client6 Test =>                   	Acc: 72.000 	Loss: 0.9598
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 68.750 	Loss: 1.1507
#  Client9 Test =>                   	Acc: 55.000 	Loss: 1.4494
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 61.133 	Loss: 0.9984
#  Client13 Test =>                   	Acc: 75.000 	Loss: 0.9206
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 65.820 	Loss: 0.9093
#  Client4 Test =>                   	Acc: 65.000 	Loss: 1.3145
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 72.070 	Loss: 1.0210
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.0940
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 63.672 	Loss: 1.1585
#  Client18 Test =>                   	Acc: 70.000 	Loss: 0.9552
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 1.1127
#  Client2 Test =>                   	Acc: 67.000 	Loss: 1.1324
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 1.0947
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.2705
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 1.0400
#  Client10 Test =>                   	Acc: 53.000 	Loss: 1.4559
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  12, Avg Accuracy 65.947 | Avg Loss 1.043
#  Test: Round  12, Avg Accuracy 63.200 | Avg Loss 1.207
# ==========================================================
# idxs_users [15  1  5  8 19  3 11  0  7 16 12  6  9 13  4 17 18  2 14 10]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 12 finished in 00:00:17
# Epoch 12 finished. Total time: 233.29 seconds
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 64.844 	Loss: 1.1813
#  Client18 Test =>                   	Acc: 70.000 	Loss: 1.0071
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 61.133 	Loss: 0.9833
#  Client3 Test =>                   	Acc: 67.000 	Loss: 0.8671
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 62.695 	Loss: 0.9092
#  Client15 Test =>                   	Acc: 68.000 	Loss: 1.1185
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 61.914 	Loss: 1.2617
#  Client14 Test =>                   	Acc: 56.000 	Loss: 1.2394
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 0.9584
#  Client8 Test =>                   	Acc: 56.000 	Loss: 1.1653
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 66.602 	Loss: 1.2106
#  Client2 Test =>                   	Acc: 60.000 	Loss: 1.1872
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 70.508 	Loss: 1.0815
#  Client17 Test =>                   	Acc: 68.000 	Loss: 1.0698
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 69.922 	Loss: 1.0345
#  Client11 Test =>                   	Acc: 71.000 	Loss: 0.9730
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 1.1356
#  Client5 Test =>                   	Acc: 71.000 	Loss: 0.9580
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 68.555 	Loss: 0.8536
#  Client10 Test =>                   	Acc: 41.000 	Loss: 1.8672
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 0.9555
#  Client6 Test =>                   	Acc: 61.000 	Loss: 1.2287
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 71.875 	Loss: 0.8103
#  Client1 Test =>                   	Acc: 56.000 	Loss: 1.2574
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 71.484 	Loss: 0.7933
#  Client7 Test =>                   	Acc: 66.000 	Loss: 1.1877
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 67.383 	Loss: 1.0566
#  Client19 Test =>                   	Acc: 68.000 	Loss: 1.0770
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 65.625 	Loss: 0.9381
#  Client12 Test =>                   	Acc: 62.000 	Loss: 1.1640
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 70.312 	Loss: 1.0444
#  Client9 Test =>                   	Acc: 61.000 	Loss: 1.0525
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 62.695 	Loss: 1.0156
#  Client4 Test =>                   	Acc: 64.000 	Loss: 1.0179
# is_attaker None
# ...
#  Client8 Test =>                   	Acc: 65.000 	Loss: 1.0314
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 78.711 	Loss: 0.6052
#  Client4 Test =>                   	Acc: 66.000 	Loss: 0.9613
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 68.555 	Loss: 0.9674
#  Client0 Test =>                   	Acc: 61.000 	Loss: 1.1179
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 1.0185
#  Client14 Test =>                   	Acc: 61.000 	Loss: 1.6648
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.594 	Loss: 1.1925
#  Client16 Test =>                   	Acc: 61.000 	Loss: 1.0581
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 75.977 	Loss: 0.6670
#  Client6 Test =>                   	Acc: 73.000 	Loss: 0.9966
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 0.8157
#  Client12 Test =>                   	Acc: 68.000 	Loss: 0.8567
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 0.9412
#  Client19 Test =>                   	Acc: 72.000 	Loss: 0.8453
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 76.367 	Loss: 0.6694
#  Client1 Test =>                   	Acc: 66.000 	Loss: 1.1536
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 1.0087
#  Client18 Test =>                   	Acc: 73.000 	Loss: 0.8288
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 78.516 	Loss: 0.5284
#  Client7 Test =>                   	Acc: 64.000 	Loss: 0.9834
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 71.875 	Loss: 0.9398
#  Client17 Test =>                   	Acc: 70.000 	Loss: 1.0730
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 61.719 	Loss: 1.2373
#  Client5 Test =>                   	Acc: 72.000 	Loss: 0.7774
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 76.367 	Loss: 0.6530
#  Client15 Test =>                   	Acc: 72.000 	Loss: 0.7616
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 65.039 	Loss: 1.0386
#  Client11 Test =>                   	Acc: 72.000 	Loss: 1.0255
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 73.633 	Loss: 0.7497
#  Client3 Test =>                   	Acc: 74.000 	Loss: 0.6748
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 78.320 	Loss: 0.6221
#  Client10 Test =>                   	Acc: 58.000 	Loss: 1.2023
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 76.562 	Loss: 0.8939
#  Client9 Test =>                   	Acc: 57.000 	Loss: 0.9904
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 66.797 	Loss: 1.0789
#  Client2 Test =>                   	Acc: 65.000 	Loss: 1.1341
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 77.344 	Loss: 0.6783
#  Client13 Test =>                   	Acc: 76.000 	Loss: 0.6625
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  91, Avg Accuracy 71.689 | Avg Loss 0.841
#  Test: Round  91, Avg Accuracy 67.300 | Avg Loss 0.990
# ==========================================================
# idxs_users [ 8  4  0 14 16  6 12 19  1 18  7 17  5 15 11  3 10  9  2 13]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 91 finished in 00:00:17
# Epoch 91 finished. Total time: 1663.54 seconds
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 71.484 	Loss: 0.9682
#  Client0 Test =>                   	Acc: 63.000 	Loss: 1.0308
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 64.844 	Loss: 1.0855
#  Client2 Test =>                   	Acc: 70.000 	Loss: 1.0940
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 64.648 	Loss: 1.0938
#  Client16 Test =>                   	Acc: 60.000 	Loss: 1.4578
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 82.031 	Loss: 0.5072
#  Client8 Test =>                   	Acc: 67.000 	Loss: 1.0342
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 67.969 	Loss: 0.7195
#  Client3 Test =>                   	Acc: 77.000 	Loss: 0.6369
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 71.680 	Loss: 1.0103
#  Client9 Test =>                   	Acc: 57.000 	Loss: 1.3528
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 74.023 	Loss: 0.6763
#  Client6 Test =>                   	Acc: 62.000 	Loss: 1.1670
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 1.0700
#  Client14 Test =>                   	Acc: 64.000 	Loss: 1.3501
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 78.320 	Loss: 0.6087
#  Client13 Test =>                   	Acc: 73.000 	Loss: 0.8438
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 68.359 	Loss: 0.9321
#  Client11 Test =>                   	Acc: 71.000 	Loss: 0.9863
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 75.391 	Loss: 0.8777
#  Client19 Test =>                   	Acc: 70.000 	Loss: 0.9110
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 73.828 	Loss: 0.7400
#  Client1 Test =>                   	Acc: 64.000 	Loss: 1.0916
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 1.0532
#  Client5 Test =>                   	Acc: 69.000 	Loss: 0.9059
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 75.195 	Loss: 0.6532
#  Client10 Test =>                   	Acc: 61.000 	Loss: 1.1171
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 63.867 	Loss: 1.0916
#  Client18 Test =>                   	Acc: 72.000 	Loss: 0.7696
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 75.586 	Loss: 0.6453
#  Client4 Test =>                   	Acc: 66.000 	Loss: 0.9332
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 73.242 	Loss: 0.6707
#  Client7 Test =>                   	Acc: 69.000 	Loss: 0.8600
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 74.219 	Loss: 0.6406
#  Client15 Test =>                   	Acc: 70.000 	Loss: 0.8084
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 77.344 	Loss: 0.7754
#  Client12 Test =>                   	Acc: 69.000 	Loss: 1.1262
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 73.047 	Loss: 0.8643
#  Client17 Test =>                   	Acc: 72.000 	Loss: 0.8176
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  92, Avg Accuracy 71.855 | Avg Loss 0.834
#  Test: Round  92, Avg Accuracy 67.300 | Avg Loss 1.015
# ==========================================================
# idxs_users [ 0  2 16  8  3  9  6 14 13 11 19  1  5 10 18  4  7 15 12 17]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 92 finished in 00:00:17
# Epoch 92 finished. Total time: 1681.39 seconds
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 57.422 	Loss: 1.2660
#  Client18 Test =>                   	Acc: 75.000 	Loss: 0.8265
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 0.9712
#  Client14 Test =>                   	Acc: 55.000 	Loss: 1.5712
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 71.094 	Loss: 0.9960
#  Client2 Test =>                   	Acc: 67.000 	Loss: 0.9058
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 72.461 	Loss: 0.6990
#  Client4 Test =>                   	Acc: 62.000 	Loss: 1.0829
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 68.555 	Loss: 1.0957
#  Client5 Test =>                   	Acc: 71.000 	Loss: 0.8571
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 77.930 	Loss: 0.5756
#  Client8 Test =>                   	Acc: 68.000 	Loss: 0.9821
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 72.461 	Loss: 0.6792
#  Client7 Test =>                   	Acc: 65.000 	Loss: 1.0542
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 0.9969
#  Client11 Test =>                   	Acc: 74.000 	Loss: 0.8728
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 74.219 	Loss: 0.6674
#  Client15 Test =>                   	Acc: 64.000 	Loss: 0.8257
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 80.469 	Loss: 0.5911
#  Client1 Test =>                   	Acc: 62.000 	Loss: 1.0551
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 80.078 	Loss: 0.5518
#  Client10 Test =>                   	Acc: 54.000 	Loss: 1.4760
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 75.781 	Loss: 0.6445
#  Client3 Test =>                   	Acc: 70.000 	Loss: 0.9930
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 79.102 	Loss: 0.6669
#  Client13 Test =>                   	Acc: 77.000 	Loss: 0.8741
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 70.898 	Loss: 0.9131
#  Client0 Test =>                   	Acc: 64.000 	Loss: 1.1454
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 70.312 	Loss: 0.9098
#  Client9 Test =>                   	Acc: 66.000 	Loss: 0.9776
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 75.586 	Loss: 0.7353
#  Client6 Test =>                   	Acc: 71.000 	Loss: 1.0456
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 69.922 	Loss: 0.7700
#  Client12 Test =>                   	Acc: 66.000 	Loss: 1.0928
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 69.336 	Loss: 0.9588
#  Client19 Test =>                   	Acc: 74.000 	Loss: 0.9322
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 58.594 	Loss: 1.1849
#  Client16 Test =>                   	Acc: 60.000 	Loss: 1.3305
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 67.188 	Loss: 1.0515
#  Client17 Test =>                   	Acc: 73.000 	Loss: 0.8425
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  93, Avg Accuracy 71.494 | Avg Loss 0.846
#  Test: Round  93, Avg Accuracy 66.900 | Avg Loss 1.037
# ==========================================================
# idxs_users [18 14  2  4  5  8  7 11 15  1 10  3 13  0  9  6 12 19 16 17]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 93 finished in 00:00:17
# Epoch 93 finished. Total time: 1699.10 seconds
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 70.117 	Loss: 0.8594
#  Client13 Test =>                   	Acc: 65.000 	Loss: 0.8713
# is_attaker None
#  Client4 Train => Local Epoch: 0 	Acc: 80.859 	Loss: 0.6027
#  Client4 Test =>                   	Acc: 69.000 	Loss: 0.8178
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 72.266 	Loss: 0.7473
#  Client12 Test =>                   	Acc: 68.000 	Loss: 0.9796
# is_attaker None
#  Client17 Train => Local Epoch: 0 	Acc: 74.609 	Loss: 0.8668
#  Client17 Test =>                   	Acc: 69.000 	Loss: 0.9920
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 67.773 	Loss: 0.9275
#  Client14 Test =>                   	Acc: 50.000 	Loss: 1.8802
# is_attaker None
#  Client2 Train => Local Epoch: 0 	Acc: 73.438 	Loss: 0.9380
#  Client2 Test =>                   	Acc: 70.000 	Loss: 0.9313
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 63.477 	Loss: 1.0738
#  Client18 Test =>                   	Acc: 73.000 	Loss: 0.8880
# is_attaker None
#  Client3 Train => Local Epoch: 0 	Acc: 75.000 	Loss: 0.6566
#  Client3 Test =>                   	Acc: 73.000 	Loss: 0.8051
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 79.688 	Loss: 0.5486
#  Client8 Test =>                   	Acc: 70.000 	Loss: 1.0131
# is_attaker None
#  Client1 Train => Local Epoch: 0 	Acc: 75.977 	Loss: 0.6206
#  Client1 Test =>                   	Acc: 62.000 	Loss: 1.1763
# is_attaker None
#  Client7 Train => Local Epoch: 0 	Acc: 82.812 	Loss: 0.5175
#  Client7 Test =>                   	Acc: 71.000 	Loss: 0.9374
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 74.414 	Loss: 0.8457
#  Client11 Test =>                   	Acc: 76.000 	Loss: 0.7947
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 68.945 	Loss: 0.9425
#  Client0 Test =>                   	Acc: 66.000 	Loss: 1.1228
# is_attaker None
#  Client10 Train => Local Epoch: 0 	Acc: 73.828 	Loss: 0.6673
#  Client10 Test =>                   	Acc: 40.000 	Loss: 1.8308
# is_attaker None
#  Client16 Train => Local Epoch: 0 	Acc: 62.891 	Loss: 1.1442
#  Client16 Test =>                   	Acc: 59.000 	Loss: 1.0673
# is_attaker None
#  Client9 Train => Local Epoch: 0 	Acc: 71.094 	Loss: 0.9701
#  Client9 Test =>                   	Acc: 66.000 	Loss: 1.0558
# is_attaker None
#  Client15 Train => Local Epoch: 0 	Acc: 76.562 	Loss: 0.6552
#  Client15 Test =>                   	Acc: 71.000 	Loss: 0.8152
# is_attaker None
#  Client19 Train => Local Epoch: 0 	Acc: 67.578 	Loss: 1.0122
#  Client19 Test =>                   	Acc: 70.000 	Loss: 0.9974
# is_attaker None
#  Client5 Train => Local Epoch: 0 	Acc: 62.500 	Loss: 1.1207
#  Client5 Test =>                   	Acc: 72.000 	Loss: 1.4413
# is_attaker None
#  Client6 Train => Local Epoch: 0 	Acc: 72.656 	Loss: 0.6991
#  Client6 Test =>                   	Acc: 71.000 	Loss: 0.8442
# ------------------------------------------------
# ------ Federation process at Server-Side -------
# ------------------------------------------------
# ====================== SERVER V1==========================
#  Train: Round  94, Avg Accuracy 72.324 | Avg Loss 0.821
#  Test: Round  94, Avg Accuracy 66.550 | Avg Loss 1.063
# ==========================================================
# idxs_users [13  4 12 17 14  2 18  3  8  1  7 11  0 10 16  9 15 19  5  6]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 94 finished in 00:00:18
# Epoch 94 finished. Total time: 1717.34 seconds
# is_attaker None
#  Client11 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 0.9441
#  Client11 Test =>                   	Acc: 72.000 	Loss: 0.7912
# is_attaker None
#  Client12 Train => Local Epoch: 0 	Acc: 71.094 	Loss: 0.7280
#  Client12 Test =>                   	Acc: 76.000 	Loss: 0.7781
# is_attaker None
#  Client0 Train => Local Epoch: 0 	Acc: 66.992 	Loss: 1.0049
#  Client0 Test =>                   	Acc: 62.000 	Loss: 1.3254
# is_attaker None
#  Client14 Train => Local Epoch: 0 	Acc: 70.312 	Loss: 0.8835
#  Client14 Test =>                   	Acc: 53.000 	Loss: 1.4541
# is_attaker None
#  Client13 Train => Local Epoch: 0 	Acc: 78.125 	Loss: 0.6660
#  Client13 Test =>                   	Acc: 68.000 	Loss: 0.9651
# is_attaker None
#  Client18 Train => Local Epoch: 0 	Acc: 61.328 	Loss: 1.0958
#  Client18 Test =>                   	Acc: 71.000 	Loss: 0.9054
# is_attaker None
#  Client8 Train => Local Epoch: 0 	Acc: 82.422 	Loss: 0.5491
#  Client8 Test =>                   	Acc: 62.000 	Loss: 1.1193
# is_attaker None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 16
#      13 local = Client(net_glob_client, idx, lr, device, dataset_train=dataset_train, dataset_test=dataset_test,
#      14                idxs=dict_users[idx], idxs_test=dict_users_test[idx], is_attacker=is_attacker)
#      15 # Training ------------------
# ---> 16 w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
#      17 idx_local_client_dict[len(w_locals_client)] = idx
#      18 w_locals_client.append(copy.deepcopy(w_client))
#
# Cell In[21], line 278, in Client.train(self, net)
#     275 len_batch = len(self.ldr_train)  # 计算该客户端的训练集数据分成的批次数。
#     276 for batch_idx, (images, labels) in enumerate(self.ldr_train):
#     277     # 内层循环是数据加载器self.ldr_train中每个批次的训练。在每个批次中，将图像和标签加载到设备上，然后将优化器的梯度清零。
# --> 278     images, labels = images.to(self.device), labels.to(self.device)
#     279     optimizer_client.zero_grad()
#     280     # ---------forward prop-------------
#
# KeyboardInterrupt:

# %%
print("Training and Evaluation completed!")

# ===============================================================================
# Save output data to .excel file (we use for comparision plots)
round_process = [i for i in range(1, len(acc_train_collect) + 1)]
df = DataFrame({'round': round_process, 'acc_train': acc_train_collect, 'acc_test': acc_test_collect,
                'loss_train': loss_train_collect, 'loss_test': loss_test_collect})
file_name = program + "_change_picture_" + str(attackers_frac) + "_" + dataset_choice + ".xlsx"
df.to_excel(file_name, sheet_name="v1_test", index=False)

# %%
acc_train_collect

# %%
import pandas as pd

# 创建一个名为df的DataFrame
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'country': ['USA', 'Canada', 'Australia']
})
