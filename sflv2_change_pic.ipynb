# %% [markdown]
# # 一、预处理
#
# 导入相关函数

# %%
import time

# We have three versions of our implementations
# Version1: without using socket and no DP+PixelDP
# Version2: with using socket but no DP+PixelDP
# Version3: without using socket but with DP+PixelDP

# This program is Version1: Single program simulation
# ============================================================================
import torch
from torch import nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import math
import os.path
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image
from glob import glob
from pandas import DataFrame
from collections import OrderedDict


import torchvision.datasets as datasets
import random
import numpy as np
import os
from torchvision.datasets import ImageFolder

import matplotlib

pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import copy

SEED = 1234

def init_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    if torch.cuda.is_available():
        torch.backends.cudnn.deterministic = True
        print(torch.cuda.get_device_name(0))
init_seeds(SEED)
# Out:
# Tesla P100-PCIE-16GB

# %% [markdown]
# ## 1.1模型定义

# %%
def conv3x3(in_planes, out_planes, stride=1):
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)

class ResNet18_client_side(nn.Module):
    def __init__(self, block, num_blocks):
        super(ResNet18_client_side, self).__init__()
        self.in_planes = 64
        self.conv1 = conv3x3(3, 64)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        return out


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = conv3x3(in_planes, planes, stride)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = conv3x3(planes, planes)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet18_server_side(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10, pool_size=4):  # Add a new argument pool_size
        super(ResNet18_server_side, self).__init__()
        self.in_planes = 64
        self.pool_size = pool_size  # Add this line to store pool_size
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.layer2(x)
        out = self.layer3(out)
        out = self.layer4(out)
        # print("Output shape before pooling:", out.shape)
        out = F.avg_pool2d(out, kernel_size=self.pool_size)  # Use self.pool_size instead of 8
        # print("Output shape after pooling:", out.shape)
        out = out.view(out.size(0), -1)
        y_hat = self.linear(out)
        return y_hat

# %% [markdown]
# ## 1.2 模型初始化

# %%
import logging

def init_logging(program_name):
    logging.basicConfig(filename=f'{program_name}.log', level=logging.INFO)
    logging.getLogger().addHandler(logging.StreamHandler())
    
# ===================================================================
program = "SFLV2_ResNet18_base"
print(f"---------{program}----------")  # this is to identify the program in the slurm outputs files
init_logging(program)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ===================================================================
# No. of users
num_users = 20
epochs = 100
frac = 1  # participation of clients; if 1 then 100% clients participate in SFLV2
lr = 0.0001

# net_glob_client = ResNet18_client_side()
net_glob_client = ResNet18_client_side(BasicBlock, [2, 2, 2, 2]).to(device)
if torch.cuda.device_count() > 1:
    print("We use", torch.cuda.device_count(), "GPUs")
    net_glob_client = nn.DataParallel(
        net_glob_client)  # to use the multiple GPUs; later we can change this to CPUs only

net_glob_client.to(device)
print(net_glob_client)
# Out:
# ---------SFLV2_ResNet18_base----------
# ResNet18_client_side(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )

# %% [markdown]
# ## 1.3 Server Side Model 服务器端模型

# %%
# =====================================================================================================
#                           Server-side Model definition
# =====================================================================================================
# Model at server side
# Choose dataset: 'HAM10000' or 'CIFAR10'
dataset_choice = 'CIFAR10'
# Model at server side
if dataset_choice == 'HAM10000':
    num_classes = 7
    pool_size = 8
elif dataset_choice == 'CIFAR10':
    num_classes = 10
    pool_size = 4
else:
    raise ValueError('Invalid dataset choice.')

net_glob_server = ResNet18_server_side(BasicBlock, [2, 2, 2, 2], num_classes=num_classes, pool_size=pool_size)
# net_glob_server = ResNet18_server_side(Baseblock, [2,2,2], 7) #7 is my numbr of classes
if torch.cuda.device_count() > 1:
    print("We use", torch.cuda.device_count(), "GPUs")
    net_glob_server = nn.DataParallel(net_glob_server)  # to use the multiple GPUs

net_glob_server.to(device)
print(net_glob_server)
# Out:
# ResNet18_server_side(
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ## 1.4 变量初始化

# %%
# ===================================================================================
# For Server Side Loss and Accuracy
loss_train_collect = []
acc_train_collect = []
loss_test_collect = []
acc_test_collect = []
batch_acc_train = []
batch_loss_train = []
batch_acc_test = []
batch_loss_test = []

criterion = nn.CrossEntropyLoss()
count1 = 0
count2 = 0

# ====================================================================================================
#                                  Server Side Programs
# ====================================================================================================
# Federated averaging: FedAvg
# to print train - test together in each round-- these are made global
acc_avg_all_user_train = 0
loss_avg_all_user_train = 0
loss_train_collect_user = []
acc_train_collect_user = []
loss_test_collect_user = []
acc_test_collect_user = []

# client idx collector
idx_collect = []
l_epoch_check = False
fed_check = False

# %% [markdown]
# ## 1.5 Server端训练定义

# %%
# Server-side function associated with Training
def train_server(fx_client, y, l_epoch_count, l_epoch, idx, len_batch):
    """

    :param fx_client:客户端计算得到的特征值
    :param y:对应的标签
    :param l_epoch_count:本地训练周期计数
    :param l_epoch:本地训练周期总数
    :param idx:
    :param len_batch:
    :return:
    """
    global net_glob_server, criterion, device, batch_acc_train, batch_loss_train, l_epoch_check, fed_check
    global loss_train_collect, acc_train_collect, count1, acc_avg_all_user_train, loss_avg_all_user_train, idx_collect
    global loss_train_collect_user, acc_train_collect_user, lr

    net_glob_server.train()
    optimizer_server = torch.optim.Adam(net_glob_server.parameters(), lr=lr)

    # train and update
    optimizer_server.zero_grad()

    fx_client = fx_client.to(device)
    y = y.to(device)

    # ---------forward prop-------------
    # 将fx_client输入到服务器端模型net_glob_server，计算得到预测值fx_server
    fx_server = net_glob_server(fx_client)

    # calculate loss
    loss = criterion(fx_server, y)
    # calculate accuracy
    acc = calculate_accuracy(fx_server, y)

    # --------backward prop--------------
    loss.backward()
    # 将fx_client的梯度保存为dfx_client。
    dfx_client = fx_client.grad.clone().detach()
    optimizer_server.step()

    batch_loss_train.append(loss.item())
    batch_acc_train.append(acc.item())

    # server-side model net_glob_server is global so it is updated automatically in each pass to this function

    # count1: to track the completion of the local batch associated with one client
    count1 += 1  # 增加计数器count1，用于追踪与一个客户端关联的本地批次的完成情况。
    if count1 == len_batch:
        # 如果count1等于len_batch，则计算批次的平均损失和准确度，并将它们分别存储在acc_avg_train和loss_avg_train中。然后清空
        acc_avg_train = sum(batch_acc_train) / len(batch_acc_train)  # it has accuracy for one batch
        loss_avg_train = sum(batch_loss_train) / len(batch_loss_train)

        batch_acc_train = []
        batch_loss_train = []
        count1 = 0

        prRed('Client{} Train => Local Epoch: {} \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, l_epoch_count, acc_avg_train,
                                                                                      loss_avg_train))

        # If one local epoch is completed, after this a new client will come
        if l_epoch_count == l_epoch - 1:

            l_epoch_check = True  # to evaluate_server function - to check local epoch has completed or not

            # we store the last accuracy in the last batch of the epoch and it is not the average of all local epochs
            # this is because we work on the last trained model and its accuracy (not earlier cases)

            # print("accuracy = ", acc_avg_train)
            acc_avg_train_all = acc_avg_train
            loss_avg_train_all = loss_avg_train

            # accumulate accuracy and loss for each new user
            loss_train_collect_user.append(loss_avg_train_all)
            acc_train_collect_user.append(acc_avg_train_all)

            # collect the id of each new user
            if idx not in idx_collect:
                idx_collect.append(idx)
                # print(idx_collect)

        # This is to check if all users are served for one round --------------------
        if len(idx_collect) == num_users * frac:
            fed_check = True  # to evaluate_server function  - to check fed check has hitted
            # all users served for one round ------------------------- output print and update is done in evaluate_server()
            # for nicer display

            idx_collect = []

            acc_avg_all_user_train = sum(acc_train_collect_user) / len(acc_train_collect_user)
            loss_avg_all_user_train = sum(loss_train_collect_user) / len(loss_train_collect_user)

            loss_train_collect.append(loss_avg_all_user_train)
            acc_train_collect.append(acc_avg_all_user_train)

            acc_train_collect_user = []
            loss_train_collect_user = []

    # send gradients to the client
    return dfx_client


# Server-side functions associated with Testing
def evaluate_server(fx_client, y, idx, len_batch, ell, selected_clients):
    global net_glob_server, criterion, batch_acc_test, batch_loss_test
    global loss_test_collect, acc_test_collect, count2, num_users, acc_avg_train_all, loss_avg_train_all, l_epoch_check, fed_check
    global loss_test_collect_user, acc_test_collect_user, acc_avg_all_user_train, loss_avg_all_user_train

    net_glob_server.eval()
    return_local_results = False

    with torch.no_grad():
        fx_client = fx_client.to(device)
        y = y.to(device)
        # ---------forward prop-------------
        fx_server = net_glob_server(fx_client)

        # calculate loss
        loss = criterion(fx_server, y)
        # calculate accuracy
        acc = calculate_accuracy(fx_server, y)

        batch_loss_test.append(loss.item())
        batch_acc_test.append(acc.item())

        # 计数器 count2 用于跟踪处理的客户端数量。如果已经处理了一个批次的客户端数据，那么计算批次的平均损失和平均准确度，然后重置批次损失和批次准确度列表以及计数器。
        count2 += 1
        if count2 == len_batch:
            acc_avg_test = sum(batch_acc_test) / len(batch_acc_test)
            loss_avg_test = sum(batch_loss_test) / len(batch_loss_test)

            batch_acc_test = []
            batch_loss_test = []
            count2 = 0

            prGreen('Client{} Test =>                   \tAcc: {:.3f} \tLoss: {:.4f}'.format(idx, acc_avg_test,
                                                                                             loss_avg_test))

            # if a local epoch is completed
            if l_epoch_check:
                l_epoch_check = False
                return_local_results = True

                # Store the last accuracy and loss
                acc_avg_test_all = acc_avg_test
                loss_avg_test_all = loss_avg_test

                loss_test_collect_user.append(loss_avg_test_all)
                acc_test_collect_user.append(acc_avg_test_all)

            # if all users are served for one round ----------
            if fed_check:
                fed_check = False



                # 计算Krum选定客户端的平均准确率和损失
                if selected_clients is None or len(selected_clients) == 0:
                    acc_avg_all_user = sum(acc_test_collect_user) / len(acc_test_collect_user)
                    loss_avg_all_user = sum(loss_test_collect_user) / len(loss_test_collect_user)
                else:
                    print("选择的客户端index:",selected_clients)
                    acc_test_collect_user = [acc_test_collect_user[i] for i in selected_clients]
                    loss_test_collect_user = [loss_test_collect_user[i] for i in selected_clients]

                    acc_avg_all_user = sum(acc_test_collect_user) / len(acc_test_collect_user)
                    loss_avg_all_user = sum(loss_test_collect_user) / len(loss_test_collect_user)


                loss_test_collect.append(loss_avg_all_user)
                acc_test_collect.append(acc_avg_all_user)
                acc_test_collect_user = []
                loss_test_collect_user = []

                print("====================== SERVER V1==========================")
                print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user_train,
                                                                                          loss_avg_all_user_train))
                print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(ell, acc_avg_all_user,
                                                                                         loss_avg_all_user))
                print("==========================================================")

    if return_local_results:
        return acc_avg_test_all,loss_avg_test_all
    else:
        return None,None

# %% [markdown]
# ## 1.6 Client端类定义

# %%
class Client(object):
    def __init__(self, net_client_model, idx, lr, device, dataset_train=None, dataset_test=None, idxs=None,
                 idxs_test=None):
        """
        :param idxs: idxs是一个表示该客户端用于训练的数据集的索引列表。在联邦学习中，原始数据集通常由多个客户端持有，每个客户端只能访问自己所持有的部分数据集。因此，为了让每个客户端只使用自己所持有的数据进行训练，需要将原始数据集划分成多个部分，每个部分由一个客户端持有，并通过idxs将该客户端用于训练的数据集的索引列表传递给Client类的构造函数。
        :param idxs_test:
        """
        # net_client_model:一个与客户端实例相关的神经网络模型。
        self.idx = idx  # 一个整数，表示客户端的索引
        self.device = device  # 一个字符串，表示执行客户端计算的设备。
        self.lr = lr
        self.local_ep = 1
        # self.selected_clients = []
        self.ldr_train = DataLoader(DatasetSplit(dataset_train, idxs), batch_size=128,
                                    shuffle=True)  # 一个PyTorch数据集，表示客户端可用于训练的数据
        self.ldr_test = DataLoader(DatasetSplit(dataset_test, idxs_test), batch_size=128, shuffle=True)

    def train(self, net):
        net.train()
        optimizer_client = torch.optim.Adam(net.parameters(), lr=self.lr)

        for iter in range(self.local_ep):
            # 外层循环是客户端的本地训练轮数self.local_ep
            len_batch = len(self.ldr_train)  # 计算该客户端的训练集数据分成的批次数。
            for batch_idx, (images, labels) in enumerate(self.ldr_train):
                # 循环处理每个批次的训练数据，batch_idx表示该批次的索引，images和labels表示该批次的图像和标签。
                # 内层循环是数据加载器self.ldr_train中每个批次的训练。在每个批次中，将图像和标签加载到设备上，然后将优化器的梯度清零。
                images, labels = images.to(self.device), labels.to(self.device)
                optimizer_client.zero_grad()
                # ---------forward prop-------------
                fx = net(images)
                # 生成一个可求导的副本client_fx
                # 对预测值进行深度拷贝，得到一个可求导的副本client_fx，并设置该张量需要计算梯度，以供后续使用。
                # 因此，在训练过程中，首先对本地模型参数进行一次前向传递，得到预测值，然后使用clone()方法生成一个与预测值张量具有相同数值但独立于原始张量的新张量client_fx，并通过detach()方法使其与计算图断开连接，最后设置requires_grad_属性为True，使得该张量具有求导的能力，从而在之后的反向传递中可以计算损失函数对该张量的梯度，以供服务器使用。
                client_fx = fx.clone().detach().requires_grad_(True)

                # Sending activations to server and receiving gradients from server
                dfx = train_server(client_fx, labels, iter, self.local_ep, self.idx, len_batch)

                # --------backward prop -------------
                fx.backward(dfx)
                optimizer_client.step()

            # prRed('Client{} Train => Epoch: {}'.format(self.idx, ell))

        return net.state_dict()

    def evaluate(self, net=None, ell=None, selected_clients=None):
        net.eval()

        with torch.no_grad():
            len_batch = len(self.ldr_test)
            for batch_idx, (images, labels) in enumerate(self.ldr_test):
                images, labels = images.to(self.device), labels.to(self.device)
                # ---------forward prop-------------
                fx = net(images)

                # Sending activations to server
                acc_avg_test_all, loss_avg_test_all = evaluate_server(fx, labels, self.idx, len_batch, ell,
                                                                      selected_clients)

            # prRed('Client{} Test => Epoch: {}'.format(self.idx, ell))
            if loss_avg_test_all is not None and acc_avg_test_all is not None:
                self.loss_avg_test_all = loss_avg_test_all
                self.acc_avg_test_all = acc_avg_test_all

        return

# %% [markdown]
# ## 1.7 聚合算法定义

# %%
# To print in color -------test/train of the client side
def prRed(skk): print("\033[91m {}\033[00m" .format(skk))
def prGreen(skk): print("\033[92m {}\033[00m" .format(skk))

def calculate_accuracy(fx, y):
    preds = fx.max(1, keepdim=True)[1]
    correct = preds.eq(y.view_as(preds)).sum()
    acc = 100.00 *correct.float()/preds.shape[0]
    return acc
# Federated averaging: FedAvg
def FedAvg(w):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[k] += w[i][k]
        w_avg[k] = torch.div(w_avg[k], len(w))
    return w_avg

# %% [markdown]
# # 2.Data Loading

# %% [markdown]
# ## 2.1 Data处理函数定义

# %%
from glob import glob
from sklearn.model_selection import train_test_split
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image

class DatasetSplit(Dataset):
    def __init__(self, dataset, idxs):
        self.dataset = dataset
        self.idxs = list(idxs)

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, item):
        image, label = self.dataset[self.idxs[item]]
        return image, label


# ==============================================================
# Custom dataset prepration in Pytorch format
class SkinData(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        X = Image.open(self.df['path'][index]).resize((64, 64))
        y = torch.tensor(int(self.df['target'][index]))

        if self.transform:
            X = self.transform(X)

        return X, y

def dataset_iid(dataset, num_users):
    """
    该函数接受一个数据集dataset和一个整数num_users作为输入。
    它的作用是将数据集分割成num_users份，以便每个客户端都有一份相同分布的数据集。
    :param dataset:
    :param num_users:
    :return:函数返回一个字典dict_users，其中包含num_users个键，每个键对应一个客户端，值为该客户端所分配的数据集索引的集合。
    dict_users:{idx:int : []:list}
    """
    # 该函数首先计算每个客户端应该拥有的数据量num_items
    num_items = int(len(dataset)/num_users)
    dict_users, all_idxs = {}, [i for i in range(len(dataset))]
    for i in range(num_users):
        # 接着，函数使用np.random.choice函数从all_idxs中选择num_items个索引，将这些索引添加到字典dict_users的第i个键中，表示第i个客户端的数据集。在选择后，从all_idxs中移除已经分配给第i个客户端的索引。
        dict_users[i] = set(np.random.choice(all_idxs, num_items, replace = False))
        all_idxs = list(set(all_idxs) - dict_users[i])
    return dict_users

def load_data(dataset_choice, num_users):
    """

    :param dataset_choice: 选择的数据集
    :param num_users: 用户的数量
    :return:
    """
    if dataset_choice == 'HAM10000':
        df = pd.read_csv('data/HAM10000_metadata.csv')
        print(df.head())

        lesion_type = {
            'nv': 'Melanocytic nevi',
            'mel': 'Melanoma',
            'bkl': 'Benign keratosis-like lesions ',
            'bcc': 'Basal cell carcinoma',
            'akiec': 'Actinic keratoses',
            'vasc': 'Vascular lesions',
            'df': 'Dermatofibroma'
        }

        # merging both folders of HAM1000 dataset -- part1 and part2 -- into a single directory
        imageid_path = {os.path.splitext(os.path.basename(x))[0]: x
                        for x in glob(os.path.join("data", '*', '*.jpg'))}

        # print("path---------------------------------------", imageid_path.get)
        # 将图像id映射为图像文件的路径，并将其存储在数据集中的path列中。
        df['path'] = df['image_id'].map(imageid_path.get)
        # 将诊断编码映射为对应的分类名称，并将其存储在数据集中的cell_type列中。
        df['cell_type'] = df['dx'].map(lesion_type.get)
        # 将分类名称转换为数字编码，并将其存储在数据集中的target列中。这里使用了.
        # 可以将字符串类型的分类变量转换为数字编码，其中不同的分类名称对应不同的数字编码。
        df['target'] = pd.Categorical(df['cell_type']).codes
        print(df['cell_type'].value_counts())
        print(df['target'].value_counts())

        # =============================================================================
        # Train-test split
        train, test = train_test_split(df, test_size=0.2)

        train = train.reset_index()

        test = test.reset_index()

        # =============================================================================
        #                         Data preprocessing
        # =============================================================================
        # Data preprocessing: Transformation
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]

        train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.Pad(3),
                                               transforms.RandomRotation(10),
                                               transforms.CenterCrop(64),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean=mean, std=std)
                                               ])

        test_transforms = transforms.Compose([
            transforms.Pad(3),
            transforms.CenterCrop(64),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])

        # With augmentation
        dataset_train = SkinData(train, transform=train_transforms)
        dataset_test = SkinData(test, transform=test_transforms)

        # ----------------------------------------------------------------
        dict_users = dataset_iid(dataset_train, num_users)
        dict_users_test = dataset_iid(dataset_test, num_users)
    elif dataset_choice == 'CIFAR10':
        # =============================================================================
        #                         Data loading
        # =============================================================================
        # Load CIFAR-10 dataset
        trainset = datasets.CIFAR10(root='./data', train=True, download=True)
        testset = datasets.CIFAR10(root='./data', train=False, download=True)

        train_df = pd.DataFrame(trainset.targets, columns=['target'])
        test_df = pd.DataFrame(testset.targets, columns=['target'])

        # Set the class names
        class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

        train_df['cell_type'] = train_df['target'].apply(lambda x: class_names[x])
        test_df['cell_type'] = test_df['target'].apply(lambda x: class_names[x])

        print(train_df['cell_type'].value_counts())
        print(train_df['target'].value_counts())

        # =============================================================================
        # Train-test split
        train = train_df.reset_index()
        test = test_df.reset_index()

        # =============================================================================
        #                         Data preprocessing
        # =============================================================================
        # Data preprocessing: Transformation
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]

        train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.Pad(3),
                                               transforms.RandomRotation(10),
                                               transforms.CenterCrop(32),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean=mean, std=std)
                                               ])

        test_transforms = transforms.Compose([
            transforms.Pad(3),
            transforms.CenterCrop(32),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])

        # With augmentation
        dataset_train = datasets.CIFAR10(root='./data', train=True, transform=train_transforms, download=True)
        dataset_test = datasets.CIFAR10(root='./data', train=False, transform=test_transforms, download=True)

        # ----------------------------------------------------------------
        dict_users = dataset_iid(dataset_train, num_users)
        dict_users_test = dataset_iid(dataset_test, num_users)
    else:
        raise ValueError("Invalid dataset_choice: Choose either 'HAM10000' or 'CIFAR10'")

    return dataset_train,dataset_test,dict_users,dict_users_test

# %% [markdown]
# ## 2.2 load data

# %%
# =============================================================================
#                         Data loading
# =============================================================================
dataset_train, dataset_test, dict_users, dict_users_test = load_data(dataset_choice, num_users)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# frog          5000
# truck         5000
# deer          5000
# automobile    5000
# bird          5000
# horse         5000
# ship          5000
# cat           5000
# dog           5000
# airplane      5000
# Name: cell_type, dtype: int64
# 6    5000
# 9    5000
# 4    5000
# 1    5000
# 2    5000
# 7    5000
# 8    5000
# 3    5000
# 5    5000
# 0    5000
# Name: target, dtype: int64
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## 2.3数据投毒——标签翻转
# ### 2.3.1函数定义

# %%
def replace_label1_with_label2_on_df(df,label1,label2,poisoned_dict_users):
    """
    标签反转
    :param df:dataframe
    :param label1: 等待翻转的标签
    :param label2: 需要翻转的标签
    :param poisoned_dict_users:包含索引列表的字典,中毒的用户
    :return:
    """
    for idx_list in poisoned_dict_users.values():
        for idx in idx_list:
            if df.loc[idx,'target'] == label1:
                df.loc[idx,'target'] = label2
    # df.loc[df['target'] == label1, 'target'] = label2
    return df

def random_select_poisoning_users(dict_users, n):
    """
    随机选择n个key-value对
    :param dict_users: 字典，key为索引，value为包含索引值的列表
    :param n: 选择的key-value对的数量
    :return: 随机选择的key-value对组成的字典
    """
    selected = {}
    keys = random.sample(list(dict_users.keys()), n)
    for k in keys:
        selected[k] = dict_users[k]
    return selected

# def poison_data(dataset_train, dict_users, poisoned_users_num, original_label, target_label):
#     poisoned_dict_users = random_select_poisoning_users(dict_users, poisoned_users_num)
#     replace_label1_with_label2_on_df(dataset_train.df, original_label, target_label, poisoned_dict_users)
#     return poisoned_dict_users

def print_poisoning_results(poisoned_dict_users, dataset_train):
    for poisoned_user_key in poisoned_dict_users:
        print("被投毒的用户:", poisoned_user_key)

    print("标签反转后的target统计:")
    print(dataset_train.df['target'].value_counts())

def cifar10_to_dataframe(dataset):
    data = [dataset[i] for i in range(len(dataset))]
    images, labels = zip(*data)
    df = pd.DataFrame({"image": images, "target": labels})
    return df



def poison_data(dataset_train, dataset_choice, dict_users, poisoned_users_num, label_mappings):
    if dataset_choice == 'CIFAR10':
        df_train = cifar10_to_dataframe(dataset_train)
    elif dataset_choice == 'HAM10000':
        df_train = dataset_train.df
    else:
        raise ValueError("Invalid dataset choice.")

    poisoned_dict_users = random_select_poisoning_users(dict_users, poisoned_users_num)

    for original_label, target_label in label_mappings:
        replace_label1_with_label2_on_df(df_train, original_label, target_label, poisoned_dict_users)

    # 修改 dataset_train 的标签
    if dataset_choice == 'CIFAR10':
        for idx, row in df_train.iterrows():
            dataset_train.targets[idx] = row['target']

    return poisoned_dict_users

# %%
# =============================================================================
#                         Poisoning
# =============================================================================
# 增加投毒用户数量至 50%
poisoned_frac = 0.3
poisoned_users_num = int(poisoned_frac * num_users)
label_mappings = [(4, 2), (1, 7), (3, 1), (2, 6), (6, 5)]
poisoned_dict_users = poison_data(dataset_train, dataset_choice, dict_users, poisoned_users_num, label_mappings)

for poisoned_user_key in poisoned_dict_users:
    print("被投毒的用户:", poisoned_user_key)

# 如果使用的是 HAM10000 数据集，您可以直接使用 dataset_train.df 查看标签分布
if dataset_choice == 'HAM10000':
    print("标签反转后的target统计:")
    print(dataset_train.df['target'].value_counts())
elif dataset_choice == 'CIFAR10':
    cifar10_df = cifar10_to_dataframe(dataset_train)
    print("标签反转后的target统计:")
    print(cifar10_df['target'].value_counts())
# Out:
# 被投毒的用户: 14
# 被投毒的用户: 3
# 被投毒的用户: 0
# 被投毒的用户: 2
# 被投毒的用户: 1
# 被投毒的用户: 10
# 标签反转后的target统计:
# 5    9436
# 7    6520
# 9    5000
# 8    5000
# 0    5000
# 1    4992
# 2    3554
# 4    3515
# 6    3495
# 3    3488
# Name: target, dtype: int64

# %% [markdown]
# # 3.模型训练和评估

# %%
# ------------ Training And Testing -----------------
net_glob_client.train()
# copy weights
w_glob_client = net_glob_client.state_dict()

# Federation takes place after certain local epochs in train() client-side
# this epoch is global epoch, also known as rounds

total_time = 0.0  # 初始化总时间为0
best_clients_indices = None
krum_acc_test_collect = []
krum_loss_test_collect = []

# %%
for iter in range(epochs):
    start_time = time.time()  # 记录开始时间
    m = max(int(frac * num_users), 1)
    idxs_users = np.random.choice(range(num_users), m, replace=False)  # ，replace=False表示不允许重复选择。
    w_locals_client = []  # 用于存储每个客户端训练后的本地模型参数。
    loss_avg_test_all_dict = {}
    acc_avg_test_all_dict = {}
    idx_local_client_dict = {}

    for idx in idxs_users:

        local = Client(net_glob_client, idx, lr, device, dataset_train=dataset_train, dataset_test=dataset_test,
                       idxs=dict_users[idx], idxs_test=dict_users_test[idx])
        # Training ------------------
        w_client = local.train(net=copy.deepcopy(net_glob_client).to(device))
        idx_local_client_dict[len(w_locals_client)] = idx
        w_locals_client.append(copy.deepcopy(w_client))

        # Testing -------------------
        local.evaluate(net=copy.deepcopy(net_glob_client).to(device), ell=iter, selected_clients=best_clients_indices)

        # Update the dictionaries with the client's self.loss_avg_test_all and self.acc_avg_test_all
        loss_avg_test_all_dict[idx] = local.loss_avg_test_all
        acc_avg_test_all_dict[idx] = local.acc_avg_test_all

    print("idxs_users", idxs_users)
    # Ater serving all clients for its local epochs------------
    # Federation process at Client-Side------------------------
    print("------------------------------------------------------------")
    print("------ Fed Server: Federation process at Client-Side -------")
    print("------------------------------------------------------------")
    # w_locals_client是所有客户端训练后的本地模型参数列表，FedAvg函数是加权平均函数，返回全局模型参数w_glob_client。
    w_glob_client = FedAvg(w_locals_client)
    # 调用 Krum 算法
    # num_to_select = int(num_users * (1 - poisoned_frac - 0.1))  # 选择的客户端数量
    # w_glob_client, best_clients_indices = krum_aggregation(w_locals_client, num_to_select)
    # print([idxs_users[i] for i in best_clients_indices])
    # Update client-side global model
    net_glob_client.load_state_dict(w_glob_client)

    # print("fedserver选择的客户端index:", best_clients_indices)
    # best_clients_idxs = [idx_local_client_dict[i] for i in best_clients_indices]
    # krum_acc_test_collect_user = [acc_avg_test_all_dict[i] for i in best_clients_idxs]
    # for acc in krum_acc_test_collect_user:
    #     print("acc:",acc)
    # krum_loss_test_collect_user = [loss_avg_test_all_dict[i] for i in best_clients_idxs]
    #
    # krum_acc_avg_all_user = sum(krum_acc_test_collect_user) / len(krum_acc_test_collect_user)
    # krum_loss_avg_all_user = sum(krum_loss_test_collect_user) / len(krum_loss_test_collect_user)
    # krum_acc_test_collect.append(krum_acc_avg_all_user)
    # krum_loss_test_collect.append(krum_loss_avg_all_user)

    # print("====================== Fed Server==========================")
    # print(' Train: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(iter, acc_avg_all_user_train,
    #                                                                           loss_avg_all_user_train))
    # print(' Test: Round {:3d}, Avg Accuracy {:.3f} | Avg Loss {:.3f}'.format(iter, krum_acc_avg_all_user,
    #                                                                          krum_loss_avg_all_user))
    # print("==========================================================")

    end_time = time.time()  # 记录结束时间
    epoch_time = end_time - start_time  # 计算epoch所耗费的时间
    total_time += epoch_time  # 将时间差加到总时间中
    # 将时间差值转换为小时、分钟和秒数
    hours, rem = divmod(epoch_time, 3600)
    minutes, seconds = divmod(rem, 60)
    print(f"Epoch {iter} finished in {int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}")
    print(f"Epoch {iter} finished. Total time: {total_time:.2f} seconds")
# Out:
#  Client11 Train => Local Epoch: 0 	Acc: 23.727 	Loss: 2.0410
#  Client11 Test =>                   	Acc: 12.433 	Loss: 3.0269
#  Client4 Train => Local Epoch: 0 	Acc: 32.932 	Loss: 1.8254
#  Client4 Test =>                   	Acc: 8.055 	Loss: 3.8765
#  Client14 Train => Local Epoch: 0 	Acc: 48.642 	Loss: 1.5158
#  Client14 Test =>                   	Acc: 8.951 	Loss: 3.6544
#  Client18 Train => Local Epoch: 0 	Acc: 31.932 	Loss: 1.9111
#  Client18 Test =>                   	Acc: 11.981 	Loss: 2.7995
#  Client8 Train => Local Epoch: 0 	Acc: 36.521 	Loss: 1.6893
#  Client8 Test =>                   	Acc: 9.617 	Loss: 3.1107
#  Client1 Train => Local Epoch: 0 	Acc: 51.376 	Loss: 1.4206
#  Client1 Test =>                   	Acc: 9.186 	Loss: 3.7400
#  Client12 Train => Local Epoch: 0 	Acc: 36.700 	Loss: 1.8125
#  Client12 Test =>                   	Acc: 11.045 	Loss: 3.2684
#  Client6 Train => Local Epoch: 0 	Acc: 41.319 	Loss: 1.6177
#  Client6 Test =>                   	Acc: 10.244 	Loss: 3.3445
#  Client16 Train => Local Epoch: 0 	Acc: 41.126 	Loss: 1.5782
#  Client16 Test =>                   	Acc: 12.082 	Loss: 3.4787
#  Client17 Train => Local Epoch: 0 	Acc: 42.004 	Loss: 1.5808
#  Client17 Test =>                   	Acc: 12.534 	Loss: 3.3744
#  Client0 Train => Local Epoch: 0 	Acc: 51.960 	Loss: 1.4105
#  Client0 Test =>                   	Acc: 9.341 	Loss: 3.3857
#  Client7 Train => Local Epoch: 0 	Acc: 39.906 	Loss: 1.7150
#  Client7 Test =>                   	Acc: 10.769 	Loss: 2.9392
#  Client10 Train => Local Epoch: 0 	Acc: 54.364 	Loss: 1.2668
#  Client10 Test =>                   	Acc: 10.163 	Loss: 3.8621
#  Client5 Train => Local Epoch: 0 	Acc: 40.425 	Loss: 1.7345
#  Client5 Test =>                   	Acc: 11.281 	Loss: 3.0001
#  Client3 Train => Local Epoch: 0 	Acc: 56.696 	Loss: 1.2174
#  Client3 Test =>                   	Acc: 7.779 	Loss: 4.1358
#  Client13 Train => Local Epoch: 0 	Acc: 40.717 	Loss: 1.7216
#  Client13 Test =>                   	Acc: 10.008 	Loss: 3.2284
#  Client19 Train => Local Epoch: 0 	Acc: 45.395 	Loss: 1.4926
#  Client19 Test =>                   	Acc: 12.412 	Loss: 3.2323
#  Client2 Train => Local Epoch: 0 	Acc: 57.360 	Loss: 1.2276
#  Client2 Test =>                   	Acc: 7.254 	Loss: 4.2610
#  Client15 Train => Local Epoch: 0 	Acc: 41.317 	Loss: 1.7017
#  Client15 Test =>                   	Acc: 15.989 	Loss: 2.8072
#  Client9 Train => Local Epoch: 0 	Acc: 46.287 	Loss: 1.4479
#  Client9 Test =>                   	Acc: 9.793 	Loss: 3.0143
# ====================== SERVER V1==========================
#  Train: Round   0, Avg Accuracy 43.035 | Avg Loss 1.596
#  Test: Round   0, Avg Accuracy 10.546 | Avg Loss 3.377
# ==========================================================
# idxs_users [11  4 14 18  8  1 12  6 16 17  0  7 10  5  3 13 19  2 15  9]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 0 finished in 00:01:05
# Epoch 0 finished. Total time: 65.16 seconds
#  Client10 Train => Local Epoch: 0 	Acc: 58.382 	Loss: 1.2204
#  Client10 Test =>                   	Acc: 20.211 	Loss: 2.9194
#  Client5 Train => Local Epoch: 0 	Acc: 44.405 	Loss: 1.6091
#  Client5 Test =>                   	Acc: 21.370 	Loss: 2.2376
#  Client4 Train => Local Epoch: 0 	Acc: 49.069 	Loss: 1.4124
#  Client4 Test =>                   	Acc: 27.990 	Loss: 2.3147
#  Client8 Train => Local Epoch: 0 	Acc: 48.732 	Loss: 1.4014
#  Client8 Test =>                   	Acc: 27.364 	Loss: 2.0685
#  Client15 Train => Local Epoch: 0 	Acc: 50.733 	Loss: 1.3663
#  Client15 Test =>                   	Acc: 30.018 	Loss: 2.2462
#  Client16 Train => Local Epoch: 0 	Acc: 51.234 	Loss: 1.3418
#  Client16 Test =>                   	Acc: 30.098 	Loss: 2.1191
#  Client6 Train => Local Epoch: 0 	Acc: 51.374 	Loss: 1.3378
#  Client6 Test =>                   	Acc: 26.643 	Loss: 2.3203
#  Client7 Train => Local Epoch: 0 	Acc: 51.549 	Loss: 1.3339
#  Client7 Test =>                   	Acc: 25.276 	Loss: 2.3841
#  Client3 Train => Local Epoch: 0 	Acc: 58.279 	Loss: 1.2504
#  Client3 Test =>                   	Acc: 14.507 	Loss: 2.9166
#  Client18 Train => Local Epoch: 0 	Acc: 46.294 	Loss: 1.5373
#  Client18 Test =>                   	Acc: 27.128 	Loss: 2.2537
#  Client12 Train => Local Epoch: 0 	Acc: 50.308 	Loss: 1.3569
#  Client12 Test =>                   	Acc: 26.542 	Loss: 2.2101
#  Client1 Train => Local Epoch: 0 	Acc: 57.385 	Loss: 1.2463
#  Client1 Test =>                   	Acc: 15.187 	Loss: 3.3803
#  Client2 Train => Local Epoch: 0 	Acc: 64.026 	Loss: 0.9632
#  Client2 Test =>                   	Acc: 12.998 	Loss: 4.3283
#  Client19 Train => Local Epoch: 0 	Acc: 46.466 	Loss: 1.6421
#  Client19 Test =>                   	Acc: 20.952 	Loss: 2.2281
#  Client13 Train => Local Epoch: 0 	Acc: 53.091 	Loss: 1.3136
#  Client13 Test =>                   	Acc: 29.378 	Loss: 2.0983
#  Client11 Train => Local Epoch: 0 	Acc: 52.920 	Loss: 1.3036
#  Client11 Test =>                   	Acc: 30.529 	Loss: 2.0645
#  Client0 Train => Local Epoch: 0 	Acc: 59.354 	Loss: 1.1857
#  Client0 Test =>                   	Acc: 18.137 	Loss: 3.0237
#  Client9 Train => Local Epoch: 0 	Acc: 49.841 	Loss: 1.4577
#  Client9 Test =>                   	Acc: 30.159 	Loss: 2.0230
#  Client17 Train => Local Epoch: 0 	Acc: 54.830 	Loss: 1.2759
#  Client17 Test =>                   	Acc: 30.395 	Loss: 1.9917
#  Client14 Train => Local Epoch: 0 	Acc: 59.318 	Loss: 1.1596
#  Client14 Test =>                   	Acc: 17.746 	Loss: 3.0669
# ====================== SERVER V1==========================
#  Train: Round   1, Avg Accuracy 52.879 | Avg Loss 1.336
#  Test: Round   1, Avg Accuracy 24.132 | Avg Loss 2.510
# ==========================================================
# idxs_users [10  5  4  8 15 16  6  7  3 18 12  1  2 19 13 11  0  9 17 14]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 1 finished in 00:01:05
# Epoch 1 finished. Total time: 130.40 seconds
#  Client4 Train => Local Epoch: 0 	Acc: 50.308 	Loss: 1.4665
#  Client4 Test =>                   	Acc: 46.363 	Loss: 1.4557
#  Client7 Train => Local Epoch: 0 	Acc: 56.822 	Loss: 1.2346
#  Client7 Test =>                   	Acc: 47.912 	Loss: 1.4157
#  Client13 Train => Local Epoch: 0 	Acc: 56.857 	Loss: 1.1781
#  Client13 Test =>                   	Acc: 49.003 	Loss: 1.3826
#  Client2 Train => Local Epoch: 0 	Acc: 63.509 	Loss: 1.0723
#  Client2 Test =>                   	Acc: 30.624 	Loss: 2.7455
#  Client14 Train => Local Epoch: 0 	Acc: 65.409 	Loss: 0.9149
#  Client14 Test =>                   	Acc: 26.428 	Loss: 3.1994
#  Client5 Train => Local Epoch: 0 	Acc: 49.042 	Loss: 1.5680
#  Client5 Test =>                   	Acc: 35.399 	Loss: 1.8909
#  Client15 Train => Local Epoch: 0 	Acc: 56.172 	Loss: 1.2322
#  Client15 Test =>                   	Acc: 54.162 	Loss: 1.2148
#  Client0 Train => Local Epoch: 0 	Acc: 59.979 	Loss: 1.1137
#  Client0 Test =>                   	Acc: 27.755 	Loss: 2.5957
#  Client12 Train => Local Epoch: 0 	Acc: 52.755 	Loss: 1.4090
#  Client12 Test =>                   	Acc: 42.336 	Loss: 1.5559
#  Client17 Train => Local Epoch: 0 	Acc: 57.732 	Loss: 1.1908
#  Client17 Test =>                   	Acc: 47.771 	Loss: 1.4224
#  Client9 Train => Local Epoch: 0 	Acc: 58.410 	Loss: 1.1778
#  Client9 Test =>                   	Acc: 55.671 	Loss: 1.2486
#  Client10 Train => Local Epoch: 0 	Acc: 62.576 	Loss: 1.0878
#  Client10 Test =>                   	Acc: 33.526 	Loss: 2.3852
#  Client16 Train => Local Epoch: 0 	Acc: 54.547 	Loss: 1.3664
#  Client16 Test =>                   	Acc: 54.782 	Loss: 1.2847
#  Client8 Train => Local Epoch: 0 	Acc: 57.833 	Loss: 1.1957
#  Client8 Test =>                   	Acc: 53.596 	Loss: 1.3234
#  Client19 Train => Local Epoch: 0 	Acc: 57.208 	Loss: 1.1834
#  Client19 Test =>                   	Acc: 52.782 	Loss: 1.2462
#  Client11 Train => Local Epoch: 0 	Acc: 58.805 	Loss: 1.1632
#  Client11 Test =>                   	Acc: 50.216 	Loss: 1.4690
#  Client6 Train => Local Epoch: 0 	Acc: 57.615 	Loss: 1.1547
#  Client6 Test =>                   	Acc: 52.465 	Loss: 1.3796
#  Client18 Train => Local Epoch: 0 	Acc: 57.969 	Loss: 1.1656
#  Client18 Test =>                   	Acc: 51.232 	Loss: 1.3146
#  Client3 Train => Local Epoch: 0 	Acc: 63.012 	Loss: 1.1195
#  Client3 Test =>                   	Acc: 31.001 	Loss: 2.3989
#  Client1 Train => Local Epoch: 0 	Acc: 67.725 	Loss: 0.8748
#  Client1 Test =>                   	Acc: 29.553 	Loss: 3.1603
# ====================== SERVER V1==========================
#  Train: Round   2, Avg Accuracy 58.214 | Avg Loss 1.193
#  Test: Round   2, Avg Accuracy 43.629 | Avg Loss 1.804
# ==========================================================
# idxs_users [ 4  7 13  2 14  5 15  0 12 17  9 10 16  8 19 11  6 18  3  1]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 2 finished in 00:01:05
# Epoch 2 finished. Total time: 196.24 seconds
#  Client12 Train => Local Epoch: 0 	Acc: 53.362 	Loss: 1.4349
#  Client12 Test =>                   	Acc: 46.680 	Loss: 1.5168
#  Client16 Train => Local Epoch: 0 	Acc: 60.940 	Loss: 1.1110
#  Client16 Test =>                   	Acc: 57.759 	Loss: 1.2614
#  Client9 Train => Local Epoch: 0 	Acc: 60.354 	Loss: 1.1011
#  Client9 Test =>                   	Acc: 53.165 	Loss: 1.3432
#  Client14 Train => Local Epoch: 0 	Acc: 64.051 	Loss: 1.0547
#  Client14 Test =>                   	Acc: 31.311 	Loss: 2.3884
#  Client10 Train => Local Epoch: 0 	Acc: 68.626 	Loss: 0.8406
#  Client10 Test =>                   	Acc: 34.678 	Loss: 2.8592
#  Client8 Train => Local Epoch: 0 	Acc: 54.513 	Loss: 1.4062
#  Client8 Test =>                   	Acc: 50.040 	Loss: 1.5155
#  Client11 Train => Local Epoch: 0 	Acc: 60.335 	Loss: 1.1106
#  Client11 Test =>                   	Acc: 56.721 	Loss: 1.3714
#  Client2 Train => Local Epoch: 0 	Acc: 66.101 	Loss: 0.9855
#  Client2 Test =>                   	Acc: 30.449 	Loss: 2.3540
#  Client15 Train => Local Epoch: 0 	Acc: 56.353 	Loss: 1.2969
#  Client15 Test =>                   	Acc: 48.747 	Loss: 1.6486
#  Client5 Train => Local Epoch: 0 	Acc: 59.513 	Loss: 1.1270
#  Client5 Test =>                   	Acc: 57.940 	Loss: 1.1399
#  Client3 Train => Local Epoch: 0 	Acc: 64.667 	Loss: 0.9983
#  Client3 Test =>                   	Acc: 34.732 	Loss: 2.5131
#  Client13 Train => Local Epoch: 0 	Acc: 57.420 	Loss: 1.2705
#  Client13 Test =>                   	Acc: 46.909 	Loss: 1.5810
#  Client17 Train => Local Epoch: 0 	Acc: 61.629 	Loss: 1.0646
#  Client17 Test =>                   	Acc: 49.340 	Loss: 1.3628
#  Client1 Train => Local Epoch: 0 	Acc: 63.123 	Loss: 1.0275
#  Client1 Test =>                   	Acc: 33.311 	Loss: 2.3175
#  Client6 Train => Local Epoch: 0 	Acc: 55.811 	Loss: 1.3095
#  Client6 Test =>                   	Acc: 52.701 	Loss: 1.3669
#  Client7 Train => Local Epoch: 0 	Acc: 61.512 	Loss: 1.0983
#  Client7 Test =>                   	Acc: 54.688 	Loss: 1.3100
#  Client4 Train => Local Epoch: 0 	Acc: 62.810 	Loss: 1.0649
#  Client4 Test =>                   	Acc: 61.456 	Loss: 1.1471
#  Client19 Train => Local Epoch: 0 	Acc: 61.241 	Loss: 1.0841
#  Client19 Test =>                   	Acc: 59.927 	Loss: 1.2890
#  Client0 Train => Local Epoch: 0 	Acc: 64.527 	Loss: 1.0120
#  Client0 Test =>                   	Acc: 35.318 	Loss: 2.4216
#  Client18 Train => Local Epoch: 0 	Acc: 58.821 	Loss: 1.2404
#  Client18 Test =>                   	Acc: 46.774 	Loss: 1.5123
# ====================== SERVER V1==========================
#  Train: Round   3, Avg Accuracy 60.785 | Avg Loss 1.132
#  Test: Round   3, Avg Accuracy 47.132 | Avg Loss 1.711
# ==========================================================
# idxs_users [12 16  9 14 10  8 11  2 15  5  3 13 17  1  6  7  4 19  0 18]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 3 finished in 00:01:05
# Epoch 3 finished. Total time: 262.01 seconds
#  Client0 Train => Local Epoch: 0 	Acc: 67.847 	Loss: 0.9008
#  Client0 Test =>                   	Acc: 33.695 	Loss: 2.5235
#  Client7 Train => Local Epoch: 0 	Acc: 58.679 	Loss: 1.2294
#  Client7 Test =>                   	Acc: 56.311 	Loss: 1.3866
#  Client18 Train => Local Epoch: 0 	Acc: 63.456 	Loss: 1.0288
#  Client18 Test =>                   	Acc: 51.273 	Loss: 1.3740
#  Client1 Train => Local Epoch: 0 	Acc: 65.620 	Loss: 0.9581
#  Client1 Test =>                   	Acc: 37.742 	Loss: 2.3368
#  Client16 Train => Local Epoch: 0 	Acc: 59.954 	Loss: 1.1856
#  Client16 Test =>                   	Acc: 56.782 	Loss: 1.2062
#  Client5 Train => Local Epoch: 0 	Acc: 62.263 	Loss: 1.0634
#  Client5 Test =>                   	Acc: 63.147 	Loss: 1.0658
#  Client6 Train => Local Epoch: 0 	Acc: 63.123 	Loss: 1.0360
#  Client6 Test =>                   	Acc: 55.422 	Loss: 1.3314
#  Client15 Train => Local Epoch: 0 	Acc: 63.518 	Loss: 1.0335
#  Client15 Test =>                   	Acc: 62.002 	Loss: 1.2033
#  Client9 Train => Local Epoch: 0 	Acc: 64.779 	Loss: 0.9897
#  Client9 Test =>                   	Acc: 55.832 	Loss: 1.2223
#  Client17 Train => Local Epoch: 0 	Acc: 64.972 	Loss: 0.9884
#  Client17 Test =>                   	Acc: 58.715 	Loss: 1.1432
#  Client10 Train => Local Epoch: 0 	Acc: 68.051 	Loss: 0.9732
#  Client10 Test =>                   	Acc: 37.796 	Loss: 2.1595
#  Client3 Train => Local Epoch: 0 	Acc: 71.395 	Loss: 0.7877
#  Client3 Test =>                   	Acc: 33.870 	Loss: 3.0040
#  Client13 Train => Local Epoch: 0 	Acc: 58.495 	Loss: 1.3145
#  Client13 Test =>                   	Acc: 50.586 	Loss: 1.5483
#  Client4 Train => Local Epoch: 0 	Acc: 64.501 	Loss: 1.0256
#  Client4 Test =>                   	Acc: 66.629 	Loss: 0.9831
#  Client19 Train => Local Epoch: 0 	Acc: 64.148 	Loss: 1.0098
#  Client19 Test =>                   	Acc: 61.961 	Loss: 1.1052
#  Client11 Train => Local Epoch: 0 	Acc: 65.080 	Loss: 0.9867
#  Client11 Test =>                   	Acc: 57.893 	Loss: 1.2562
#  Client12 Train => Local Epoch: 0 	Acc: 64.887 	Loss: 0.9862
#  Client12 Test =>                   	Acc: 57.152 	Loss: 1.2054
#  Client14 Train => Local Epoch: 0 	Acc: 65.469 	Loss: 1.0084
#  Client14 Test =>                   	Acc: 36.160 	Loss: 2.2193
#  Client8 Train => Local Epoch: 0 	Acc: 60.393 	Loss: 1.1848
#  Client8 Test =>                   	Acc: 63.093 	Loss: 1.0930
#  Client2 Train => Local Epoch: 0 	Acc: 69.341 	Loss: 0.8819
#  Client2 Test =>                   	Acc: 33.486 	Loss: 2.5933
# ====================== SERVER V1==========================
#  Train: Round   4, Avg Accuracy 64.299 | Avg Loss 1.029
#  Test: Round   4, Avg Accuracy 51.477 | Avg Loss 1.598
# ==========================================================
# idxs_users [ 0  7 18  1 16  5  6 15  9 17 10  3 13  4 19 11 12 14  8  2]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 4 finished in 00:01:06
# Epoch 4 finished. Total time: 328.20 seconds
#  Client19 Train => Local Epoch: 0 	Acc: 61.806 	Loss: 1.1223
#  Client19 Test =>                   	Acc: 56.802 	Loss: 1.3244
#  Client5 Train => Local Epoch: 0 	Acc: 65.462 	Loss: 0.9896
#  Client5 Test =>                   	Acc: 58.520 	Loss: 1.1466
#  Client6 Train => Local Epoch: 0 	Acc: 66.877 	Loss: 0.9409
#  Client6 Test =>                   	Acc: 58.930 	Loss: 1.2528
#  Client18 Train => Local Epoch: 0 	Acc: 66.160 	Loss: 0.9436
#  Client18 Test =>                   	Acc: 54.768 	Loss: 1.3006
#  Client13 Train => Local Epoch: 0 	Acc: 65.954 	Loss: 0.9229
#  Client13 Test =>                   	Acc: 60.123 	Loss: 1.1141
#  Client11 Train => Local Epoch: 0 	Acc: 66.668 	Loss: 0.9353
#  Client11 Test =>                   	Acc: 62.116 	Loss: 1.1446
#  Client7 Train => Local Epoch: 0 	Acc: 68.130 	Loss: 0.9198
#  Client7 Test =>                   	Acc: 55.341 	Loss: 1.4710
#  Client9 Train => Local Epoch: 0 	Acc: 68.403 	Loss: 0.8980
#  Client9 Test =>                   	Acc: 64.756 	Loss: 1.0250
#  Client14 Train => Local Epoch: 0 	Acc: 64.968 	Loss: 1.0399
#  Client14 Test =>                   	Acc: 32.388 	Loss: 2.6102
#  Client1 Train => Local Epoch: 0 	Acc: 72.808 	Loss: 0.7486
#  Client1 Test =>                   	Acc: 38.308 	Loss: 3.0601
#  Client10 Train => Local Epoch: 0 	Acc: 73.955 	Loss: 0.6934
#  Client10 Test =>                   	Acc: 40.362 	Loss: 3.3769
#  Client3 Train => Local Epoch: 0 	Acc: 73.495 	Loss: 0.6980
#  Client3 Test =>                   	Acc: 30.294 	Loss: 3.9330
#  Client4 Train => Local Epoch: 0 	Acc: 56.643 	Loss: 1.4772
#  Client4 Test =>                   	Acc: 54.344 	Loss: 1.4536
#  Client2 Train => Local Epoch: 0 	Acc: 70.972 	Loss: 0.7953
#  Client2 Test =>                   	Acc: 38.113 	Loss: 2.5441
#  Client17 Train => Local Epoch: 0 	Acc: 61.512 	Loss: 1.2254
#  Client17 Test =>                   	Acc: 50.256 	Loss: 1.4092
#  Client16 Train => Local Epoch: 0 	Acc: 65.931 	Loss: 0.9816
#  Client16 Test =>                   	Acc: 64.547 	Loss: 1.0904
#  Client15 Train => Local Epoch: 0 	Acc: 67.493 	Loss: 0.9468
#  Client15 Test =>                   	Acc: 64.076 	Loss: 1.0839
#  Client12 Train => Local Epoch: 0 	Acc: 66.801 	Loss: 0.9468
#  Client12 Test =>                   	Acc: 62.466 	Loss: 1.2450
#  Client8 Train => Local Epoch: 0 	Acc: 66.834 	Loss: 0.9376
#  Client8 Test =>                   	Acc: 63.840 	Loss: 0.9902
#  Client0 Train => Local Epoch: 0 	Acc: 65.322 	Loss: 0.9725
#  Client0 Test =>                   	Acc: 36.907 	Loss: 2.1923
# ====================== SERVER V1==========================
#  Train: Round   5, Avg Accuracy 66.810 | Avg Loss 0.957
#  Test: Round   5, Avg Accuracy 52.363 | Avg Loss 1.738
# ==========================================================
# idxs_users [19  5  6 18 13 11  7  9 14  1 10  3  4  2 17 16 15 12  8  0]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 5 finished in 00:01:06
# Epoch 5 finished. Total time: 394.34 seconds
#  Client12 Train => Local Epoch: 0 	Acc: 65.400 	Loss: 1.0564
#  Client12 Test =>                   	Acc: 59.927 	Loss: 1.2520
#  Client11 Train => Local Epoch: 0 	Acc: 67.835 	Loss: 0.8960
#  Client11 Test =>                   	Acc: 58.641 	Loss: 1.2678
#  Client7 Train => Local Epoch: 0 	Acc: 69.033 	Loss: 0.8920
#  Client7 Test =>                   	Acc: 63.234 	Loss: 1.0231
#  Client13 Train => Local Epoch: 0 	Acc: 69.389 	Loss: 0.8750
#  Client13 Test =>                   	Acc: 65.187 	Loss: 1.0132
#  Client9 Train => Local Epoch: 0 	Acc: 69.986 	Loss: 0.8555
#  Client9 Test =>                   	Acc: 62.412 	Loss: 1.0602
#  Client8 Train => Local Epoch: 0 	Acc: 70.161 	Loss: 0.8609
#  Client8 Test =>                   	Acc: 66.655 	Loss: 0.9876
#  Client1 Train => Local Epoch: 0 	Acc: 68.853 	Loss: 0.9859
#  Client1 Test =>                   	Acc: 42.161 	Loss: 1.9765
#  Client2 Train => Local Epoch: 0 	Acc: 78.038 	Loss: 0.6356
#  Client2 Test =>                   	Acc: 35.810 	Loss: 3.3406
#  Client3 Train => Local Epoch: 0 	Acc: 74.540 	Loss: 0.6701
#  Client3 Test =>                   	Acc: 34.032 	Loss: 3.7792
#  Client18 Train => Local Epoch: 0 	Acc: 59.910 	Loss: 1.3477
#  Client18 Test =>                   	Acc: 51.057 	Loss: 1.5055
#  Client10 Train => Local Epoch: 0 	Acc: 72.335 	Loss: 0.7628
#  Client10 Test =>                   	Acc: 36.200 	Loss: 2.6549
#  Client5 Train => Local Epoch: 0 	Acc: 63.369 	Loss: 1.1473
#  Client5 Test =>                   	Acc: 62.015 	Loss: 1.1977
#  Client15 Train => Local Epoch: 0 	Acc: 68.729 	Loss: 0.8936
#  Client15 Test =>                   	Acc: 58.600 	Loss: 1.2004
#  Client4 Train => Local Epoch: 0 	Acc: 68.902 	Loss: 0.8974
#  Client4 Test =>                   	Acc: 70.016 	Loss: 0.8688
#  Client16 Train => Local Epoch: 0 	Acc: 67.585 	Loss: 0.8928
#  Client16 Test =>                   	Acc: 64.211 	Loss: 1.0826
#  Client6 Train => Local Epoch: 0 	Acc: 68.074 	Loss: 0.8831
#  Client6 Test =>                   	Acc: 69.296 	Loss: 0.9875
#  Client0 Train => Local Epoch: 0 	Acc: 69.042 	Loss: 0.9124
#  Client0 Test =>                   	Acc: 34.947 	Loss: 2.7370
#  Client14 Train => Local Epoch: 0 	Acc: 74.219 	Loss: 0.6671
#  Client14 Test =>                   	Acc: 31.688 	Loss: 3.5977
#  Client19 Train => Local Epoch: 0 	Acc: 63.022 	Loss: 1.2052
#  Client19 Test =>                   	Acc: 56.055 	Loss: 1.3050
#  Client17 Train => Local Epoch: 0 	Acc: 70.469 	Loss: 0.8969
#  Client17 Test =>                   	Acc: 61.712 	Loss: 1.0867
# ====================== SERVER V1==========================
#  Train: Round   6, Avg Accuracy 68.945 | Avg Loss 0.912
#  Test: Round   6, Avg Accuracy 54.193 | Avg Loss 1.696
# ==========================================================
# idxs_users [12 11  7 13  9  8  1  2  3 18 10  5 15  4 16  6  0 14 19 17]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 6 finished in 00:01:06
# Epoch 6 finished. Total time: 460.42 seconds
#  Client8 Train => Local Epoch: 0 	Acc: 71.758 	Loss: 0.8294
#  Client8 Test =>                   	Acc: 71.579 	Loss: 0.8979
#  Client11 Train => Local Epoch: 0 	Acc: 71.000 	Loss: 0.8531
#  Client11 Test =>                   	Acc: 67.592 	Loss: 0.9977
#  Client12 Train => Local Epoch: 0 	Acc: 71.801 	Loss: 0.8332
#  Client12 Test =>                   	Acc: 60.614 	Loss: 1.3731
#  Client18 Train => Local Epoch: 0 	Acc: 71.029 	Loss: 0.8334
#  Client18 Test =>                   	Acc: 62.938 	Loss: 1.0746
#  Client14 Train => Local Epoch: 0 	Acc: 69.189 	Loss: 0.9359
#  Client14 Test =>                   	Acc: 39.137 	Loss: 2.2610
#  Client4 Train => Local Epoch: 0 	Acc: 66.703 	Loss: 1.0051
#  Client4 Test =>                   	Acc: 65.106 	Loss: 1.0483
#  Client13 Train => Local Epoch: 0 	Acc: 71.634 	Loss: 0.8164
#  Client13 Test =>                   	Acc: 64.386 	Loss: 1.0487
#  Client6 Train => Local Epoch: 0 	Acc: 70.002 	Loss: 0.8289
#  Client6 Test =>                   	Acc: 67.922 	Loss: 1.0086
#  Client3 Train => Local Epoch: 0 	Acc: 69.345 	Loss: 0.9141
#  Client3 Test =>                   	Acc: 37.581 	Loss: 2.6090
#  Client19 Train => Local Epoch: 0 	Acc: 66.542 	Loss: 1.0169
#  Client19 Test =>                   	Acc: 57.503 	Loss: 1.1664
#  Client10 Train => Local Epoch: 0 	Acc: 73.132 	Loss: 0.7598
#  Client10 Test =>                   	Acc: 37.567 	Loss: 2.6961
#  Client15 Train => Local Epoch: 0 	Acc: 65.306 	Loss: 1.0213
#  Client15 Test =>                   	Acc: 61.921 	Loss: 1.1690
#  Client16 Train => Local Epoch: 0 	Acc: 71.535 	Loss: 0.8310
#  Client16 Test =>                   	Acc: 70.447 	Loss: 0.8725
#  Client7 Train => Local Epoch: 0 	Acc: 71.684 	Loss: 0.8318
#  Client7 Test =>                   	Acc: 67.807 	Loss: 0.9436
#  Client1 Train => Local Epoch: 0 	Acc: 70.361 	Loss: 0.8834
#  Client1 Test =>                   	Acc: 42.026 	Loss: 2.3734
#  Client5 Train => Local Epoch: 0 	Acc: 66.264 	Loss: 1.0354
#  Client5 Test =>                   	Acc: 61.375 	Loss: 1.1832
#  Client0 Train => Local Epoch: 0 	Acc: 73.146 	Loss: 0.7574
#  Client0 Test =>                   	Acc: 35.358 	Loss: 2.8744
#  Client17 Train => Local Epoch: 0 	Acc: 66.650 	Loss: 1.0033
#  Client17 Test =>                   	Acc: 61.146 	Loss: 1.1513
#  Client9 Train => Local Epoch: 0 	Acc: 69.945 	Loss: 0.8500
#  Client9 Test =>                   	Acc: 66.703 	Loss: 1.1116
#  Client2 Train => Local Epoch: 0 	Acc: 71.618 	Loss: 0.7979
#  Client2 Test =>                   	Acc: 35.911 	Loss: 2.5232
# ====================== SERVER V1==========================
#  Train: Round   7, Avg Accuracy 69.932 | Avg Loss 0.882
#  Test: Round   7, Avg Accuracy 56.731 | Avg Loss 1.519
# ==========================================================
# idxs_users [ 8 11 12 18 14  4 13  6  3 19 10 15 16  7  1  5  0 17  9  2]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 7 finished in 00:01:05
# Epoch 7 finished. Total time: 526.05 seconds
#  Client16 Train => Local Epoch: 0 	Acc: 66.103 	Loss: 0.9977
#  Client16 Test =>                   	Acc: 61.550 	Loss: 1.1316
#  Client3 Train => Local Epoch: 0 	Acc: 72.631 	Loss: 0.7715
#  Client3 Test =>                   	Acc: 35.756 	Loss: 2.5872
#  Client5 Train => Local Epoch: 0 	Acc: 66.016 	Loss: 1.0645
#  Client5 Test =>                   	Acc: 58.506 	Loss: 1.2288
#  Client19 Train => Local Epoch: 0 	Acc: 71.459 	Loss: 0.7970
#  Client19 Test =>                   	Acc: 68.413 	Loss: 0.9270
#  Client18 Train => Local Epoch: 0 	Acc: 72.266 	Loss: 0.7903
#  Client18 Test =>                   	Acc: 63.153 	Loss: 1.1282
#  Client0 Train => Local Epoch: 0 	Acc: 72.364 	Loss: 0.8409
#  Client0 Test =>                   	Acc: 39.042 	Loss: 2.3850
#  Client7 Train => Local Epoch: 0 	Acc: 67.943 	Loss: 0.9715
#  Client7 Test =>                   	Acc: 56.499 	Loss: 1.3645
#  Client8 Train => Local Epoch: 0 	Acc: 71.585 	Loss: 0.8108
#  Client8 Test =>                   	Acc: 69.235 	Loss: 0.9316
#  Client17 Train => Local Epoch: 0 	Acc: 73.633 	Loss: 0.7643
#  Client17 Test =>                   	Acc: 66.985 	Loss: 0.9796
#  Client12 Train => Local Epoch: 0 	Acc: 71.634 	Loss: 0.7950
#  Client12 Test =>                   	Acc: 61.847 	Loss: 1.1904
#  Client9 Train => Local Epoch: 0 	Acc: 73.242 	Loss: 0.7415
#  Client9 Test =>                   	Acc: 69.666 	Loss: 0.9192
#  Client1 Train => Local Epoch: 0 	Acc: 70.551 	Loss: 0.8949
#  Client1 Test =>                   	Acc: 43.393 	Loss: 2.1400
#  Client6 Train => Local Epoch: 0 	Acc: 68.355 	Loss: 0.9504
#  Client6 Test =>                   	Acc: 65.019 	Loss: 1.0805
#  Client13 Train => Local Epoch: 0 	Acc: 73.194 	Loss: 0.7722
#  Client13 Test =>                   	Acc: 65.928 	Loss: 1.0947
#  Client11 Train => Local Epoch: 0 	Acc: 72.808 	Loss: 0.8107
#  Client11 Test =>                   	Acc: 66.635 	Loss: 1.0451
#  Client10 Train => Local Epoch: 0 	Acc: 72.188 	Loss: 0.8169
#  Client10 Test =>                   	Acc: 43.413 	Loss: 2.2656
#  Client2 Train => Local Epoch: 0 	Acc: 77.300 	Loss: 0.6047
#  Client2 Test =>                   	Acc: 36.981 	Loss: 3.3420
#  Client4 Train => Local Epoch: 0 	Acc: 66.471 	Loss: 1.0866
#  Client4 Test =>                   	Acc: 62.938 	Loss: 1.1543
#  Client15 Train => Local Epoch: 0 	Acc: 72.803 	Loss: 0.7983
#  Client15 Test =>                   	Acc: 66.184 	Loss: 0.8988
#  Client14 Train => Local Epoch: 0 	Acc: 71.128 	Loss: 0.8521
#  Client14 Test =>                   	Acc: 38.638 	Loss: 2.5143
# ====================== SERVER V1==========================
#  Train: Round   8, Avg Accuracy 71.184 | Avg Loss 0.847
#  Test: Round   8, Avg Accuracy 56.989 | Avg Loss 1.515
# ==========================================================
# idxs_users [16  3  5 19 18  0  7  8 17 12  9  1  6 13 11 10  2  4 15 14]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 8 finished in 00:01:05
# Epoch 8 finished. Total time: 591.71 seconds
#  Client10 Train => Local Epoch: 0 	Acc: 79.600 	Loss: 0.5417
#  Client10 Test =>                   	Acc: 40.113 	Loss: 3.2677
#  Client9 Train => Local Epoch: 0 	Acc: 67.911 	Loss: 1.0331
#  Client9 Test =>                   	Acc: 55.711 	Loss: 1.4234
#  Client13 Train => Local Epoch: 0 	Acc: 74.550 	Loss: 0.7649
#  Client13 Test =>                   	Acc: 65.207 	Loss: 1.0602
#  Client19 Train => Local Epoch: 0 	Acc: 72.548 	Loss: 0.7705
#  Client19 Test =>                   	Acc: 70.643 	Loss: 0.9018
#  Client12 Train => Local Epoch: 0 	Acc: 74.380 	Loss: 0.7488
#  Client12 Test =>                   	Acc: 71.424 	Loss: 0.8586
#  Client15 Train => Local Epoch: 0 	Acc: 72.923 	Loss: 0.7572
#  Client15 Test =>                   	Acc: 65.517 	Loss: 0.9405
#  Client14 Train => Local Epoch: 0 	Acc: 73.233 	Loss: 0.8336
#  Client14 Test =>                   	Acc: 36.961 	Loss: 2.5348
#  Client16 Train => Local Epoch: 0 	Acc: 69.984 	Loss: 0.9482
#  Client16 Test =>                   	Acc: 70.737 	Loss: 0.8926
#  Client0 Train => Local Epoch: 0 	Acc: 74.683 	Loss: 0.7110
#  Client0 Test =>                   	Acc: 38.530 	Loss: 2.6895
#  Client11 Train => Local Epoch: 0 	Acc: 69.329 	Loss: 0.9573
#  Client11 Test =>                   	Acc: 58.291 	Loss: 1.6103
#  Client3 Train => Local Epoch: 0 	Acc: 75.910 	Loss: 0.6875
#  Client3 Test =>                   	Acc: 36.476 	Loss: 2.9151
#  Client2 Train => Local Epoch: 0 	Acc: 79.253 	Loss: 0.5443
#  Client2 Test =>                   	Acc: 36.651 	Loss: 3.5350
#  Client7 Train => Local Epoch: 0 	Acc: 67.691 	Loss: 1.1014
#  Client7 Test =>                   	Acc: 61.005 	Loss: 1.1765
#  Client4 Train => Local Epoch: 0 	Acc: 72.201 	Loss: 0.8238
#  Client4 Test =>                   	Acc: 66.871 	Loss: 0.8998
#  Client18 Train => Local Epoch: 0 	Acc: 74.887 	Loss: 0.7392
#  Client18 Test =>                   	Acc: 66.851 	Loss: 1.0410
#  Client8 Train => Local Epoch: 0 	Acc: 73.837 	Loss: 0.7601
#  Client8 Test =>                   	Acc: 71.228 	Loss: 0.9384
#  Client6 Train => Local Epoch: 0 	Acc: 74.580 	Loss: 0.7257
#  Client6 Test =>                   	Acc: 70.016 	Loss: 0.8894
#  Client17 Train => Local Epoch: 0 	Acc: 74.575 	Loss: 0.7301
#  Client17 Test =>                   	Acc: 67.827 	Loss: 0.9077
#  Client1 Train => Local Epoch: 0 	Acc: 70.859 	Loss: 0.8742
#  Client1 Test =>                   	Acc: 40.793 	Loss: 2.3904
#  Client5 Train => Local Epoch: 0 	Acc: 68.042 	Loss: 0.9728
#  Client5 Test =>                   	Acc: 67.201 	Loss: 1.0710
# ====================== SERVER V1==========================
#  Train: Round   9, Avg Accuracy 73.049 | Avg Loss 0.801
#  Test: Round   9, Avg Accuracy 57.903 | Avg Loss 1.597
# ==========================================================
# idxs_users [10  9 13 19 12 15 14 16  0 11  3  2  7  4 18  8  6 17  1  5]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 9 finished in 00:01:05
# Epoch 9 finished. Total time: 657.27 seconds
#  Client12 Train => Local Epoch: 0 	Acc: 75.025 	Loss: 0.7418
#  Client12 Test =>                   	Acc: 71.127 	Loss: 0.8943
#  Client11 Train => Local Epoch: 0 	Acc: 74.591 	Loss: 0.7232
#  Client11 Test =>                   	Acc: 62.042 	Loss: 1.1884
#  Client2 Train => Local Epoch: 0 	Acc: 75.593 	Loss: 0.7452
#  Client2 Test =>                   	Acc: 39.756 	Loss: 2.4593
#  Client17 Train => Local Epoch: 0 	Acc: 71.831 	Loss: 0.8627
#  Client17 Test =>                   	Acc: 64.366 	Loss: 1.0843
#  Client9 Train => Local Epoch: 0 	Acc: 75.807 	Loss: 0.7013
#  Client9 Test =>                   	Acc: 67.491 	Loss: 0.9319
#  Client3 Train => Local Epoch: 0 	Acc: 72.659 	Loss: 0.8299
#  Client3 Test =>                   	Acc: 37.116 	Loss: 2.5182
#  Client6 Train => Local Epoch: 0 	Acc: 71.627 	Loss: 0.8741
#  Client6 Test =>                   	Acc: 66.204 	Loss: 1.1564
#  Client5 Train => Local Epoch: 0 	Acc: 73.837 	Loss: 0.7491
#  Client5 Test =>                   	Acc: 69.895 	Loss: 0.9155
#  Client4 Train => Local Epoch: 0 	Acc: 75.340 	Loss: 0.7173
#  Client4 Test =>                   	Acc: 70.057 	Loss: 0.8842
#  Client10 Train => Local Epoch: 0 	Acc: 74.005 	Loss: 0.7593
#  Client10 Test =>                   	Acc: 42.807 	Loss: 2.3791
#  Client8 Train => Local Epoch: 0 	Acc: 71.085 	Loss: 0.9050
#  Client8 Test =>                   	Acc: 66.750 	Loss: 1.0422
#  Client14 Train => Local Epoch: 0 	Acc: 75.099 	Loss: 0.7176
#  Client14 Test =>                   	Acc: 33.621 	Loss: 2.9311
#  Client1 Train => Local Epoch: 0 	Acc: 79.517 	Loss: 0.5534
#  Client1 Test =>                   	Acc: 41.750 	Loss: 3.2107
#  Client18 Train => Local Epoch: 0 	Acc: 69.297 	Loss: 1.0326
#  Client18 Test =>                   	Acc: 57.173 	Loss: 1.4509
#  Client19 Train => Local Epoch: 0 	Acc: 75.308 	Loss: 0.7336
#  Client19 Test =>                   	Acc: 66.285 	Loss: 1.1861
#  Client16 Train => Local Epoch: 0 	Acc: 74.901 	Loss: 0.7367
#  Client16 Test =>                   	Acc: 72.616 	Loss: 0.8216
#  Client15 Train => Local Epoch: 0 	Acc: 76.939 	Loss: 0.7091
#  Client15 Test =>                   	Acc: 72.245 	Loss: 0.8155
#  Client13 Train => Local Epoch: 0 	Acc: 75.136 	Loss: 0.7046
#  Client13 Test =>                   	Acc: 69.956 	Loss: 0.9016
#  Client0 Train => Local Epoch: 0 	Acc: 72.100 	Loss: 0.8382
#  Client0 Test =>                   	Acc: 41.049 	Loss: 2.3476
#  Client7 Train => Local Epoch: 0 	Acc: 70.846 	Loss: 0.9052
#  Client7 Test =>                   	Acc: 61.752 	Loss: 1.2283
# ====================== SERVER V1==========================
#  Train: Round  10, Avg Accuracy 74.027 | Avg Loss 0.777
#  Test: Round  10, Avg Accuracy 58.703 | Avg Loss 1.517
# ==========================================================
# idxs_users [12 11  2 17  9  3  6  5  4 10  8 14  1 18 19 16 15 13  0  7]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 10 finished in 00:01:05
# Epoch 10 finished. Total time: 722.95 seconds
#  Client7 Train => Local Epoch: 0 	Acc: 77.934 	Loss: 0.6535
#  Client7 Test =>                   	Acc: 69.390 	Loss: 0.8750
#  Client5 Train => Local Epoch: 0 	Acc: 75.455 	Loss: 0.6998
#  Client5 Test =>                   	Acc: 71.383 	Loss: 0.9238
#  Client15 Train => Local Epoch: 0 	Acc: 76.958 	Loss: 0.6604
#  Client15 Test =>                   	Acc: 70.461 	Loss: 0.8150
#  Client12 Train => Local Epoch: 0 	Acc: 76.153 	Loss: 0.6840
#  Client12 Test =>                   	Acc: 70.292 	Loss: 0.9258
#  Client10 Train => Local Epoch: 0 	Acc: 73.796 	Loss: 0.8026
#  Client10 Test =>                   	Acc: 45.292 	Loss: 1.9700
#  Client14 Train => Local Epoch: 0 	Acc: 80.832 	Loss: 0.5298
#  Client14 Test =>                   	Acc: 33.520 	Loss: 3.8187
#  Client19 Train => Local Epoch: 0 	Acc: 69.995 	Loss: 0.9685
#  Client19 Test =>                   	Acc: 66.925 	Loss: 1.0435
#  Client13 Train => Local Epoch: 0 	Acc: 76.358 	Loss: 0.6832
#  Client13 Test =>                   	Acc: 67.066 	Loss: 1.0619
#  Client3 Train => Local Epoch: 0 	Acc: 73.716 	Loss: 0.7503
#  Client3 Test =>                   	Acc: 35.069 	Loss: 2.9557
#  Client1 Train => Local Epoch: 0 	Acc: 81.193 	Loss: 0.5148
#  Client1 Test =>                   	Acc: 39.736 	Loss: 3.4580
#  Client6 Train => Local Epoch: 0 	Acc: 69.141 	Loss: 1.0095
#  Client6 Test =>                   	Acc: 62.278 	Loss: 1.1673
#  Client2 Train => Local Epoch: 0 	Acc: 77.121 	Loss: 0.6187
#  Client2 Test =>                   	Acc: 39.022 	Loss: 2.9384
#  Client9 Train => Local Epoch: 0 	Acc: 71.236 	Loss: 0.8920
#  Client9 Test =>                   	Acc: 66.709 	Loss: 1.1592
#  Client4 Train => Local Epoch: 0 	Acc: 76.788 	Loss: 0.7074
#  Client4 Test =>                   	Acc: 73.067 	Loss: 0.8871
#  Client18 Train => Local Epoch: 0 	Acc: 76.588 	Loss: 0.6829
#  Client18 Test =>                   	Acc: 66.278 	Loss: 1.0636
#  Client8 Train => Local Epoch: 0 	Acc: 76.402 	Loss: 0.6936
#  Client8 Test =>                   	Acc: 75.822 	Loss: 0.7443
#  Client17 Train => Local Epoch: 0 	Acc: 76.801 	Loss: 0.6665
#  Client17 Test =>                   	Acc: 56.351 	Loss: 1.6223
#  Client11 Train => Local Epoch: 0 	Acc: 76.050 	Loss: 0.6943
#  Client11 Test =>                   	Acc: 70.447 	Loss: 0.8903
#  Client0 Train => Local Epoch: 0 	Acc: 74.111 	Loss: 0.8097
#  Client0 Test =>                   	Acc: 40.329 	Loss: 2.4208
#  Client16 Train => Local Epoch: 0 	Acc: 71.898 	Loss: 0.8782
#  Client16 Test =>                   	Acc: 68.023 	Loss: 0.9212
# ====================== SERVER V1==========================
#  Train: Round  11, Avg Accuracy 75.426 | Avg Loss 0.730
#  Test: Round  11, Avg Accuracy 59.373 | Avg Loss 1.583
# ==========================================================
# idxs_users [ 7  5 15 12 10 14 19 13  3  1  6  2  9  4 18  8 17 11  0 16]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 11 finished in 00:01:05
# Epoch 11 finished. Total time: 788.61 seconds
#  Client5 Train => Local Epoch: 0 	Acc: 75.908 	Loss: 0.6887
#  Client5 Test =>                   	Acc: 70.420 	Loss: 0.9758
#  Client2 Train => Local Epoch: 0 	Acc: 76.379 	Loss: 0.6905
#  Client2 Test =>                   	Acc: 37.177 	Loss: 2.6714
#  Client3 Train => Local Epoch: 0 	Acc: 80.322 	Loss: 0.5209
#  Client3 Test =>                   	Acc: 36.342 	Loss: 3.7429
#  Client7 Train => Local Epoch: 0 	Acc: 70.519 	Loss: 0.9505
#  Client7 Test =>                   	Acc: 59.106 	Loss: 1.1797
#  Client11 Train => Local Epoch: 0 	Acc: 78.502 	Loss: 0.6316
#  Client11 Test =>                   	Acc: 72.360 	Loss: 0.9311
#  Client15 Train => Local Epoch: 0 	Acc: 77.516 	Loss: 0.6402
#  Client15 Test =>                   	Acc: 71.107 	Loss: 0.9058
#  Client0 Train => Local Epoch: 0 	Acc: 74.046 	Loss: 0.7944
#  Client0 Test =>                   	Acc: 35.796 	Loss: 2.6931
#  Client9 Train => Local Epoch: 0 	Acc: 73.706 	Loss: 0.8121
#  Client9 Test =>                   	Acc: 70.602 	Loss: 0.9385
#  Client13 Train => Local Epoch: 0 	Acc: 77.521 	Loss: 0.6325
#  Client13 Test =>                   	Acc: 73.006 	Loss: 0.8180
#  Client4 Train => Local Epoch: 0 	Acc: 77.994 	Loss: 0.6605
#  Client4 Test =>                   	Acc: 76.307 	Loss: 0.7289
#  Client18 Train => Local Epoch: 0 	Acc: 77.348 	Loss: 0.6489
#  Client18 Test =>                   	Acc: 71.599 	Loss: 0.8504
#  Client14 Train => Local Epoch: 0 	Acc: 74.869 	Loss: 0.7877
#  Client14 Test =>                   	Acc: 36.335 	Loss: 2.9707
#  Client16 Train => Local Epoch: 0 	Acc: 73.097 	Loss: 0.8330
#  Client16 Test =>                   	Acc: 72.845 	Loss: 0.9346
#  Client10 Train => Local Epoch: 0 	Acc: 76.921 	Loss: 0.6448
#  Client10 Test =>                   	Acc: 36.685 	Loss: 2.7267
#  Client17 Train => Local Epoch: 0 	Acc: 71.668 	Loss: 0.8981
#  Client17 Test =>                   	Acc: 58.702 	Loss: 1.4970
#  Client1 Train => Local Epoch: 0 	Acc: 76.553 	Loss: 0.6433
#  Client1 Test =>                   	Acc: 44.174 	Loss: 2.4922
#  Client12 Train => Local Epoch: 0 	Acc: 72.824 	Loss: 0.8559
#  Client12 Test =>                   	Acc: 67.868 	Loss: 0.9642
#  Client8 Train => Local Epoch: 0 	Acc: 76.629 	Loss: 0.6554
#  Client8 Test =>                   	Acc: 74.293 	Loss: 0.7604
#  Client19 Train => Local Epoch: 0 	Acc: 77.125 	Loss: 0.6412
#  Client19 Test =>                   	Acc: 70.158 	Loss: 0.9704
#  Client6 Train => Local Epoch: 0 	Acc: 76.441 	Loss: 0.6663
#  Client6 Test =>                   	Acc: 76.684 	Loss: 0.7359
# ====================== SERVER V1==========================
#  Train: Round  12, Avg Accuracy 75.794 | Avg Loss 0.715
#  Test: Round  12, Avg Accuracy 60.578 | Avg Loss 1.524
# ==========================================================
# idxs_users [ 5  2  3  7 11 15  0  9 13  4 18 14 16 10 17  1 12  8 19  6]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 12 finished in 00:01:06
# Epoch 12 finished. Total time: 854.72 seconds
#  Client17 Train => Local Epoch: 0 	Acc: 79.079 	Loss: 0.6131
#  Client17 Test =>                   	Acc: 71.579 	Loss: 0.8189
#  Client5 Train => Local Epoch: 0 	Acc: 77.045 	Loss: 0.6445
#  Client5 Test =>                   	Acc: 75.000 	Loss: 0.7842
#  Client0 Train => Local Epoch: 0 	Acc: 75.271 	Loss: 0.7892
#  Client0 Test =>                   	Acc: 40.322 	Loss: 2.7401
#  Client8 Train => Local Epoch: 0 	Acc: 74.350 	Loss: 0.7773
#  Client8 Test =>                   	Acc: 73.963 	Loss: 0.7436
#  Client14 Train => Local Epoch: 0 	Acc: 78.079 	Loss: 0.6367
#  Client14 Test =>                   	Acc: 39.817 	Loss: 2.5698
#  Client19 Train => Local Epoch: 0 	Acc: 73.780 	Loss: 0.8367
#  Client19 Test =>                   	Acc: 71.424 	Loss: 0.9915
#  Client10 Train => Local Epoch: 0 	Acc: 78.899 	Loss: 0.6267
#  Client10 Test =>                   	Acc: 43.979 	Loss: 2.5800
#  Client7 Train => Local Epoch: 0 	Acc: 73.447 	Loss: 0.8355
#  Client7 Test =>                   	Acc: 65.834 	Loss: 0.9984
#  Client16 Train => Local Epoch: 0 	Acc: 76.579 	Loss: 0.6658
#  Client16 Test =>                   	Acc: 74.158 	Loss: 0.7712
#  Client15 Train => Local Epoch: 0 	Acc: 77.408 	Loss: 0.6402
#  Client15 Test =>                   	Acc: 71.734 	Loss: 0.8872
#  Client12 Train => Local Epoch: 0 	Acc: 77.613 	Loss: 0.6324
#  Client12 Test =>                   	Acc: 71.343 	Loss: 0.9248
#  Client18 Train => Local Epoch: 0 	Acc: 79.049 	Loss: 0.6142
#  Client18 Test =>                   	Acc: 73.168 	Loss: 0.8316
#  Client9 Train => Local Epoch: 0 	Acc: 77.551 	Loss: 0.6235
#  Client9 Test =>                   	Acc: 74.919 	Loss: 0.7877
#  Client2 Train => Local Epoch: 0 	Acc: 74.625 	Loss: 0.7919
#  Client2 Test =>                   	Acc: 42.161 	Loss: 2.5770
#  Client13 Train => Local Epoch: 0 	Acc: 72.723 	Loss: 0.8082
#  Client13 Test =>                   	Acc: 68.918 	Loss: 1.0922
#  Client4 Train => Local Epoch: 0 	Acc: 77.378 	Loss: 0.6586
#  Client4 Test =>                   	Acc: 73.438 	Loss: 0.7334
#  Client11 Train => Local Epoch: 0 	Acc: 78.380 	Loss: 0.6320
#  Client11 Test =>                   	Acc: 71.518 	Loss: 0.8723
#  Client1 Train => Local Epoch: 0 	Acc: 74.660 	Loss: 0.7854
#  Client1 Test =>                   	Acc: 45.602 	Loss: 2.2005
#  Client6 Train => Local Epoch: 0 	Acc: 72.374 	Loss: 0.8200
#  Client6 Test =>                   	Acc: 69.450 	Loss: 0.9644
#  Client3 Train => Local Epoch: 0 	Acc: 77.525 	Loss: 0.6529
#  Client3 Test =>                   	Acc: 35.500 	Loss: 2.9254
# ====================== SERVER V1==========================
#  Train: Round  13, Avg Accuracy 76.291 | Avg Loss 0.704
#  Test: Round  13, Avg Accuracy 62.691 | Avg Loss 1.390
# ==========================================================
# idxs_users [17  5  0  8 14 19 10  7 16 15 12 18  9  2 13  4 11  1  6  3]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 13 finished in 00:01:06
# Epoch 13 finished. Total time: 920.87 seconds
#  Client10 Train => Local Epoch: 0 	Acc: 84.127 	Loss: 0.4468
#  Client10 Test =>                   	Acc: 41.359 	Loss: 3.3638
#  Client19 Train => Local Epoch: 0 	Acc: 71.866 	Loss: 0.9487
#  Client19 Test =>                   	Acc: 61.591 	Loss: 1.2415
#  Client0 Train => Local Epoch: 0 	Acc: 78.596 	Loss: 0.6056
#  Client0 Test =>                   	Acc: 36.961 	Loss: 2.9590
#  Client5 Train => Local Epoch: 0 	Acc: 73.433 	Loss: 0.8212
#  Client5 Test =>                   	Acc: 66.810 	Loss: 1.1114
#  Client13 Train => Local Epoch: 0 	Acc: 79.743 	Loss: 0.5837
#  Client13 Test =>                   	Acc: 71.929 	Loss: 1.0595
#  Client11 Train => Local Epoch: 0 	Acc: 79.049 	Loss: 0.6069
#  Client11 Test =>                   	Acc: 69.976 	Loss: 1.0344
#  Client12 Train => Local Epoch: 0 	Acc: 79.534 	Loss: 0.6000
#  Client12 Test =>                   	Acc: 74.003 	Loss: 0.8861
#  Client18 Train => Local Epoch: 0 	Acc: 80.129 	Loss: 0.6033
#  Client18 Test =>                   	Acc: 71.269 	Loss: 0.9804
#  Client4 Train => Local Epoch: 0 	Acc: 78.454 	Loss: 0.6313
#  Client4 Test =>                   	Acc: 77.620 	Loss: 0.6307
#  Client8 Train => Local Epoch: 0 	Acc: 79.079 	Loss: 0.6126
#  Client8 Test =>                   	Acc: 75.391 	Loss: 0.7468
#  Client15 Train => Local Epoch: 0 	Acc: 78.745 	Loss: 0.5985
#  Client15 Test =>                   	Acc: 71.700 	Loss: 0.8916
#  Client17 Train => Local Epoch: 0 	Acc: 79.644 	Loss: 0.5984
#  Client17 Test =>                   	Acc: 70.232 	Loss: 0.7809
#  Client3 Train => Local Epoch: 0 	Acc: 77.130 	Loss: 0.7901
#  Client3 Test =>                   	Acc: 38.544 	Loss: 2.7619
#  Client7 Train => Local Epoch: 0 	Acc: 75.124 	Loss: 0.7901
#  Client7 Test =>                   	Acc: 63.995 	Loss: 1.0826
#  Client16 Train => Local Epoch: 0 	Acc: 78.812 	Loss: 0.6217
#  Client16 Test =>                   	Acc: 73.633 	Loss: 0.7882
#  Client9 Train => Local Epoch: 0 	Acc: 79.347 	Loss: 0.5808
#  Client9 Test =>                   	Acc: 74.960 	Loss: 0.7942
#  Client1 Train => Local Epoch: 0 	Acc: 75.646 	Loss: 0.7824
#  Client1 Test =>                   	Acc: 41.864 	Loss: 2.8453
#  Client14 Train => Local Epoch: 0 	Acc: 82.443 	Loss: 0.4799
#  Client14 Test =>                   	Acc: 36.820 	Loss: 3.8268
#  Client2 Train => Local Epoch: 0 	Acc: 82.417 	Loss: 0.4632
#  Client2 Test =>                   	Acc: 39.285 	Loss: 3.9906
#  Client6 Train => Local Epoch: 0 	Acc: 71.949 	Loss: 0.9866
#  Client6 Test =>                   	Acc: 66.831 	Loss: 1.0108
# ====================== SERVER V1==========================
#  Train: Round  14, Avg Accuracy 78.263 | Avg Loss 0.658
#  Test: Round  14, Avg Accuracy 61.239 | Avg Loss 1.639
# ==========================================================
# idxs_users [10 19  0  5 13 11 12 18  4  8 15 17  3  7 16  9  1 14  2  6]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 14 finished in 00:01:06
# Epoch 14 finished. Total time: 987.26 seconds
#  Client2 Train => Local Epoch: 0 	Acc: 80.234 	Loss: 0.5785
#  Client2 Test =>                   	Acc: 38.955 	Loss: 3.0848
#  Client8 Train => Local Epoch: 0 	Acc: 75.972 	Loss: 0.7948
#  Client8 Test =>                   	Acc: 71.579 	Loss: 0.8148
#  Client0 Train => Local Epoch: 0 	Acc: 78.051 	Loss: 0.6311
#  Client0 Test =>                   	Acc: 38.524 	Loss: 3.1410
#  Client16 Train => Local Epoch: 0 	Acc: 76.153 	Loss: 0.7510
#  Client16 Test =>                   	Acc: 69.666 	Loss: 1.0172
#  Client1 Train => Local Epoch: 0 	Acc: 78.971 	Loss: 0.5842
#  Client1 Test =>                   	Acc: 46.208 	Loss: 2.5447
#  Client17 Train => Local Epoch: 0 	Acc: 73.961 	Loss: 0.8275
#  Client17 Test =>                   	Acc: 62.271 	Loss: 1.2876
#  Client9 Train => Local Epoch: 0 	Acc: 81.804 	Loss: 0.5389
#  Client9 Test =>                   	Acc: 75.101 	Loss: 0.7984
#  Client18 Train => Local Epoch: 0 	Acc: 79.713 	Loss: 0.5786
#  Client18 Test =>                   	Acc: 74.771 	Loss: 0.8242
#  Client11 Train => Local Epoch: 0 	Acc: 79.561 	Loss: 0.5981
#  Client11 Test =>                   	Acc: 73.808 	Loss: 0.8832
#  Client3 Train => Local Epoch: 0 	Acc: 76.783 	Loss: 0.7388
#  Client3 Test =>                   	Acc: 41.164 	Loss: 2.5210
#  Client15 Train => Local Epoch: 0 	Acc: 75.358 	Loss: 0.7873
#  Client15 Test =>                   	Acc: 67.949 	Loss: 0.8685
#  Client12 Train => Local Epoch: 0 	Acc: 80.450 	Loss: 0.5856
#  Client12 Test =>                   	Acc: 72.407 	Loss: 0.9589
#  Client5 Train => Local Epoch: 0 	Acc: 78.412 	Loss: 0.6300
#  Client5 Test =>                   	Acc: 73.768 	Loss: 0.9207
#  Client14 Train => Local Epoch: 0 	Acc: 76.944 	Loss: 0.7329
#  Client14 Test =>                   	Acc: 35.439 	Loss: 3.3072
#  Client4 Train => Local Epoch: 0 	Acc: 74.731 	Loss: 0.8114
#  Client4 Test =>                   	Acc: 76.818 	Loss: 0.7067
#  Client13 Train => Local Epoch: 0 	Acc: 78.801 	Loss: 0.5990
#  Client13 Test =>                   	Acc: 76.798 	Loss: 0.8044
#  Client10 Train => Local Epoch: 0 	Acc: 77.240 	Loss: 0.6916
#  Client10 Test =>                   	Acc: 43.609 	Loss: 2.5039
#  Client19 Train => Local Epoch: 0 	Acc: 75.342 	Loss: 0.7576
#  Client19 Test =>                   	Acc: 71.444 	Loss: 0.9008
#  Client7 Train => Local Epoch: 0 	Acc: 78.490 	Loss: 0.6148
#  Client7 Test =>                   	Acc: 66.534 	Loss: 1.0823
#  Client6 Train => Local Epoch: 0 	Acc: 79.072 	Loss: 0.6111
#  Client6 Test =>                   	Acc: 69.423 	Loss: 1.0090
# ====================== SERVER V1==========================
#  Train: Round  15, Avg Accuracy 77.802 | Avg Loss 0.672
#  Test: Round  15, Avg Accuracy 62.312 | Avg Loss 1.499
# ==========================================================
# ...
#  Client18 Test =>                   	Acc: 78.637 	Loss: 1.2749
#  Client2 Train => Local Epoch: 0 	Acc: 91.932 	Loss: 0.4308
#  Client2 Test =>                   	Acc: 42.511 	Loss: 5.8657
#  Client14 Train => Local Epoch: 0 	Acc: 94.458 	Loss: 0.1712
#  Client14 Test =>                   	Acc: 38.955 	Loss: 10.5263
# ====================== SERVER V1==========================
#  Train: Round  94, Avg Accuracy 93.887 | Avg Loss 0.240
#  Test: Round  94, Avg Accuracy 68.407 | Avg Loss 2.793
# ==========================================================
# idxs_users [15  1  8 11 10 19  9 12  3 17  4 13  0  6  5  7 16 18  2 14]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 94 finished in 00:01:05
# Epoch 94 finished. Total time: 6248.56 seconds
#  Client10 Train => Local Epoch: 0 	Acc: 95.673 	Loss: 0.1241
#  Client10 Test =>                   	Acc: 44.902 	Loss: 10.8583
#  Client5 Train => Local Epoch: 0 	Acc: 92.093 	Loss: 0.2911
#  Client5 Test =>                   	Acc: 77.539 	Loss: 1.6335
#  Client6 Train => Local Epoch: 0 	Acc: 95.673 	Loss: 0.1441
#  Client6 Test =>                   	Acc: 78.873 	Loss: 1.8862
#  Client15 Train => Local Epoch: 0 	Acc: 94.467 	Loss: 0.1772
#  Client15 Test =>                   	Acc: 78.772 	Loss: 0.9630
#  Client4 Train => Local Epoch: 0 	Acc: 94.584 	Loss: 0.1882
#  Client4 Test =>                   	Acc: 84.328 	Loss: 0.7572
#  Client0 Train => Local Epoch: 0 	Acc: 90.942 	Loss: 0.4947
#  Client0 Test =>                   	Acc: 41.635 	Loss: 6.1361
#  Client7 Train => Local Epoch: 0 	Acc: 92.865 	Loss: 0.2567
#  Client7 Test =>                   	Acc: 78.401 	Loss: 1.2094
#  Client11 Train => Local Epoch: 0 	Acc: 95.639 	Loss: 0.1339
#  Client11 Test =>                   	Acc: 79.553 	Loss: 1.3428
#  Client8 Train => Local Epoch: 0 	Acc: 95.283 	Loss: 0.1523
#  Client8 Test =>                   	Acc: 80.496 	Loss: 0.9605
#  Client14 Train => Local Epoch: 0 	Acc: 91.406 	Loss: 0.5058
#  Client14 Test =>                   	Acc: 44.275 	Loss: 6.7442
#  Client2 Train => Local Epoch: 0 	Acc: 94.697 	Loss: 0.1844
#  Client2 Test =>                   	Acc: 39.621 	Loss: 8.2823
#  Client12 Train => Local Epoch: 0 	Acc: 91.590 	Loss: 0.4168
#  Client12 Test =>                   	Acc: 80.300 	Loss: 0.9811
#  Client19 Train => Local Epoch: 0 	Acc: 94.667 	Loss: 0.1602
#  Client19 Test =>                   	Acc: 82.981 	Loss: 1.0069
#  Client17 Train => Local Epoch: 0 	Acc: 95.331 	Loss: 0.1603
#  Client17 Test =>                   	Acc: 82.152 	Loss: 0.8888
#  Client13 Train => Local Epoch: 0 	Acc: 95.136 	Loss: 0.1535
#  Client13 Test =>                   	Acc: 77.835 	Loss: 1.6275
#  Client3 Train => Local Epoch: 0 	Acc: 90.609 	Loss: 0.4447
#  Client3 Test =>                   	Acc: 41.022 	Loss: 6.8176
#  Client16 Train => Local Epoch: 0 	Acc: 93.964 	Loss: 0.2063
#  Client16 Test =>                   	Acc: 80.105 	Loss: 0.9406
#  Client18 Train => Local Epoch: 0 	Acc: 94.984 	Loss: 0.1625
#  Client18 Test =>                   	Acc: 76.913 	Loss: 1.2787
#  Client1 Train => Local Epoch: 0 	Acc: 93.720 	Loss: 0.2720
#  Client1 Test =>                   	Acc: 47.852 	Loss: 4.9683
#  Client9 Train => Local Epoch: 0 	Acc: 93.794 	Loss: 0.2325
#  Client9 Test =>                   	Acc: 76.933 	Loss: 1.2162
# ====================== SERVER V1==========================
#  Train: Round  95, Avg Accuracy 93.856 | Avg Loss 0.243
#  Test: Round  95, Avg Accuracy 68.724 | Avg Loss 3.025
# ==========================================================
# idxs_users [10  5  6 15  4  0  7 11  8 14  2 12 19 17 13  3 16 18  1  9]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 95 finished in 00:01:05
# Epoch 95 finished. Total time: 6313.90 seconds
#  Client13 Train => Local Epoch: 0 	Acc: 95.595 	Loss: 0.1531
#  Client13 Test =>                   	Acc: 76.057 	Loss: 1.9850
#  Client15 Train => Local Epoch: 0 	Acc: 94.646 	Loss: 0.1813
#  Client15 Test =>                   	Acc: 79.263 	Loss: 1.1520
#  Client5 Train => Local Epoch: 0 	Acc: 94.607 	Loss: 0.1670
#  Client5 Test =>                   	Acc: 82.644 	Loss: 1.0067
#  Client4 Train => Local Epoch: 0 	Acc: 95.097 	Loss: 0.1693
#  Client4 Test =>                   	Acc: 82.738 	Loss: 1.2671
#  Client12 Train => Local Epoch: 0 	Acc: 96.059 	Loss: 0.1253
#  Client12 Test =>                   	Acc: 81.371 	Loss: 0.9092
#  Client0 Train => Local Epoch: 0 	Acc: 90.570 	Loss: 0.5539
#  Client0 Test =>                   	Acc: 38.450 	Loss: 6.3235
#  Client10 Train => Local Epoch: 0 	Acc: 95.200 	Loss: 0.1380
#  Client10 Test =>                   	Acc: 44.841 	Loss: 8.8379
#  Client6 Train => Local Epoch: 0 	Acc: 92.394 	Loss: 0.3117
#  Client6 Test =>                   	Acc: 75.977 	Loss: 1.4627
#  Client16 Train => Local Epoch: 0 	Acc: 94.770 	Loss: 0.1487
#  Client16 Test =>                   	Acc: 78.165 	Loss: 0.9914
#  Client19 Train => Local Epoch: 0 	Acc: 94.706 	Loss: 0.1766
#  Client19 Test =>                   	Acc: 81.977 	Loss: 1.8152
#  Client2 Train => Local Epoch: 0 	Acc: 91.034 	Loss: 0.4745
#  Client2 Test =>                   	Acc: 42.733 	Loss: 6.4721
#  Client11 Train => Local Epoch: 0 	Acc: 93.876 	Loss: 0.2919
#  Client11 Test =>                   	Acc: 73.222 	Loss: 2.3252
#  Client8 Train => Local Epoch: 0 	Acc: 94.862 	Loss: 0.1579
#  Client8 Test =>                   	Acc: 80.374 	Loss: 1.1201
#  Client14 Train => Local Epoch: 0 	Acc: 92.900 	Loss: 0.3029
#  Client14 Test =>                   	Acc: 41.339 	Loss: 5.9656
#  Client7 Train => Local Epoch: 0 	Acc: 93.339 	Loss: 0.2357
#  Client7 Test =>                   	Acc: 77.169 	Loss: 1.4886
#  Client18 Train => Local Epoch: 0 	Acc: 95.326 	Loss: 0.1599
#  Client18 Test =>                   	Acc: 75.546 	Loss: 1.1714
#  Client3 Train => Local Epoch: 0 	Acc: 93.217 	Loss: 0.2756
#  Client3 Test =>                   	Acc: 41.925 	Loss: 5.8657
#  Client9 Train => Local Epoch: 0 	Acc: 93.764 	Loss: 0.2432
#  Client9 Test =>                   	Acc: 80.098 	Loss: 0.9745
#  Client1 Train => Local Epoch: 0 	Acc: 93.051 	Loss: 0.2627
#  Client1 Test =>                   	Acc: 47.905 	Loss: 4.6942
#  Client17 Train => Local Epoch: 0 	Acc: 93.690 	Loss: 0.2417
#  Client17 Test =>                   	Acc: 76.347 	Loss: 1.5127
# ====================== SERVER V1==========================
#  Train: Round  96, Avg Accuracy 93.935 | Avg Loss 0.239
#  Test: Round  96, Avg Accuracy 67.907 | Avg Loss 2.867
# ==========================================================
# idxs_users [13 15  5  4 12  0 10  6 16 19  2 11  8 14  7 18  3  9  1 17]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 96 finished in 00:01:05
# Epoch 96 finished. Total time: 6378.97 seconds
#  Client17 Train => Local Epoch: 0 	Acc: 96.186 	Loss: 0.1216
#  Client17 Test =>                   	Acc: 82.482 	Loss: 0.9598
#  Client0 Train => Local Epoch: 0 	Acc: 93.798 	Loss: 0.2738
#  Client0 Test =>                   	Acc: 40.888 	Loss: 7.4453
#  Client10 Train => Local Epoch: 0 	Acc: 95.092 	Loss: 0.1489
#  Client10 Test =>                   	Acc: 40.948 	Loss: 8.1299
#  Client8 Train => Local Epoch: 0 	Acc: 92.822 	Loss: 0.2610
#  Client8 Test =>                   	Acc: 78.812 	Loss: 1.1094
#  Client15 Train => Local Epoch: 0 	Acc: 95.101 	Loss: 0.1517
#  Client15 Test =>                   	Acc: 80.805 	Loss: 1.0400
#  Client14 Train => Local Epoch: 0 	Acc: 92.865 	Loss: 0.3349
#  Client14 Test =>                   	Acc: 42.282 	Loss: 6.7568
#  Client18 Train => Local Epoch: 0 	Acc: 93.148 	Loss: 0.2339
#  Client18 Test =>                   	Acc: 77.755 	Loss: 1.2034
#  Client1 Train => Local Epoch: 0 	Acc: 94.228 	Loss: 0.2498
#  Client1 Test =>                   	Acc: 48.087 	Loss: 4.4748
#  Client19 Train => Local Epoch: 0 	Acc: 93.247 	Loss: 0.3088
#  Client19 Test =>                   	Acc: 80.024 	Loss: 1.4269
#  Client6 Train => Local Epoch: 0 	Acc: 95.595 	Loss: 0.1548
#  Client6 Test =>                   	Acc: 82.173 	Loss: 0.9513
#  Client11 Train => Local Epoch: 0 	Acc: 95.448 	Loss: 0.1557
#  Client11 Test =>                   	Acc: 78.401 	Loss: 1.2479
#  Client16 Train => Local Epoch: 0 	Acc: 95.161 	Loss: 0.1684
#  Client16 Test =>                   	Acc: 77.714 	Loss: 1.6317
#  Client4 Train => Local Epoch: 0 	Acc: 94.580 	Loss: 0.1700
#  Client4 Test =>                   	Acc: 81.998 	Loss: 1.0417
#  Client9 Train => Local Epoch: 0 	Acc: 94.320 	Loss: 0.1780
#  Client9 Test =>                   	Acc: 80.651 	Loss: 1.0338
#  Client13 Train => Local Epoch: 0 	Acc: 95.834 	Loss: 0.1324
#  Client13 Test =>                   	Acc: 77.849 	Loss: 1.3763
#  Client2 Train => Local Epoch: 0 	Acc: 91.112 	Loss: 0.5515
#  Client2 Test =>                   	Acc: 40.544 	Loss: 5.4975
#  Client5 Train => Local Epoch: 0 	Acc: 92.870 	Loss: 0.2257
#  Client5 Test =>                   	Acc: 80.981 	Loss: 0.9752
#  Client12 Train => Local Epoch: 0 	Acc: 95.335 	Loss: 0.1461
#  Client12 Test =>                   	Acc: 78.354 	Loss: 1.4634
#  Client3 Train => Local Epoch: 0 	Acc: 91.972 	Loss: 0.3906
#  Client3 Test =>                   	Acc: 41.770 	Loss: 5.5403
#  Client7 Train => Local Epoch: 0 	Acc: 94.320 	Loss: 0.2063
#  Client7 Test =>                   	Acc: 78.832 	Loss: 1.0221
# ====================== SERVER V1==========================
#  Train: Round  97, Avg Accuracy 94.152 | Avg Loss 0.228
#  Test: Round  97, Avg Accuracy 68.567 | Avg Loss 2.716
# ==========================================================
# idxs_users [17  0 10  8 15 14 18  1 19  6 11 16  4  9 13  2  5 12  3  7]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 97 finished in 00:01:05
# Epoch 97 finished. Total time: 6444.41 seconds
#  Client3 Train => Local Epoch: 0 	Acc: 93.803 	Loss: 0.2435
#  Client3 Test =>                   	Acc: 43.339 	Loss: 5.2589
#  Client15 Train => Local Epoch: 0 	Acc: 93.056 	Loss: 0.2743
#  Client15 Test =>                   	Acc: 79.674 	Loss: 1.1247
#  Client11 Train => Local Epoch: 0 	Acc: 96.576 	Loss: 0.1193
#  Client11 Test =>                   	Acc: 78.556 	Loss: 1.2226
#  Client12 Train => Local Epoch: 0 	Acc: 95.682 	Loss: 0.1294
#  Client12 Test =>                   	Acc: 81.775 	Loss: 1.0589
#  Client17 Train => Local Epoch: 0 	Acc: 95.292 	Loss: 0.1498
#  Client17 Test =>                   	Acc: 80.745 	Loss: 1.1231
#  Client10 Train => Local Epoch: 0 	Acc: 92.470 	Loss: 0.3807
#  Client10 Test =>                   	Acc: 47.447 	Loss: 4.2518
#  Client14 Train => Local Epoch: 0 	Acc: 95.478 	Loss: 0.1994
#  Client14 Test =>                   	Acc: 36.685 	Loss: 10.2293
#  Client16 Train => Local Epoch: 0 	Acc: 91.395 	Loss: 0.3643
#  Client16 Test =>                   	Acc: 76.354 	Loss: 1.0757
#  Client1 Train => Local Epoch: 0 	Acc: 93.968 	Loss: 0.2627
#  Client1 Test =>                   	Acc: 48.828 	Loss: 5.2241
#  Client19 Train => Local Epoch: 0 	Acc: 94.076 	Loss: 0.2150
#  Client19 Test =>                   	Acc: 77.364 	Loss: 1.4893
#  Client0 Train => Local Epoch: 0 	Acc: 93.998 	Loss: 0.2503
#  Client0 Test =>                   	Acc: 39.696 	Loss: 7.1048
#  Client13 Train => Local Epoch: 0 	Acc: 93.153 	Loss: 0.2502
#  Client13 Test =>                   	Acc: 78.893 	Loss: 1.2831
#  Client7 Train => Local Epoch: 0 	Acc: 94.892 	Loss: 0.1613
#  Client7 Test =>                   	Acc: 78.105 	Loss: 1.0664
#  Client5 Train => Local Epoch: 0 	Acc: 95.005 	Loss: 0.1671
#  Client5 Test =>                   	Acc: 81.277 	Loss: 1.0421
#  Client4 Train => Local Epoch: 0 	Acc: 95.032 	Loss: 0.1699
#  Client4 Test =>                   	Acc: 81.701 	Loss: 1.1304
#  Client8 Train => Local Epoch: 0 	Acc: 94.177 	Loss: 0.1844
#  Client8 Test =>                   	Acc: 81.762 	Loss: 0.8133
#  Client9 Train => Local Epoch: 0 	Acc: 95.517 	Loss: 0.1481
#  Client9 Test =>                   	Acc: 80.395 	Loss: 1.1894
#  Client2 Train => Local Epoch: 0 	Acc: 90.384 	Loss: 0.5254
#  Client2 Test =>                   	Acc: 39.952 	Loss: 5.4839
#  Client18 Train => Local Epoch: 0 	Acc: 93.603 	Loss: 0.2445
#  Client18 Test =>                   	Acc: 75.801 	Loss: 1.4523
#  Client6 Train => Local Epoch: 0 	Acc: 94.589 	Loss: 0.1693
#  Client6 Test =>                   	Acc: 82.974 	Loss: 0.9762
# ====================== SERVER V1==========================
#  Train: Round  98, Avg Accuracy 94.107 | Avg Loss 0.230
#  Test: Round  98, Avg Accuracy 68.566 | Avg Loss 2.680
# ==========================================================
# idxs_users [ 3 15 11 12 17 10 14 16  1 19  0 13  7  5  4  8  9  2 18  6]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 98 finished in 00:01:05
# Epoch 98 finished. Total time: 6509.77 seconds
#  Client8 Train => Local Epoch: 0 	Acc: 95.370 	Loss: 0.1452
#  Client8 Test =>                   	Acc: 82.658 	Loss: 0.9194
#  Client7 Train => Local Epoch: 0 	Acc: 95.414 	Loss: 0.1394
#  Client7 Test =>                   	Acc: 76.354 	Loss: 1.6535
#  Client17 Train => Local Epoch: 0 	Acc: 95.643 	Loss: 0.1562
#  Client17 Test =>                   	Acc: 81.701 	Loss: 0.9389
#  Client0 Train => Local Epoch: 0 	Acc: 92.583 	Loss: 0.3928
#  Client0 Test =>                   	Acc: 41.103 	Loss: 6.6648
#  Client9 Train => Local Epoch: 0 	Acc: 94.120 	Loss: 0.1924
#  Client9 Test =>                   	Acc: 76.542 	Loss: 1.3009
#  Client3 Train => Local Epoch: 0 	Acc: 92.895 	Loss: 0.2894
#  Client3 Test =>                   	Acc: 42.181 	Loss: 6.0375
#  Client12 Train => Local Epoch: 0 	Acc: 93.739 	Loss: 0.2150
#  Client12 Test =>                   	Acc: 76.152 	Loss: 1.6164
#  Client13 Train => Local Epoch: 0 	Acc: 95.600 	Loss: 0.1516
#  Client13 Test =>                   	Acc: 78.516 	Loss: 1.1979
#  Client6 Train => Local Epoch: 0 	Acc: 95.604 	Loss: 0.1604
#  Client6 Test =>                   	Acc: 81.412 	Loss: 1.1950
#  Client19 Train => Local Epoch: 0 	Acc: 95.643 	Loss: 0.1511
#  Client19 Test =>                   	Acc: 80.220 	Loss: 1.4696
#  Client18 Train => Local Epoch: 0 	Acc: 95.873 	Loss: 0.1322
#  Client18 Test =>                   	Acc: 79.768 	Loss: 1.0361
#  Client11 Train => Local Epoch: 0 	Acc: 94.901 	Loss: 0.1557
#  Client11 Test =>                   	Acc: 78.563 	Loss: 1.4139
#  Client10 Train => Local Epoch: 0 	Acc: 90.956 	Loss: 0.5515
#  Client10 Test =>                   	Acc: 45.838 	Loss: 4.6566
#  Client4 Train => Local Epoch: 0 	Acc: 94.228 	Loss: 0.1894
#  Client4 Test =>                   	Acc: 80.024 	Loss: 1.1972
#  Client1 Train => Local Epoch: 0 	Acc: 91.360 	Loss: 0.4083
#  Client1 Test =>                   	Acc: 45.932 	Loss: 5.1212
#  Client14 Train => Local Epoch: 0 	Acc: 95.083 	Loss: 0.1503
#  Client14 Test =>                   	Acc: 39.797 	Loss: 10.0632
#  Client5 Train => Local Epoch: 0 	Acc: 91.728 	Loss: 0.3747
#  Client5 Test =>                   	Acc: 77.990 	Loss: 1.7594
#  Client15 Train => Local Epoch: 0 	Acc: 95.370 	Loss: 0.1729
#  Client15 Test =>                   	Acc: 80.186 	Loss: 1.2504
#  Client2 Train => Local Epoch: 0 	Acc: 92.983 	Loss: 0.3153
#  Client2 Test =>                   	Acc: 44.720 	Loss: 4.7023
#  Client16 Train => Local Epoch: 0 	Acc: 92.631 	Loss: 0.2621
#  Client16 Test =>                   	Acc: 77.209 	Loss: 1.1129
# ====================== SERVER V1==========================
#  Train: Round  99, Avg Accuracy 94.086 | Avg Loss 0.235
#  Test: Round  99, Avg Accuracy 68.343 | Avg Loss 2.765
# ==========================================================
# idxs_users [ 8  7 17  0  9  3 12 13  6 19 18 11 10  4  1 14  5 15  2 16]
# ------------------------------------------------------------
# ------ Fed Server: Federation process at Client-Side -------
# ------------------------------------------------------------
# Epoch 99 finished in 00:01:04
# Epoch 99 finished. Total time: 6574.71 seconds

# %%
# ===================================================================================

print("Training and Evaluation completed!")

# ===============================================================================
# Save output data to .excel file (we use for comparision plots)
round_process = [i for i in range(1, len(acc_train_collect) + 1)]
df = DataFrame({'round': round_process, 'acc_train': acc_train_collect, 'acc_test': acc_test_collect,
                'loss_train': loss_train_collect, 'loss_test': loss_test_collect})
file_name = program + "_poisoned0.3_" + dataset_choice + ".xlsx"
df.to_excel(file_name, sheet_name="v1_test", index=False)

# =============================================================================
#                         Program Completed
# =============================================================================
# Out:
# Training and Evaluation completed!
